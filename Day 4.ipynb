# %% [markdown]
# # Revision

# %%
Names = []
Games =["pubg"," candy crush"]

# %%
Names.append("Harshuji")

# %%
Names
# Out:
# ['Harshuji']

# %%
Names.extend(Games)

# %%
Names
# Out:
# ['Harshuji', 'pubg', ' candy crush']

# %%
name = "Monty Python"
name[::-1]
# Out:
# 'nohtyP ytnoM'

# %%
elec =  ["Computer","Phone","iPhone","iPad","Microphone","Speaker","Earplugs"]

# %%
del elec[-1]
print(elec)
# Error
#
# Out:
# ['Computer', 'Phone', 'iPhone', 'iPad', 'Microphone', 'Speaker']

# %%
elec = []
print(elec)
ele = list()
# Out:
# []

# %%
w = [9,34,777,576,34,0,0.5,3,56,98,23,67,0.1,9,-0.5]
min(w)
# Out:
# -0.5

# %%
lis = [[[7,[5]]],[[1,[2,[3,4,[5,[9,8]]]]]]]

# %%
lis[1][0][1][1][2][1].remove(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 lis[1][0][1][1][2][1].remove(1)
#
# ValueError: list.remove(x): x not in list

# %%
lis
# Out:
# [[[7, [5]]], [[1, [2, [3, 4, [5, [9, 8]]]]]]]

# %%
a = "Hello Hola HeyHi"
a[0:-1:2]

# 'HloHl e '
# loHl e H
# Out:
# 'HloHl eH'

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
list1 = list1 + list2

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lis = ["apples", "mangoes","cherry"]

# %%
clear()
#  It removes all the elements from the list

# %%
lis.clear()

# %%
lis
# Out:
# []

# %%
listi = lis.copy()
listi
# Out:
# []

# %%
copy()

# %%
listi
# Out:
# ['apples', 'mangoes', 'cherry']

# %%
kite = [1,2,3,4,5,6,1,2,1,1,2,3,3,3,3]

# %%
kite.count(3)
# Out:
# 5

# %% [markdown]
# # Tuple
#
# 1. Python Data Structure
# 2. Immutable -> Unchangable
# 3. ()
# 4. It allows the Duplicacy

# %%
abd = {'w': 1, '3': 1, 'r': 2, 'e': 2, 's': 1, 'o': 1, 'u': 1, 'c': 1}

# %%
abd.fromkeys
# Out:
# <function dict.fromkeys(iterable, value=None, /)>

# %%
x = ('AWS', 'GCP', 'Azure', 'Heroku')
y = 'Cloud'
thisdict = dict.fromkeys(x, y)
print(thisdict)
# Out:
# {'AWS': 'Cloud', 'GCP': 'Cloud', 'Azure': 'Cloud', 'Heroku': 'Cloud'}

# %%
lis.items()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Asus\OneDrive\Desktop\Internship Devtown\Notebooks\Day 4.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/OneDrive/Desktop/Internship%20Devtown/Notebooks/Day%204.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> lis.items()
#
# AttributeError: 'list' object has no attribute 'items'
