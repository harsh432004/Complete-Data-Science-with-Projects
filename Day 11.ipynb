# %% [markdown]
# # Revision for the Day-10

# %%
# OOPs concept, principles, properies, class, objects, methods, 
# Scope of variables - Global & Local variables,
# Properties - Inheritance -> Single, Multiple & Multi-level
# Polymorphism -> Method Overriding & In python we dont have Method Overloading by default
# Constructors -> __init__(), __delete__(), __doc__(), a.__add__(b),
# super(),sub()
# Destructors
# Data Abstraction & Encapsulation

# %%
a
b(a)
c(b)
d(b,c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a
#       2 b(a)
#       3 c(b)
#
# NameError: name 'a' is not defined

# %%
def sum(a,b,c):
  print(a+b+c)

def sum(a,b):
  print(a+b)


def sum(a,b):
  print(a-b)

sum(1,4)
# Out:
# -3

# %%
sum(1,2,3) #Here we can conclude that python dosnt support method overloading

# Error
# Output
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sum(1,2,3) #Here we can conclude that python dosnt support method overloading
#       3 # Error
#       4 # Output
#
# TypeError: sum() takes 2 positional arguments but 3 were given

# %%
var = 10
var = var + 20

# %%
var
# Out:
# 30

# %%
class Animal:
  def speak(self):
    print("The animal is speaking")

class Dog(Animal):
  def speak(self):
    print("The Dog is speaking")

class Cat(Animal):
  def speak(self):
    print("The Cat is speaking")

# %%
obj1 = Dog()
obj2 = Cat()

# %%
obj1.speak()
# Out:
# The Dog is speaking

# %% [markdown]
# # Constructor

# %%
class Animal:
  a = 10  # class variables (Global Variable)
  def __init__(self, animal, sound, activity):
    self.animal = animal # Instance variables (Local variable)
    self.sound = sound
    self.activity = activity
    # body of the constructor

  def speak(self):
    print(f"The {self.animal} makes the sound {self.sound}")
  
  def speak1(self):
    print(f"The {self.animal} has an activity {self.activity}")

# %%
obj = Animal("Dog", "Bhaw Bhaw", "Barks")
# obj1 = Animal()

# %%
obj.speak("Cow", "Moooo")
# Out:
# The Cow makes the sound Moooo

# %%
obj1.speak1("Dog", "Barks")
# Out:
# The Dog has an activity Barks

# %%
obj.speak()
# Out:
# The Dog makes the sound Bhaw Bhaw

# %%
obj.speak1()
# Out:
# The Dog has an activity Barks

# %%
class Electronics:
  def __init__(self, mobile, laptop):
    self.mobile = mobile
    self.laptop = laptop
    print(f"The mobile is {self.mobile} and the laptop is {self.laptop}")

  def __init__(self, speaker, microphone):
    self.speaker = speaker
    self.microphone = microphone
    print(f"The speaker is {self.speaker} and the microphone is {self.microphone}")

# %%
obj = Electronics("iPhone", "Mac")
# Out:
# The mobile is iPhone and the laptop is Mac

# %%
class xyz:
  a = 0
  def __init__(self):
    # self.a = a
    print(self.a)
    self.a += 1
  
  def abcd(self):
    print(self.a)

# %%
obj1 = xyz()

# 0
# 1
# Error
# Out:
# 0

# %%
obj1.abcd()

# 0, 1, Error
# Out:
# 1

# %%
obj2 = xyz(0)

# 0/1
# Out:
# 0

# %%
obj3 = xyz(0
           )

# 0/1/2
# Out:
# 0

# %%
# Quiz

class Employee:
  a = 0
  def __init__(self,fname, lname, salary):
    self.fname = fname
    self.lname = lname
    self.salary = salary
    self.a = self.a + 1
    print(self.a)

# %%
obj = Employee("Ram","Mohan",45000)
obj1 = Employee("Ravi","Chandra",10000)
obj2 = Employee("Steve","Rogers",1000)
# 1
# 1 1 1
#
# Out:
# 1
# 1
# 1

# %%
# Quiz

class Student:
  a = 4
  
  def __init__(self,num):
    self.num = num
  
  def faul(self):
    print(self.num*self.a)

# %%
obj = Student(4)

# Error
# Output - 16
# No output

# %%
obj.faul()

# Error
# 16
# Out:
# 16

# %% [markdown]
# # Destructor

# %%
delete, del, discard

# %%
def __del__(self):
  # body of destructor

# %%
class Animal:
  a = 10
  def __init__(self):
    print("Over here, the constructor has initialized")
  
  def __del__(self):
    print("Over here, the destructor has initialized")

# %%
obj = Animal()
del obj
# Out:
# Over here, the constructor has initialized

# %%
del obj

# Error 
# Delete it

# %%
obj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-c88944e91e53> in <module>()
# ----> 1 obj
#
# NameError: name 'obj' is not defined

# %% [markdown]
# # Data Abstraction & Encaps

# %%
class Animal:
  __a = 10
  def speak(self):
    print(self)
    print(f"The value of __a is {self.__a + 1}")

# %%
obj = Animal()

Home- F,B,I
Ne- Rs 10

# %%
obj.speak()
# Error
# 10
# Out:
# ...
# The value of __a is 11

# %%
Google(algorithm), Yahoo, Bing, DuckDuckGo

# %%
iPhone X -> notch
Mi ()
Xaomi
 -> raindrop, punchhole

# %%
Coca Cola

red bull

# %%
classmethod, statismethod, C -> __init__, __add__,
private, public

# %%
File System -> Pandas()
DataBase System -> MySQL -> SQL
SQLite, Postgres, Oracle, MongoDB (NoSQL)

# %%
class Electronics:
  def item(self):
    print("X")
class Sub(Electronics):
  def kind(self):
    print("8051")
  def item(self):
    print("M")
  def item(self):
    print("Y")

# %%
obj = Sub()
# obj.item()
# obj.kind()

# %%
obj.item()
# Out:
# Y

# %%
a=11900-----------------Global Variable
def gob(i):
  return i+a
gob(4)
# Out:
#   File "<ipython-input-143-6e58b0ce3f64>", line 1
#     a=11900-----------------Global Variable
#                                           ^
# SyntaxError: invalid syntax

# %%
x = 12
def f1(a, b=x):
  print(a,b)

f1(4)

# %%
x = 15
f1(4)
print(x)
# Out:
# 4 12
# 15

# %%
import random

ls_comment = ["ITS FAST BALL ... JUST MISS ",
              "VERY GOOD DEFENCE 1 RUN IN THIS BALL",
              "TRY THROUGH GAP BUT MANAGED TO TAKE 2 RUNS",
              "OH HERE FIELDING MISSED HERE PLAYERS MANAGED TO SCORE 3 RUNS",
              "GREAT SHOT >>>>> ITS A FOUR .......",
              "ITS FIVE RUN",
              "WOWWW WHAT A HIT ... BALL FLYING ON HEIGHTS ITS SIXER...."]


def user_bat(name):
    counter = 0
    print("{} IS ON STRIKE.".format(name))
    print("ITS  BALL 1 :- ")
    run_user = int(input("Select a number between 0 and 6 (both included) : "))
    ball_comp = random.randint(0, 7)
    print("COMPUTER SELECTS :- {}".format(ball_comp))
    i = 2
    while (run_user != ball_comp):
        print(ls_comment[run_user])
        counter = counter + run_user
        print("THE SCORE IS {} ".format(run_user))
        print("_____________________________________________\n")
        print("ITS  BALL {} :- ".format(i))
        i += 1
        run_user = int(input("Select a number between 1 and 6 (both included) : "))
        ball_comp = random.randint(0, 6)
        print("COMPUTER SELECTS :- {}".format(ball_comp))
    else:
        print("HERE IT IS HUHUHU ...... ITS OUT .")
        print("THE TOTAL SCORE BY {} IS {} :- ".format(name, counter))
        print("*******************************************************\n\n")
        return counter


def comp_bat():
    counter = 0
    print("COMPUTER ON STRIKE : \n")
    print("ITS  BALL 1 :- ")
    ball_user = int(input("Select a number between 0 and 6 (both included) : "))
    run_comp = random.randint(0, 6)
    print("COMPUTER SELECTS :- {}".format(run_comp))
    i = 2
    while (ball_user != run_comp):
        print(ls_comment[run_comp])
        counter = counter + run_comp
        print("THE SCORE IS {} ".format(run_comp))
        print("____________________________________________\n")
        print("ITS  BALL {} :- ".format(i))
        i += 1
        ball_user = int(input("Select a number between 1 and 6 (both included) : "))
        run_comp = random.randint(0, 6)
        print("COMPUTER SELECTS :- {}".format(run_comp))
    else:
        print("HERE IT IS HUHUHU ...... ITS OUT .")
        print("THE TOTAL SCORE BY {} IS  :- {}".format("computer", counter))
        print("*******************************************************\n\n")
        return counter


print("\t\t************************    CRICKET    *****************************")
print("\t\t\t 1 . STRAT THE GAME ")
print("\t\t\t 2 . QUIT")
print("\t\t\t     press the respective number.")
choice = int(input("\t\t\t>>"))
while choice == 1:
    print("WElcome Player .....")
    user_name = input("Enter Your Name : ").upper()
    print("You have to chose Even or Odd")
    choice_user = input("Enter the choice : ").upper()
    if choice_user == "EVEN":
        choice_comp = "ODD"
    else:
        choice_comp = "EVEN"
    print("Computer chosen : {} ".format(choice_comp))
    input_user = int(input("Select a number between 1 and 6 (both included) : "))
    input_comp = random.randint(1, 6)
    print("Computer have chosen a number that is...... {} ".format(input_comp))

    if (input_comp + input_user) % 2 == 0:
        toss = "EVEN"
    else:
        toss = "ODD"

    print("THE TOSS IS {} ".format(toss))

    if toss == choice_user:
        print("{} WON THE TOSS . ".format(user_name))
        select_user = input("ENTER YOUR CHOICE BAT OR BALL\n >>").upper()
        print("{} OPT FOR {} ".format(user_name,select_user))
        if select_user == "BAT":
            select_comp = "BALL"
        else:
            select_comp = "BAT"
    else:
        print("{} WON THE TOSS . ".format("COMPUTER"))
        select_comp = random.choice(["BAT","BALL"])
        print("COMPUTER OPT FOR {} ".format(select_comp))
        if select_comp == "BALL":
            select_user = "BAT"
        else:
            select_user = "BALL"

    print("YOU ARE GOING FOR {}ING . ".format(select_user))
    print("COMPUTER IS GOING FOR {}ING . ".format(select_comp))

    if select_user == "BAT":
        user_score = user_bat(user_name)
        comp_score = comp_bat()
    else:
        comp_score = comp_bat()
        user_score = user_bat(user_name)
    if user_score > comp_score:
        print("CONGRATS CONGRATS CONGRATS {} YOU WON THE GAME BY {} RUNS.".format(user_name, user_score - comp_score))
    else:
        print("!!!!!!!! BETTER LUCK NEXT TIME {} YOU LOST THE GAME BY {} RUNS.".format(user_name, comp_score - user_score))
    print("\nPRESS 1 IF YOU WANT TO CONTINUE WITH ANOTHER MATCH OR PRESS 2 FOR QUIT")
    choice = int(input(">>"))
else:
    print("\t\t\t************** THANK YOU *************")
# Out:
# 		************************    CRICKET    *****************************
# 			 1 . STRAT THE GAME
# 			 2 . QUIT
# 			     press the respective number.
# 			>>1
# WElcome Player .....
# Enter Your Name : Tony
# You have to chose Even or Odd
# Enter the choice : OdD
# Computer chosen : EVEN
# Select a number between 1 and 6 (both included) : 2
# Computer have chosen a number that is...... 1
# THE TOSS IS ODD
# TONY WON THE TOSS .
# ENTER YOUR CHOICE BAT OR BALL
#  >>bat
# TONY OPT FOR BAT
# YOU ARE GOING FOR BATING .
# COMPUTER IS GOING FOR BALLING .
# TONY IS ON STRIKE.
# ITS  BALL 1 :-
# Select a number between 0 and 6 (both included) : 4
# COMPUTER SELECTS :- 1
# GREAT SHOT >>>>> ITS A FOUR .......
# THE SCORE IS 4
# _____________________________________________
#
# ITS  BALL 2 :-
# Select a number between 1 and 6 (both included) : 6
# COMPUTER SELECTS :- 5
# WOWWW WHAT A HIT ... BALL FLYING ON HEIGHTS ITS SIXER....
# THE SCORE IS 6
# _____________________________________________
#
# ...

# %%
def sum(a,b):
  return a+b

# %%
a= "Car"

# %%
print("This is a",a)
# Out:
# This is a Car

# %%
print(f"This is a {a} {b}, dshjfgshjfs{vjdkjd}")
# Out:
# This is a Car

# %%
var = 100
def fun1():
    var=20
    def fun2():
        # global var
        var=30        
        print(f"Value of var after : {var}")
    
    print(f"value of varr before: {var}")
    return fun2()

# fun1()

# %%
break
continue
pass

# %%
for i in range(10):
  if i == 8:
    break
  else:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(10):
  if i == 8:
    continue
  else:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 9

# %%
for i in range(10):
  if i == 8:
    pass
  else:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 9

# %%
class po:
  continue
# Out:
#   File "<ipython-input-25-8e907ae0939f>", line 2
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop

# %%
class po:
  pass

# %%
a = 9
b = a

A=B
B=C
A=C

# %%
self.some = a
self.some = self.some + 1

# %%
self.some = self.a + 1

# %%
class A():

	def __init__(self,count=100):

		self.count=count



obj1=A(104)

obj2=A(102)

print(obj1.count)

print(obj2.count)
# Out:
# 104
# 102

# %%
School_bus = Bus("School Volvo", 12, 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c6ea9157f773> in <module>()
# ----> 1 School_bus = Bus("School Volvo", 12)
#
# TypeError: __init__() missing 1 required positional argument: 'capacity'

# %%
School_bus.__name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-cf1801c07053> in <module>()
# ----> 1 School_bus.__name
#
# AttributeError: 'Bus' object has no attribute '__name'
