# %% [markdown]
# # Revision

# %%
# Inroduction of Pandas
# Pandas DS - Series, DataFrame, Panel
# CRUD -> Series
1. Using ndarray
2. Using dict
3. Scalar Value
4. Empty Series
# Boolean Masking
# Arithmetic Operation

# %% [markdown]
# # DataFrame - MIMP DS
#
# 1. It is a 2D DS

# %%
# SYNTAX: pd.DataFrame(data, index, columns, dtype, copy)

# %%
import pandas as pd

# %% [markdown]
# # CRUD must when dealing with table
# * Entire pandas is built on numpy hence we can do numpy operations on pandas

# %% [markdown]
# * C - Create

# %%
1. List
2. Dict
3. ndarrays
4. Series
5. Another DataFrame

# %% [markdown]
# 1. Empty DataFrame

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# 2. Create a DataFrame using List

# %%
data = [7,8,44,56,23,98]
df = pd.DataFrame(data)

# %%
df # It is dataframe bcz it is 2D as 0 is also come up that signifies the column
# Out:
#     0
# 0   7
# 1   8
# 2  44
# 3  56
# 4  23
# 5  98

# %%
s = pd.Series(data)

# %%
s
# Out:
# 0     7
# 1     8
# 2    44
# 3    56
# 4    23
# 5    98
# dtype: int64

# %%
data = [["Dog","Bhaw Bhaw"],["Cat", "Meow"],["Cow","Moo"]]
df = pd.DataFrame(data,columns=["Animal_name","Animal_sound"])

# %%
df
# Out:
#   Animal_name Animal_sound
# 0         Dog    Bhaw Bhaw
# 1         Cat         Meow
# 2         Cow          Moo

# %%
df
# Out:
#   Animal_name Animal_sound
# 0         Dog    Bhaw Bhaw
# 1         Cat         Meow
# 2         Cow          Moo

# %%
data = [["Dog","Bhaw Bhaw"],["Cat", "Meow"],["Cow","Moo"]]
df = pd.DataFrame(data,columns=["Animal_name"]) # It will throw error because no all coloumns are named only name is given but sound is lleft

# %% [markdown]
# 3. Dict

# %%
data = {"Name":["Ram", "Rahul", "Bhwana"], "Age":[25, 20, 18]}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age
# 0     Ram   25
# 1   Rahul   20
# 2  Bhwana   18

# %%
data = {"Name":["Ram", "Rahul", "Bhwana", "Harsh"], "Age":[25, 20, 18, 20]}
df = pd.DataFrame(data, index = ["A", "B", "C", "D"])

# %%
df
# Out:
#      Name  Age
# A     Ram   25
# B   Rahul   20
# C  Bhwana   18
# D   Harsh   20

# %%
data = {"Name":["Ram", "Rahul", "Bhwana"], "Age":[25, 20, 18, 19]}
df = pd.DataFrame(data, index = ["A", "B", "C","D"]) # It will throw error because In DF rows and cols should be precisely mentioned otherwise will throw error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 data = {"Name":["Ram", "Rahul", "Bhwana"], "Age":[25, 20, 18, 19]}
# ----> 2 df = pd.DataFrame(data, index = ["A", "B", "C","D"]) # In DF rows and cols should be precisely mentioned otherwise will throw error
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
#     734 elif isinstance(data, dict):
#     735     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 736     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     737 elif isinstance(data, ma.MaskedArray):
#     738     from numpy.ma import mrecords
#
# ...

# %% [markdown]
# 4. Create DataFrame using Series

# %%
data = {"Karan_Marks":pd.Series([50,77,65,98],index=["Test1","Test2","Test3","Test4"]),
        "Arjun_Marks":pd.Series([67,89,32,98,50],index=["Test-1","PTest1","Test-2","PTest2","Test-3"])}
df = pd.DataFrame(data)

# %%
df
# If columns headings are changed to A & B and all the values -> NaN
# If only columns headings are changed to A & B but the data remain the same
# Out:
#         Karan_Marks  Arjun_Marks
# PTest1          NaN         89.0
# PTest2          NaN         98.0
# Test-1          NaN         67.0
# Test-2          NaN         32.0
# Test-3          NaN         50.0
# Test1          50.0          NaN
# Test2          77.0          NaN
# Test3          65.0          NaN
# Test4          98.0          NaN

# %%
data = {"Karan_Marks":pd.Series([50,77,65,98],index=["Test1","Test2","Test3","Test4"]),
        "Arjun_Marks":pd.Series([67,89,32,98,50],index=["Test-1","PTest1","Test-2","PTest2","Test-3"])}
df = pd.DataFrame(data)

# %%
df
# If all columns headings are changed to A & B  and all the values  -> NaN
# If only columns headings are changed to A & B  but data remains the same
# Out:
#         Karan_Marks  Arjun_Marks
# PTest1          NaN         89.0
# PTest2          NaN         98.0
# Test-1          NaN         67.0
# Test-2          NaN         32.0
# Test-3          NaN         50.0
# Test1          50.0          NaN
# Test2          77.0          NaN
# Test3          65.0          NaN
# Test4          98.0          NaN

# %% [markdown]
# 5. Create a DataFrame from List of Dict

# %%
data = [{"A":1,"B":2,"C":90},{"C":3,"D":4},{"E":5,"F":6}]
df = pd.DataFrame(data)

# %%
df # FullForm of NaN is Not a NUMBER
# Out:
#      A    B     C    D    E    F
# 0  1.0  2.0  90.0  NaN  NaN  NaN
# 1  NaN  NaN   3.0  4.0  NaN  NaN
# 2  NaN  NaN   NaN  NaN  5.0  6.0

# %%
data = [{"A":1,"B":2},{"C":3,"D":4},{"E":5,"F":6}]
df = pd.DataFrame(data,index=["X","Y","Z"])

# %%
df
# Out:
#      A    B    C    D    E    F
# X  1.0  2.0  NaN  NaN  NaN  NaN
# Y  NaN  NaN  3.0  4.0  NaN  NaN
# Z  NaN  NaN  NaN  NaN  5.0  6.0

# %% [markdown]
# # Update

# %%
data = [10,20,30,40,50,60,70]
dat1 = [100,200,300,400,500,600,700]
df = pd.DataFrame([data,dat1], columns=["A","B","C","D","E","F","G"])

# %%
df
# Out:
#      A    B    C    D    E    F    G
# 0   10   20   30   40   50   60   70
# 1  100  200  300  400  500  600  700

# %% [markdown]
# 1. Column Selection

# %%
df["A"]
# Out:
# 0     10
# 1    100
# Name: A, dtype: int64

# %% [markdown]
# 2. Add a column

# %%
df['H'] = [56,78]

# %%
df
# Out:
#      A    B    C    D    E    F    G   H
# 0   10   20   30   40   50   60   70  56
# 1  100  200  300  400  500  600  700  78

# %%
df['M'] = pd.Series([56,78,89]) # It will not count 89 as here we have only two rows so it will only print values of 2 data

# %%
df
# Out:
#      A    B    C    D    E    F    G   H   M
# 0   10   20   30   40   50   60   70  56  56
# 1  100  200  300  400  500  600  700  78  78

# %%
df['N'] = pd.Series([56,66])

# %%
df
# Out:
#      A    B    C    D    E    F    G   H   M   N
# 0   10   20   30   40   50   60   70  56  56  56
# 1  100  200  300  400  500  600  700  78  78  66

# %%
df['Z'] = pd.Series([1,2,3,4],index=[0,1,2,3])

# %%
df
# Out:
#      A    B    C    D    E    F    G   H   M   N  Z
# 0   10   20   30   40   50   60   70  56  56  56  1
# 1  100  200  300  400  500  600  700  78  78  66  2

# %%
df['Y'] = pd.Series([1,2,3,4],index=["A","B","C","D"]) # Here it will give NaN value to Y because index are not matched as index are 0,1...

# %%
df
# Out:
#      A    B    C    D    E    F    G   H   M   N  Z   Y
# 0   10   20   30   40   50   60   70  56  56  56  1 NaN
# 1  100  200  300  400  500  600  700  78  78  66  2 NaN

# %% [markdown]
# 3. Delete a column

# %%
df
# Out:
#      A    B    C    D    E    F    G   H   M   N  Z   Y
# 0   10   20   30   40   50   60   70  56  56  56  1 NaN
# 1  100  200  300  400  500  600  700  78  78  66  2 NaN

# %%
# DEL Keyword
del df['G']

# %%
df
# Out:
#      A    B    C    D    E    F   H   M   N  Z   Y
# 0   10   20   30   40   50   60  56  56  56  1 NaN
# 1  100  200  300  400  500  600  78  78  66  2 NaN

# %%
# Pop function
df.pop('Z')
# Out:
# 0    1
# 1    2
# Name: Z, dtype: int64

# %%
df
# Out:
#      A    B    C    D    E    F   H   M   N   Y
# 0   10   20   30   40   50   60  56  56  56 NaN
# 1  100  200  300  400  500  600  78  78  66 NaN

# %%
df['C']
# Out:
# 0     30
# 1    300
# Name: C, dtype: int64

# %%
df[['C']]
# Out:
#      C
# 0   30
# 1  300

# %%
df[['E','A','N']]
# Out:
#      E    A   N
# 0   50   10  56
# 1  500  100  66

# %%
df['E','A','N'] # It will throw error because in this format we can only have one dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('E', 'A', 'N')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-d83279295623> in <module>()
# ...

# %%
df
# Out:
#      A    B    C    D    E    F   H   M   N   Y
# 0   10   20   30   40   50   60  56  56  56 NaN
# 1  100  200  300  400  500  600  78  78  66 NaN

# %%
del df['D','Y'] # we can only delete single column at once hence this will throw an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('D', 'Y')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 del df['D','Y']
#
# ...

# %%
df.pop(["D","Y"]) # it has same functionality as del so will only delete one column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['D', 'Y']' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.pop(["D","Y"])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5573, in DataFrame.pop(self, item)
#    5532 def pop(self, item: Hashable) -> Series:
#    5533     """
# ...

# %%
df.pop("D","Y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.pop("D","Y")
#
# TypeError: DataFrame.pop() takes 2 positional arguments but 3 were given

# %%
# drop() difference is del and pop willl delete permanantly whereas drop will delete temporary
#df.drop(["D","Y"]) # this will be unable to find axis
df.drop(["D","Y"],axis=1) # here when we use axis then it is permanant delete
# Out:
#      A    B    C    E    F   H   M   N
# 0   10   20   30   50   60  56  56  56
# 1  100  200  300  500  600  78  78  66

# %%
df
# Out:
#      A    B    C    D    E    F   H   M   N   Y
# 0   10   20   30   40   50   60  56  56  56 NaN
# 1  100  200  300  400  500  600  78  78  66 NaN

# %%
df["P"] = df["E"] + df["N"]
# 0 -> Null, Void, NaN

# %%
df
# Out:
#      A    B    C    D    E    F   H   M   N   Y    P
# 0   10   20   30   40   50   60  56  56  56 NaN  106
# 1  100  200  300  400  500  600  78  78  66 NaN  566

# %%
df["P"] + df["N"] # It will create NaN because anything added with NaN is NaN itself. Don't confuse it with 0. NaN is not any number
# Out:
# 0    162
# 1    632
# dtype: int64

# %%
df
# Out:
#      A    B    C    D    E    F   H   M   N   Y    P
# 0   10   20   30   40   50   60  56  56  56 NaN  106
# 1  100  200  300  400  500  600  78  78  66 NaN  566

# %%
df1 = [{"A":45,"B":98,"P":104}] # this is data and not dataframe

# %%
df = df.append(df1,index="Hey")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-175fc62b6eca> in <module>()
# ----> 1 df = df.append(df1,index="Hey")
#
# TypeError: append() got an unexpected keyword argument 'index'

# %%
df
# Out:
#      A    B      C      D      E      F     H     M     N   Y      P
# 0   10   20   30.0   40.0   50.0   60.0  56.0  56.0  56.0 NaN  106.0
# 1  100  200  300.0  400.0  500.0  600.0  78.0  78.0   NaN NaN    NaN
# 0   45   98    NaN    NaN    NaN    NaN   NaN   NaN   NaN NaN  104.0

# %%
df = pd.DataFrame(df1)

# %%
df["hello"] = 130

# %%
df
# Out:
#     A   B    P  hello
# 0  45  98  104    130

# %%
# df.insert(location, name_of_column, data)

# %%
df.insert(2,"bbye",[100])

# %%
df
# Out:
#     A   B  bbye    P  hello
# 0  45  98   100  104    130

# %%
df.insert(2,"bank",200,300)

# %%
df
# Out:
#     A   B  bank  bbye    P  hello
# 0  45  98   200   100  104    130
