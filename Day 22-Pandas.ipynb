# %% [markdown]
# # Pandas - Data Manipulation Tool
#
# * It's a Python Library that is used while you are working with the datasets
# * It has some function
# 1. Analyze
# 2. Cleaning
# 3. Explore
# 4. Manipulation

# %% [markdown]
# # Why Pandas?
#
# * It allows us to analyze big datas
# * It is used to clean messy datasets and then make it readable and relevant

# %%
MS Excel -> 10million
insta.xlxs # data of instagram which contain 100 trillion of datapoints cant be done by Excel

# %%
# university.csv Naive Bayes. ML revolves around Accuracy 75%
# university.csv cleaning will cause: 30days or 2 months or more than that 
# Random Forest Regressor Accuracy 89% 5-10 min
# datsets -> table(Row & Column)
# datapoint -> particular row

# %% [markdown]
# # Importation of Pandas
# * Library is collection of Packages
# * Packages is collection of Modules

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.1'

# %% [markdown]
# # Pandas Data Structure stands for Panel Datas
# Here DataFrame is very imp
#
# 1. Series -> CRUD. It has only one axis i.e. column
# 2. Dataframe -> CRUD #This is only required in Data Analytics. It is of 2-D rows and columns
# 3. Panel -> Is is of 3D. But we dont use Panel bcz graphical representation is very difficult
#
# Pandas DS are very fast because the DS are built on top of the NumPy array.

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])

# %%
a.shape # it is 1D but shape is 4
# Out:
# (4,)

# %% [markdown]
# # Series
#
# 1. It is a 1D array like DS
# 2. [1,2,3,4,5,6,7,8] -> column

# %%
SYNTAX: pd.Series(data, index, dtype)

# %%
# You can create a series by using various input datas such as
1. Array
2. Dict
3. Scalar Value

# %% [markdown]
# * Creating an empty series

# %%
s = pd.Series()

# %%
s
# Out:
# Series([], dtype: object)

# %% [markdown]
# * Creating a series using Numpy Array
# First create data then only series can be made

# %%
data = np.array([12,45,32,89])
s = pd.Series(data)

# %%
s # Here 0,1,2,3 are index values. We will access any row in pandas using index and column with its column value
# Out:
# 0    12
# 1    45
# 2    32
# 3    89
# dtype: int32

# %%
data = np.array([12,45,32,89])
s = pd.Series(data,index=[101,102,103,104])

# %%
s
# Out:
# 101    12
# 102    45
# 103    32
# 104    89
# dtype: int32

# %% [markdown]
# * Creating a series using dictionary

# %%
data = {"a":10, "b":40, "c":90, "d":95}
s = pd.Series(data,index=["c","d","e","b","a"])

# %%
s
# Out:
# c    90.0
# d    95.0
# e     NaN
# b    40.0
# a    10.0
# dtype: float64

# %% [markdown]
# * Creating a series using the scalar value

# %%
data = 99
s = pd.Series(data, index=[101,102,103,104])

# %%
s
# Out:
# 101    99
# 102    99
# 103    99
# 104    99
# dtype: int64

# %% [markdown]
# * U - Updation
#
# 1. Accessing the data from the Pandas series DS

# %%
data = np.array([12,45,32,89,7,-10,21,-0.5,-7,30])
s = pd.Series(data)

# %%
s
# Out:
# 0    12.0
# 1    45.0
# 2    32.0
# 3    89.0
# 4     7.0
# 5   -10.0
# 6    21.0
# 7    -0.5
# 8    -7.0
# 9    30.0
# dtype: float64

# %%
s[:3] # accessing the data till 3 means 0,1,2
# Out:
# 0    12.0
# 1    45.0
# 2    32.0
# dtype: float64

# %%
s[4:7]
# Out:
# 4     7.0
# 5   -10.0
# 6    21.0
# dtype: float64

# %%
s[7:]
# s[-3:]
# Out:
# 7    -0.5
# 8    -7.0
# 9    30.0
# dtype: float64

# %%
data = {"a":10, "b":40, "c":90, "d":95}
s = pd.Series(data,index=["c","d","e","b","a"])

# %%
s[["c",'b']]
# Out:
# c    90.0
# b    40.0
# dtype: float64

# %%
s
# 85.5
# Out:
# c    90.0
# d    95.0
# e     NaN
# b    40.0
# a    10.0
# dtype: float64

# %%
s['e']=85.5

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# a    10.0
# dtype: float64

# %% [markdown]
# * Boolean Masking

# %%
0 - False
1 - True

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# a    10.0
# dtype: float64

# %%
s[s>50]
# Out:
# c    90.0
# d    95.0
# e    85.5
# dtype: float64

# %%
# Task & Quizzes
# error
# s[s>90 or s==10]
# Output
s[(s > 90) | (s == 10)]
# Out:
# d    95.0
# a    10.0
# dtype: float64

# %%
s.shape

# 4,1
# 5,
# 5,1
# 4,

# NaN 0
# Out:
# (5,)

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# a    10.0
# dtype: float64

# %%
s.ndim
# Out:
# 1

# %%
s.size
# Out:
# 5

# %%
s.index
# Out:
# Index(['c', 'd', 'e', 'b', 'a'], dtype='object')

# %%
s.values
# Decimal - 6987.
# Double - 5.6
# Float - 5.68888888
# Out:
# array([90. , 95. , 85.5, 40. , 10. ])

# %%
10
10.
# Out:
# 10.0

# %%
"10.0" in s #it will be false as it is string
10.0 in s #  #it will be again false as it takes through index
# Out:
# False

# %%
'a' in s
# Out:
# True

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# a    10.0
# dtype: float64

# %% [markdown]
# * Deleting with refference to index in pandas

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# a    10.0
# dtype: float64

# %%
#s.drop(['c',"e"])  this is temporary delete but wont effect in original series
# s.drop('a', inplace=True)
s.drop(['c',"e"], inplace=True)

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# dtype: float64

# %%
s+2
# Out:
# c    92.0
# d    97.0
# e    87.5
# b    42.0
# dtype: float64

# %%
s-2
# Out:
# c    88.0
# d    93.0
# e    83.5
# b    38.0
# dtype: float64

# %%
s*2
# Out:
# c    180.0
# d    190.0
# e    171.0
# b     80.0
# dtype: float64

# %%
s/10
# Out:
# c    9.00
# d    9.50
# e    8.55
# b    4.00
# dtype: float64

# %%
np.power(s,2)
# Out:
# c    8100.00
# d    9025.00
# e    7310.25
# b    1600.00
# dtype: float64

# %%
s**2
# Out:
# c    8100.00
# d    9025.00
# e    7310.25
# b    1600.00
# dtype: float64

# %%
np.exp(s)
# Out:
# c    1.220403e+39
# d    1.811239e+41
# e    1.355746e+37
# b    2.353853e+17
# dtype: float64

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# dtype: float64

# %%
s['e']-10
# Out:
# 75.5

# %%
s
# Out:
# c    90.0
# d    95.0
# e    85.5
# b    40.0
# dtype: float64

# %%
import re

# %%
stri=input("enter a string: ")
vali=re.match("ab*",stri)
if vali:
  print("valid")
else:
  print("invalid")

# a ab abb abbbb
# b ba baba
# Out:
# enter a string: a
# invalid

# %%
import re
inp = input("Enter any string: ")
def check_me():
  patterns = 'ab*'
  if re.search(patterns, inp):
    print("yes, matched")
  else:
    return('Not matched!')

check_me()

# %%
def pat():
#str=input("enter any string!")
  stri=input("enter any string!:")
  pattern="ab*?"
  if re.findall(pattern,stri):
    print("matched")
  else:
    print("no match")

# %%
pat()
# Out:
# enter any string!:baba
# matched

# %%
word= input("Mention the required word: ")
need= re.match("ab.*",word)
if need:
  print("Yes! The criteria is matched.")
else:
  print("Sorry but the criteria didn't match.")
# Out:
# Mention the required word: a
# Yes! The criteria is matched.

# %%
babab

# %%
def email_validator(mail):
  if len(mail)<=100:
    valid=re.match("[\w]+@[a-z]{3,6}[.][a-z]{3,5}$",mail)
    if valid:
      print("Valid email")
    else:
      print("Invalid email")
mail=input("Enter email: ")
email_validator(mail)
# Out:
# Enter email: !@##$$$%%.#$$$
# Invalid email

# %%
raw_data = "0--1--1---9--9--9--9--9--9--9--9--9--9"
asd = re.sub('--','',raw_data)
print(asd)
# Out:
# 011-9999999999

# %%
raw_data = "0--1--1-a9-b9-c9-d9-e9-f9-g9-h9-i9-j9"
data_pr = re.findall("\d",raw_data)
data_out = "".join(data_pr[:3])+"-"+"".join(data_pr[3:])
print(data_out)
# Out:
# 011-9999999999

# %%
rd = "0--1--1-a9-b9-c9-d9-e9-f9-g9-h9-i9-j9"
d=re.findall('\d',rd)
o=''
count=0
for i in d:
  if count==3:
    o+='-'
  else:
    o+=i
  count+=1
print(o)
# Out:
# 011-999999999

# %%
raw_data = "0--1--1-a9-b9-c9-d9-e9-f9-g9-h9-i9-j9"
''.join(re.split("--|a|-b|-c|-d|-e|-f|-g|-h|-i|-j",raw_data))
# Out:
# '011-9999999999'

# %%
lisi = ['<li><a href="/wiki/Robert_Downey_Jr." title="Robert Downey Jr."></a></li>',
'<li><a href="/wiki/Chris_Evans" title="Chris Evans"></a></li>',
'<li><a href="/wiki/Mark_Ruffalo" title="Mark Ruffalo"></a></li>',
'<li><a href="/wiki/Chris_Hemsworth" title="Chris Hemsworth"></a></li>',
'<li><a href="/wiki/Scarlett_Johansson" title="Scarlett Johansson"></a></li>',
'<li><a href="/wiki/Jeremy_Renner" title="Jeremy Renner"></a></li>',
'<li><a href="/wiki/Don_Cheadle" title="Don Cheadle"></a></li>',
'<li><a href="/wiki/Paul_Rudd" title="Paul Rudd"></a></li>',
'<li><a href="/wiki/Brie_Larson" title="Brie Larson"></a></li>',
'<li><a href="/wiki/Karen_Gillan" title="Karen Gillan"></a></li>',
'<li><a href="/wiki/Danai_Gurira" title="Danai Gurira"></a></li>',
'<li><a href="/wiki/Benedict_Wong" title="Benedict Wong"></a></li>',
'<li><a href="/wiki/Jon_Favreau" title="Jon Favreau"></a></li>',
'<li><a href="/wiki/Bradley_Cooper" title="Bradley Cooper"></a></li>',
'<li><a href="/wiki/Gwyneth_Paltrow" title="Gwyneth Paltrow"></a></li>',
'<li><a href="/wiki/Josh_Brolin" title="Josh Brolin"></a></li></ul>']

name = []
title = []

for i in lisi:
  i = re.sub('<li><a href="/wiki/|title=|></a></li>|</ul>|"',"",i)
  i = re.split(" ",i)
  name.append(re.sub("_"," ",i[0]))
  title.append(" ".join(i[1:]))

# %%
name
# Out:
# ['Robert Downey Jr.',
#  'Chris Evans',
#  'Mark Ruffalo',
#  'Chris Hemsworth',
#  'Scarlett Johansson',
#  'Jeremy Renner',
#  'Don Cheadle',
#  'Paul Rudd',
#  'Brie Larson',
#  'Karen Gillan',
#  'Danai Gurira',
#  'Benedict Wong',
#  'Jon Favreau',
#  'Bradley Cooper',
#  'Gwyneth Paltrow',
#  'Josh Brolin']

# %%
title
# Out:
# ['Robert Downey Jr.',
#  'Chris Evans',
#  'Mark Ruffalo',
#  'Chris Hemsworth',
#  'Scarlett Johansson',
#  'Jeremy Renner',
#  'Don Cheadle',
#  'Paul Rudd',
#  'Brie Larson',
#  'Karen Gillan',
#  'Danai Gurira',
#  'Benedict Wong',
#  'Jon Favreau',
#  'Bradley Cooper',
#  'Gwyneth Paltrow',
#  'Josh Brolin']
