# %% [markdown]
# # Project 4
#
# Dataset (JSON): https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json
#
# Categories Dataset: https://raw.githubusercontent.com/AliasIO/wappalyzer/master/src/technologies.json

# %% [markdown]
# * Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
tech = pd.read_json('https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json')
cats = pd.read_json('https://raw.githubusercontent.com/AliasIO/wappalyzer/master/src/technologies.json')

# %%
data_tech = tech.copy()
data_cats = cats.copy()

# %%
data_tech.head()

# %% [markdown]
# 1. Manipulate the DataFrame in such a way that the column becomes the row and vice-versa

# %%
data_tech = data_tech.T

# %%
data_tech.head()
# Out:
#              cats  ...  css
# 1C-Bitrix  [1, 6]  ...  NaN
# 3dCart     [1, 6]  ...  NaN
# @sulu/web    [59]  ...  NaN
# A-Frame      [25]  ...  NaN
# A8.net       [71]  ...  NaN
#
# [5 rows x 21 columns]

# %%
data_tech.info()

# %%
data_tech.shape
# Out:
# (1511, 21)

# %%
data_tech.columns
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %%
data_cats.head(6)
# Out:
#           $schema                                    categories technologies
# 1  ../schema.json                {'name': 'CMS', 'priority': 1}          NaN
# 2  ../schema.json     {'name': 'Message boards', 'priority': 1}          NaN
# 3  ../schema.json  {'name': 'Database managers', 'priority': 2}          NaN
# 4  ../schema.json      {'name': 'Documentation', 'priority': 2}          NaN
# 5  ../schema.json            {'name': 'Widgets', 'priority': 9}          NaN
# 6  ../schema.json          {'name': 'Ecommerce', 'priority': 1}          NaN

# %%
tec = data_tech.copy()
cat = data_cats.copy()

# %%
for i in tec.cats:
  for j in range(len(i)):
   i[j] = cat.categories.iloc[(i[j]-1)]["name"]

# %%
tec.headers.notnull().sum()
# Out:
# 320

# %%
tec.headers[]
# Out:
# nan

# %%
for i in range(len(tec.headers)):
  try:
    key=tec.headers[i].keys()
    print(list(key))
  except:
    pass

# %%
for i in tec.headers:
  print(i)

# %%
pd.isnull(tec.headers[2])
# Out:
# True

# %%
arr = []
for i in range(len(tec.headers)):
  if not pd.isnull(tec.headers[i]):
    arr.extend(list(tec.headers[i].keys()))

# %%
arr = set(arr)

# %%
len(arr)
# Out:
# 185

# %%
l=[]
for i in data_tech.headers:
  if type(i)==dict:
    x=list(i.keys())
    for j in x:
      if j not in l:
        l.append(j)

l

# %%
len(l)
# Out:
# 185

# %%
tec
# Out:
#                              cats  ...  css
# 1C-Bitrix        [CMS, Ecommerce]  ...  NaN
# 3dCart           [CMS, Ecommerce]  ...  NaN
# @sulu/web                  [PaaS]  ...  NaN
# A-Frame     [JavaScript graphics]  ...  NaN
# A8.net              [A/B Testing]  ...  NaN
# ...                           ...  ...  ...
# wisyCMS                     [CMS]  ...  NaN
# wpBakery                    [CRM]  ...  NaN
# wpCache                 [Caching]  ...  NaN
# xCharts     [JavaScript graphics]  ...  NaN
# xtCommerce            [Ecommerce]  ...  NaN
#
# [1511 rows x 21 columns]

# %%
https://amazon.in

# %%
url = "https://en.wikipedia.org/wiki/Avengers:_Endgame"
# url = 'www.youtube.com/watch?v=hnVOvvbQrwA'

# %%
regex = "https://"+re.sub('.*//|/.*|www\.','',url)
regex
# Out:
# 'https://en.wikipedia.org'

# %%
re.sub('.*//|/.*|www\.','',url)
# Out:
# 'en.wikipedia.org'

# %%
from bs4 import BeautifulSoup
import requests

# %%
req = requests.get(regex)

# %%
req.headers
# Out:
# {'Date': 'Sat, 14 Aug 2021 15:14:25 GMT', 'Server': 'mw2408.codfw.wmnet', 'X-Content-Type-Options': 'nosniff', 'P3p': 'CP="See https://en.wikipedia.org/wiki/Special:CentralAutoLogin/P3P for more info."', 'Content-Language': 'en', 'Vary': 'Accept-Encoding,Cookie,Authorization', 'Last-Modified': 'Sat, 14 Aug 2021 15:14:21 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Encoding': 'gzip', 'Age': '1003', 'X-Cache': 'cp1089 miss, cp1087 hit/1558', 'X-Cache-Status': 'hit-front', 'Server-Timing': 'cache;desc="hit-front", host;desc="cp1087"', 'Strict-Transport-Security': 'max-age=106384710; includeSubDomains; preload', 'Report-To': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'NEL': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'Permissions-Policy': 'interest-cohort=()', 'X-Client-IP': '34.73.110.238', 'Cache-Control': 'private, s-maxage=0, max-age=0, must-revalidate', 'Accept-Ranges': 'bytes', 'Content-Length': '19678', 'Connection': 'keep-alive'}

# %%
req.cookies.get_dict().keys()
# Out:
# dict_keys([])

# %%
soup = BeautifulSoup(req.content)

# %%
soup

# %%
tec
