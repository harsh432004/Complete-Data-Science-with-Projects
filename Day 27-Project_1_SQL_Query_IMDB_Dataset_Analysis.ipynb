# %% [markdown]
# # Dataset: '/content/drive/MyDrive/Datasets/movies.sqlite'

# %% [markdown]
# Here is the link to download the dataset: https://www.kaggle.com/code/harshsachinvaidya/imdb-sqlite
# After that create a folder and upload it on goggle drive. then perform the following steps:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #this will connect your google drive with collab then just find the folder in files section in collab.
# # You can also follow this video for refference: https://youtu.be/z1pBdycYCGY?si=PMpaKM6BgCyLOc4b

# %% [markdown]
# # Importing the libraries

# %%
# NumPy -> To perform the Mathematical operations
import numpy as np

# Pandas -> Data Manipulation tool
import pandas as pd

# Matplotlib -> Data Visualisation tool
import matplotlib.pyplot as plt

# Seaborn -> Data Visualisation tool
import seaborn as sns

# SQLite -> Server-less Database
import sqlite3

# %% [markdown]
# # Hints & Tips

# %% [markdown]
# # Hints
# 1. Connect your database (or create a connection) -> sqlite3.connect(database_name)
# 2. Use the cursor function -> database_variable.cursor()
#
#
# # Complete workflow Workflow
# 1. You need to establish a connection to the SQLite database by creating a Connection object
# 2. Then, you have to create a Cursor object using the cursor() method
# 3. Then, excute the query -> cursor_object.execute('query')
# 4. To fetch the data, then use fetchall() method of the cursor object

# %% [markdown]
# 1. Establishing the connection to the database

# %%
db = '/content/gdrive/MyDrive/Dataset/movie.sqlite'
conn = sqlite3.connect(db)
cur = conn.cursor()

# %% [markdown]
# 2. Get all the data about movies?

# %%
# Fetching the data of the Movies table from the Database
cur.execute("SELECT * FROM movies")
# Creating the cursor object
movies = cur.fetchall() # Here cur means cursor

# %%
# Displaying the database data
movies
# Out:
# [(43597,
#   'Avatar',
#   237000000,
#   150,
#   '2009-12-10',
#   2787965087,
#   'Avatar',
#   7.2,
#   11800,
#   'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#   'Enter the World of Pandora.',
#   19995,
#   4762),
#  (43598,
#   "Pirates of the Caribbean: At World's End",
#   300000000,
#   139,
#   '2007-05-19',
#   961000000,
#   "Pirates of the Caribbean: At World's End",
#   6.9,
#   4500,
#   'Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.',
#   'At the end of the world, the adventure begins.',
#   285,
#   4763),
#  (43599,
#   'Spectre',
#   245000000,
#   107,
#   '2015-10-26',
#   880674609,
#   'Spectre',
#   6.3,
#   4466,
#   'A cryptic message from Bond’s past sends him on a trail to uncover a sinister organization. While M battles political forces to keep the secret service alive, Bond peels back the layers of deceit to reveal the terrible truth behind SPECTRE.',
#   'A Plan No One Escapes',
#   206647,
#   4764),
#  (43600,
#   'The Dark Knight Rises',
#   250000000,
#   112,
#   '2012-07-16',
#   1084939099,
#   'The Dark Knight Rises',
#   7.6,
#   9106,
#   "Following the death of District Attorney Harvey Dent, Batman assumes responsibility for Dent's crimes to protect the late attorney's reputation and is subsequently hunted by the Gotham City Police Department. Eight years later, Batman encounters the mysterious Selina Kyle and the villainous Bane, a new terrorist leader who overwhelms Gotham's finest. The Dark Knight resurfaces to protect a city that has branded him an enemy.",
#   'The Legend Ends',
#   49026,
#   4765),
#  (43601,
#   'John Carter',
#   260000000,
#   43,
#   '2012-03-07',
#   284139100,
#   'John Carter',
#   6.1,
#   2124,
#   "John Carter is a war-weary, former military captain who's inexplicably transported to the mysterious and exotic planet of Barsoom (Mars) and reluctantly becomes embroiled in an epic conflict. It's a world on the brink of collapse, and Carter rediscovers his humanity when he realizes the survival of Barsoom and its people rests in his hands.",
#   'Lost in our world, found in another.',
#   49529,
#   4766),
#  (43602,
#   'Spider-Man 3',
#   258000000,
#   115,
#   '2007-05-01',
#   890871626,
#   'Spider-Man 3',
#   5.9,
#   3576,
#   'The seemingly invincible Spider-Man goes up against an all-new crop of villain – including the shape-shifting Sandman. While Spider-Man’s superpowers are altered by an alien organism, his alter ego, Peter Parker, deals with nemesis Eddie Brock and also gets caught up in a love triangle.',
#   'The battle within.',
#   559,
#   4767),
#  (43603,
#   'Tangled',
#   260000000,
#   48,
#   '2010-11-24',
#   591794936,
#   'Tangled',
#   7.4,
#   3330,
#   "When the kingdom's most wanted-and most charming-bandit Flynn Rider hides out in a mysterious tower, he's taken hostage by Rapunzel, a beautiful and feisty tower-bound teen with 70 feet of magical, golden hair. Flynn's curious captor, who's looking for her ticket out of the tower where she's been locked away for years, strikes a deal with the handsome thief and the unlikely duo sets off on an action-packed escapade, complete with a super-cop horse, an over-protective chameleon and a gruff gang of pub thugs.",
#   "They're taking adventure to new lengths.",
#   38757,
#   4768),
#  (43604,
#   'Avengers: Age of Ultron',
#   280000000,
#   134,
#   '2015-04-22',
#   1405403694,
#   'Avengers: Age of Ultron',
#   7.3,
#   6767,
#   'When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.',
#   'A New Age Has Come.',
#   99861,
#   4769),
#  (43605,
#   'Harry Potter and the Half-Blood Prince',
#   250000000,
#   98,
#   '2009-07-07',
#   933959197,
#   'Harry Potter and the Half-Blood Prince',
#   7.4,
#   5293,
#   "As Harry begins his sixth year at Hogwarts, he discovers an old book marked as 'Property of the Half-Blood Prince', and begins to learn more about Lord Voldemort's dark past.",
#   'Dark Secrets Revealed',
#   767,
#   4770),
#  (43606,
#   'Batman v Superman: Dawn of Justice',
#   250000000,
#   155,
#   '2016-03-23',
#   873260194,
#   'Batman v Superman: Dawn of Justice',
#   5.7,
#   7004,
#   'Fearing the actions of a god-like Super Hero left unchecked, Gotham City’s own formidable, forceful vigilante takes on Metropolis’s most revered, modern-day savior, while the world wrestles with what sort of hero it really needs. And with Batman and Superman at war with one another, a new threat quickly arises, putting mankind in greater danger than it’s ever known before.',
#   'Justice or revenge',
#   209112,
#   4771),
#  (43607,
#   'Superman Returns',
#   270000000,
#   57,
#   '2006-06-28',
#   391081192,
#   'Superman Returns',
#   5.4,
#   1400,
#   'Superman returns to discover his 5-year absence has allowed Lex Luthor to walk free, and that those he was closest too felt abandoned and have moved on. Luthor plots his ultimate revenge that could see millions killed and change the face of the planet forever, as well as ridding himself of the Man of Steel.',
#   None,
#   1452,
#   4772),
#  (43608,
#   'Quantum of Solace',
#   200000000,
#   107,
#   '2008-10-30',
#   586090727,
#   'Quantum of Solace',
#   6.1,
#   2965,
#   'Quantum of Solace continues the adventures of James Bond after Casino Royale. Betrayed by Vesper, the woman he loved, 007 fights the urge to make his latest mission personal. Pursuing his determination to uncover the truth, Bond and M interrogate Mr. White, who reveals that the organization that blackmailed Vesper is far more complex and dangerous than anyone had imagined.',
#   'For love, for hate, for justice, for revenge.',
#   10764,
#   4773),
#  (43609,
#   "Pirates of the Caribbean: Dead Man's Chest",
#   200000000,
#   145,
#   '2006-06-20',
#   1065659812,
#   "Pirates of the Caribbean: Dead Man's Chest",
#   7.0,
#   5246,
#   'Captain Jack Sparrow works his way out of a blood debt with the ghostly Davey Jones, he also attempts to avoid eternal damnation.',
#   'Jack is back!',
#   58,
#   4763),
#  (43610,
#   'The Lone Ranger',
#   255000000,
#   49,
#   '2013-07-03',
#   89289910,
#   'The Lone Ranger',
#   5.9,
#   2311,
#   'The Texas Rangers chase down a gang of outlaws led by Butch Cavendish, but the gang ambushes the Rangers, seemingly killing them all. One survivor is found, however, by an American Indian named Tonto, who nurses him back to health. The Ranger, donning a mask and riding a white stallion named Silver, teams up with Tonto to bring the unscrupulous gang and others of that ilk to justice.',
#   'Never Take Off the Mask',
#   57201,
#   4763),
#  (43611,
#   'Man of Steel',
#   225000000,
#   99,
#   '2013-06-12',
#   662845518,
#   'Man of Steel',
#   6.5,
#   6359,
#   'A young boy learns that he has extraordinary powers and is not of this earth. As a young man, he journeys to discover where he came from and what he was sent here to do. But the hero in him must emerge if he is to save the world from annihilation and become the symbol of hope for all mankind.',
#   'You will believe that a man can fly.',
#   49521,
#   4771),
#  (43612,
#   'The Chronicles of Narnia: Prince Caspian',
#   225000000,
#   53,
#   '2008-05-15',
#   419651413,
#   'The Chronicles of Narnia: Prince Caspian',
#   6.3,
#   1630,
#   'One year after their incredible adventures in the Lion, the Witch and the Wardrobe, Peter, Edmund, Lucy and Susan Pevensie return to Narnia to aid a young prince whose life has been threatened by the evil King Miraz. Now, with the help of a colorful cast of new characters, including Trufflehunter the badger and Nikabrik the dwarf, the Pevensie clan embarks on an incredible quest to ensure that Narnia is returned to its rightful heir.',
#   'Hope has a new face.',
#   2454,
#   4774),
#  (43613,
#   'The Avengers',
#   220000000,
#   144,
#   '2012-04-25',
#   1519557910,
#   'The Avengers',
#   7.4,
#   11776,
#   'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#   'Some assembly required.',
#   24428,
#   4769),
#  (43614,
#   'Pirates of the Caribbean: On Stranger Tides',
#   380000000,
#   135,
#   '2011-05-14',
#   1045713802,
#   'Pirates of the Caribbean: On Stranger Tides',
#   6.4,
#   4948,
#   "Captain Jack Sparrow crosses paths with a woman from his past, and he's not sure if it's love -- or if she's a ruthless con artist who's using him to find the fabled Fountain of Youth. When she forces him aboard the Queen Anne's Revenge, the ship of the formidable pirate Blackbeard, Jack finds himself on an unexpected adventure in which he doesn't know who to fear more: Blackbeard or the woman from his past.",
#   'Live Forever Or Die Trying.',
#   1865,
#   4775),
#  (43615,
#   'Men in Black 3',
#   225000000,
#   52,
#   '2012-05-23',
#   624026776,
#   'Men in Black 3',
#   6.2,
#   4160,
#   "Agents J (Will Smith) and K (Tommy Lee Jones) are back...in time. J has seen some inexplicable things in his 15 years with the Men in Black, but nothing, not even aliens, perplexes him as much as his wry, reticent partner. But when K's life and the fate of the planet are put at stake, Agent J will have to travel back in time to put things right. J discovers that there are secrets to the universe that K never told him - secrets that will reveal themselves as he teams up with the young Agent K (Josh Brolin) to save his partner, the agency, and the future of humankind.",
#   'They are back... in time.',
#   41154,
#   4776),
#  (43616,
#   'The Hobbit: The Battle of the Five Armies',
#   250000000,
#   120,
#   '2014-12-10',
#   956019788,
#   'The Hobbit: The Battle of the Five Armies',
#   7.1,
#   4760,
#   "Immediately after the events of The Desolation of Smaug, Bilbo and the dwarves try to defend Erebor's mountain of treasure from others who claim it: the men of the ruined Laketown and the elves of Mirkwood. Meanwhile an army of Orcs led by Azog the Defiler is marching on Erebor, fueled by the rise of the dark lord Sauron. Dwarves, elves and men must unite, and the hope for Middle-Earth falls into Bilbo's hands.",
#   'Witness the defining chapter of the Middle-Earth saga',
#   122917,
#   4777),
#  (43617,
#   'The Amazing Spider-Man',
#   215000000,
#   89,
#   '2012-06-27',
#   752215857,
#   'The Amazing Spider-Man',
#   6.5,
#   6586,
#   "Peter Parker is an outcast high schooler abandoned by his parents as a boy, leaving him to be raised by his Uncle Ben and Aunt May. Like most teenagers, Peter is trying to figure out who he is and how he got to be the person he is today. As Peter discovers a mysterious briefcase that belonged to his father, he begins a quest to understand his parents' disappearance – leading him directly to Oscorp and the lab of Dr. Curt Connors, his father's former partner. As Spider-Man is set on a collision course with Connors' alter ego, The Lizard, Peter will make life-altering choices to use his powers and shape his destiny to become a hero.",
#   'The untold story begins.',
#   1930,
#   4778),
#  (43618,
#   'Robin Hood',
#   200000000,
#   37,
#   '2010-05-12',
#   310669540,
#   'Robin Hood',
#   6.2,
#   1398,
#   "When soldier Robin happens upon the dying Robert of Loxley, he promises to return the man's sword to his family in Nottingham. There, he assumes Robert's identity; romances his widow, Marion; and draws the ire of the town's sheriff and King John's henchman, Godfrey.",
#   'Rise and rise again, until lambs become lions.',
#   20662,
#   4779),
#  (43619,
#   'The Hobbit: The Desolation of Smaug',
#   250000000,
#   94,
#   '2013-12-11',
#   958400000,
#   'The Hobbit: The Desolation of Smaug',
#   7.6,
#   4524,
#   'The Dwarves, Bilbo and Gandalf have successfully escaped the Misty Mountains, and Bilbo has gained the One Ring. They all continue their journey to get their gold back from the Dragon, Smaug.',
#   'Beyond darkness... beyond desolation... lies the greatest danger of all.',
#   57158,
#   4777),
#  (43620,
#   'The Golden Compass',
#   180000000,
#   42,
#   '2007-12-04',
#   372234864,
#   'The Golden Compass',
#   5.8,
#   1303,
#   "After overhearing a shocking secret, precocious orphan Lyra Belacqua trades her carefree existence roaming the halls of Jordan College for an otherworldly adventure in the far North, unaware that it's part of her destiny.",
#   'There are worlds beyond our own - the compass will show the way.',
#   2268,
#   4780),
#  (43621,
#   'King Kong',
#   207000000,
#   61,
#   '2005-12-14',
#   550000000,
#   'King Kong',
#   6.6,
#   2337,
#   'In 1933 New York, an overly ambitious movie producer coerces his cast and hired ship crew to travel to mysterious Skull Island, where they encounter Kong, a giant ape who is immediately smitten with the leading lady.',
#   'The eighth wonder of the world.',
#   254,
#   4777),
#  (43622,
#   'Titanic',
#   200000000,
#   100,
#   '1997-11-18',
#   1845034188,
#   'Titanic',
#   7.5,
#   7562,
#   '84 years later, a 101-year-old woman named Rose DeWitt Bukater tells the story to her granddaughter Lizzy Calvert, Brock Lovett, Lewis Bodine, Bobby Buell and Anatoly Mikailavich on the Keldysh about her life set in April 10th 1912, on a ship called Titanic when young Rose boards the departing ship with the upper-class passengers and her mother, Ruth DeWitt Bukater, and her fiancé, Caledon Hockley. Meanwhile, a drifter and artist named Jack Dawson and his best friend Fabrizio De Rossi win third-class tickets to the ship in a game. And she explains the whole story from departure until the death of Titanic on its first and last voyage April 15th, 1912 at 2:20 in the morning.',
#   'Nothing on Earth could come between them.',
#   597,
#   4762),
#  (43623,
#   'Captain America: Civil War',
#   250000000,
#   198,
#   '2016-04-27',
#   1153304495,
#   'Captain America: Civil War',
#   7.1,
#   7241,
#   'Following the events of Age of Ultron, the collective governments of the world pass an act designed to regulate all superhuman activity. This polarizes opinion amongst the Avengers, causing two factions to side with Iron Man or Captain America, which causes an epic battle between former allies.',
#   'Divided We Fall',
#   271110,
#   4781),
#  (43624,
#   'Battleship',
#   209000000,
#   64,
#   '2012-04-11',
#   303025485,
#   'Battleship',
#   5.5,
#   2114,
#   "When mankind beams a radio signal into space, a reply comes from ‘Planet G’, in the form of several alien crafts that splash down in the waters off Hawaii. Lieutenant Alex Hopper is a weapons officer assigned to the USS John Paul Jones, part of an international naval coalition which becomes the world's last hope for survival as they engage the hostile alien force of unimaginable strength. While taking on the invaders, Hopper must also try to live up to the potential his brother, and his fiancée's father, Admiral Shane, expect of him.",
#   'The Battle for Earth Begins at Sea',
#   44833,
#   4782),
#  (43625,
#   'Jurassic World',
#   150000000,
#   418,
#   '2015-06-09',
#   1513528810,
#   'Jurassic World',
#   6.5,
#   8662,
#   'Twenty-two years after the events of Jurassic Park, Isla Nublar now features a fully functioning dinosaur theme park, Jurassic World, as originally envisioned by John Hammond.',
#   'The park is open.',
#   135397,
#   4783),
#  (43626,
#   'Skyfall',
#   200000000,
#   93,
#   '2012-10-25',
#   1108561013,
#   'Skyfall',
#   6.9,
#   7604,
#   "When Bond's latest assignment goes gravely wrong and agents around the world are exposed, MI6 is attacked forcing M to relocate the agency. These events cause her authority and position to be challenged by Gareth Mallory, the new Chairman of the Intelligence and Security Committee. With MI6 now compromised from both inside and out, M is left with one ally she can trust: Bond. 007 takes to the shadows - aided only by field agent, Eve - following a trail to the mysterious Silva, whose lethal and hidden motives have yet to reveal themselves.",
#   'Think on your sins.',
#   37724,
#   4764),
#  (43627,
#   'Spider-Man 2',
#   200000000,
#   35,
#   '2004-06-25',
#   783766341,
#   'Spider-Man 2',
#   6.7,
#   4321,
#   "Peter Parker is going through a major identity crisis. Burned out from being Spider-Man, he decides to shelve his superhero alter ego, which leaves the city suffering in the wake of carnage left by the evil Doc Ock. In the meantime, Parker still can't act on his feelings for Mary Jane Watson, a girl he's loved since childhood.",
#   "There's a hero in all of us.",
#   558,
#   4767),
#  (43628,
#   'Iron Man 3',
#   200000000,
#   77,
#   '2013-04-18',
#   1215439994,
#   'Iron Man 3',
#   6.8,
#   8806,
#   "When Tony Stark's world is torn apart by a formidable terrorist called the Mandarin, he starts an odyssey of rebuilding and retribution.",
#   'Unleash the power behind the armor.',
#   68721,
#   4784),
#  (43629,
#   'Alice in Wonderland',
#   200000000,
#   78,
#   '2010-03-03',
#   1025491110,
#   'Alice in Wonderland',
#   6.4,
#   4645,
#   "Alice, an unpretentious and individual 19-year-old, is betrothed to a dunce of an English nobleman. At her engagement party, she escapes the crowd to consider whether to go through with the marriage and falls down a hole in the garden after spotting an unusual rabbit. Arriving in a strange and surreal place called 'Underland,' she finds herself in a world that resembles the nightmares she had as a child, filled with talking animals, villainous queens and knights, and frumious bandersnatches. Alice realizes that she is there for a reason – to conquer the horrific Jabberwocky and restore the rightful queen to her throne.",
#   "You're invited to a very important date.",
#   12155,
#   4785),
#  (43630,
#   'X-Men: The Last Stand',
#   210000000,
#   3,
#   '2006-05-24',
#   459359555,
#   'X-Men: The Last Stand',
#   6.3,
#   3525,
#   "When a cure is found to treat mutations, lines are drawn amongst the X-Men and The Brotherhood, a band of powerful mutants organized under Xavier's former ally, Magneto.",
#   'Take a Stand',
#   36668,
#   4786),
#  (43631,
#   'Monsters University',
#   200000000,
#   89,
#   '2013-06-20',
#   743559607,
#   'Monsters University',
#   7.0,
#   3528,
#   "A look at the relationship between Mike and Sulley during their days at Monsters University — when they weren't necessarily the best of friends.",
#   'School never looked this scary.',
#   62211,
#   4787),
#  (43632,
#   'Transformers: Revenge of the Fallen',
#   150000000,
#   21,
#   '2009-06-19',
#   836297228,
#   'Transformers: Revenge of the Fallen',
#   6.0,
#   3138,
#   "Sam Witwicky leaves the Autobots behind for a normal life. But when his mind is filled with cryptic symbols, the Decepticons target him and he is dragged back into the Transformers' war.",
#   'Revenge is coming.',
#   8373,
#   4788),
#  (43633,
#   'Transformers: Age of Extinction',
#   210000000,
#   116,
#   '2014-06-25',
#   1091405097,
#   'Transformers: Age of Extinction',
#   5.8,
#   3095,
#   'As humanity picks up the pieces, following the conclusion of "Transformers: Dark of the Moon," Autobots and Decepticons have all but vanished from the face of the planet. However, a group of powerful, ingenious businessman and scientists attempt to learn from past Transformer incursions and push the boundaries of technology beyond what they can control - all while an ancient, powerful Transformer menace sets Earth in his cross-hairs.',
#   "This is not war. It's extinction.",
#   91314,
#   4788),
#  (43634,
#   'Oz: The Great and Powerful',
#   200000000,
#   46,
#   '2013-03-07',
#   491868548,
#   'Oz: The Great and Powerful',
#   5.7,
#   3530,
#   "Oscar Diggs, a small-time circus illusionist and con-artist, is whisked from Kansas to the Land of Oz where the inhabitants assume he's the great wizard of prophecy, there to save Oz from the clutches of evil.",
#   'In Oz, nothing is what it seems',
#   68728,
#   4767),
#  (43635,
#   'The Amazing Spider-Man 2',
#   200000000,
#   89,
#   '2014-04-16',
#   705717432,
#   'The Amazing Spider-Man 2',
#   6.5,
#   4179,
#   'For Peter Parker, life is busy. Between taking out the bad guys as Spider-Man and spending time with the person he loves, Gwen Stacy, high school graduation cannot come quickly enough. Peter has not forgotten about the promise he made to Gwen’s father to protect her by staying away, but that is a promise he cannot keep. Things will change for Peter when a new villain, Electro, emerges, an old friend, Harry Osborn, returns, and Peter uncovers new clues about his past.',
#   'No more secrets.',
#   102382,
#   4778),
#  (43636,
#   'TRON: Legacy',
#   170000000,
#   73,
#   '2010-12-10',
#   400062763,
#   'TRON: Legacy',
#   6.3,
#   2841,
#   "Sam Flynn, the tech-savvy and daring son of Kevin Flynn, investigates his father's disappearance and is pulled into The Grid. With the help of a mysterious program named Quorra, Sam quests to stop evil dictator Clu from crossing into the real world.",
#   'The Game Has Changed.',
#   20526,
#   4789),
#  (43637,
#   'Cars 2',
#   200000000,
#   49,
#   '2011-06-11',
#   559852396,
#   'Cars 2',
#   5.8,
#   2033,
#   'Star race car Lightning McQueen and his pal Mater head overseas to compete in the World Grand Prix race. But the road to the championship becomes rocky as Mater gets caught up in an intriguing adventure of his own: international espionage.',
#   'Ka-ciao!',
#   49013,
#   4790),
#  (43638,
#   'Green Lantern',
#   200000000,
#   51,
#   '2011-06-16',
#   219851172,
#   'Green Lantern',
#   5.1,
#   2487,
#   'For centuries, a small but powerful force of warriors called the Green Lantern Corps has sworn to keep intergalactic order. Each Green Lantern wears a ring that grants him superpowers. But when a new enemy called Parallax threatens to destroy the balance of power in the Universe, their fate and the fate of Earth lie in the hands of the first human ever recruited.',
#   'In our darkest hour, there will be light.',
#   44912,
#   4791),
#  (43639,
#   'Toy Story 3',
#   200000000,
#   59,
#   '2010-06-16',
#   1066969703,
#   'Toy Story 3',
#   7.6,
#   4597,
#   "Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.",
#   'No toy gets left behind.',
#   10193,
#   4792),
#  (43640,
#   'Terminator Salvation',
#   200000000,
#   71,
#   '2009-05-20',
#   371353001,
#   'Terminator Salvation',
#   5.9,
#   2463,
#   "All grown up in post-apocalyptic 2018, John Connor must lead the resistance of humans against the increasingly dominating militaristic robots. But when Marcus Wright appears, his existence confuses the mission as Connor tries to determine whether Wright has come from the future or the past -- and whether he's friend or foe.",
#   'The End Begins.',
#   534,
#   4793),
#  (43641,
#   'Furious 7',
#   190000000,
#   102,
#   '2015-04-01',
#   1506249360,
#   'Furious 7',
#   7.3,
#   4176,
#   'Deckard Shaw seeks revenge against Dominic Toretto and his family for his comatose brother.',
#   'Vengeance Hits Home',
#   168259,
#   4794),
#  (43642,
#   'World War Z',
#   200000000,
#   81,
#   '2013-06-20',
#   531865000,
#   'World War Z',
#   6.7,
#   5560,
#   'Life for former United Nations investigator Gerry Lane and his family seems content. Suddenly, the world is plagued by a mysterious infection turning whole human populations into rampaging mindless zombies. After barely escaping the chaos, Lane is persuaded to go on a mission to investigate this disease. What follows is a perilous trek around the world where Lane must brave horrific dangers and long odds to find answers before human civilization falls.',
#   'Remember Philly!',
#   72190,
#   4773),
#  (43643,
#   'X-Men: Days of Future Past',
#   250000000,
#   118,
#   '2014-05-15',
#   747862775,
#   'X-Men: Days of Future Past',
#   7.5,
#   6032,
#   'The ultimate X-Men ensemble fights a war for the survival of the species across two time periods as they join forces with their younger selves in an epic battle that must change the past – to save our future.',
#   'To save the future, they must alter the past',
#   127585,
#   4772),
#  (43644,
#   'Star Trek Into Darkness',
#   190000000,
#   78,
#   '2013-05-05',
#   467365246,
#   'Star Trek Into Darkness',
#   7.4,
#   4418,
#   'When the crew of the Enterprise is called back home, they find an unstoppable force of terror from within their own organization has detonated the fleet and everything it stands for, leaving our world in a state of crisis.  With a personal score to settle, Captain Kirk leads a manhunt to a war-zone world to capture a one man weapon of mass destruction. As our heroes are propelled into an epic chess game of life and death, love will be challenged, friendships will be torn apart, and sacrifices must be made for the only family Kirk has left: his crew.',
#   'Earth Will Fall',
#   54138,
#   4795),
#  (43645,
#   'Jack the Giant Slayer',
#   195000000,
#   43,
#   '2013-02-27',
#   197687603,
#   'Jack the Giant Slayer',
#   5.5,
#   2598,
#   'The story of an ancient war that is reignited when a young farmhand unwittingly opens a gateway between our world and a fearsome race of giants. Unleashed on the Earth for the first time in centuries, the giants strive to reclaim the land they once lost, forcing the young man, Jack into the battle of his life to stop them. Fighting for a kingdom, its people, and the love of a brave princess, he comes face to face with the unstoppable warriors he thought only existed in legend–and gets the chance to become a legend himself.',
#   'Prepare for a giant adventure',
#   81005,
#   4772),
#  (43646,
#   'The Great Gatsby',
#   105000000,
#   61,
#   '2013-05-10',
#   351040419,
#   'The Great Gatsby',
#   7.3,
#   3769,
#   "An adaptation of F. Scott Fitzgerald's Long Island-set novel, where Midwesterner Nick Carraway is lured into the lavish world of his neighbor, Jay Gatsby. Soon enough, however, Carraway will see through the cracks of Gatsby's nouveau riche existence, where obsession, madness, and tragedy await.",
#   'Reserving judgments is a matter of infinite hope... I come to the admission that it has a limit.',
#   64682,
#   4796),
#  (43647,
#   'Prince of Persia: The Sands of Time',
#   150000000,
#   62,
#   '2010-05-19',
#   335154643,
#   'Prince of Persia: The Sands of Time',
#   6.2,
#   2317,
#   'A rogue prince reluctantly joins forces with a mysterious princess and together, they race against dark forces to safeguard an ancient dagger capable of releasing the Sands of Time – gift from the gods that can reverse time and allow its possessor to rule the world.',
#   'Defy the Future',
#   9543,
#   4797),
#  (43648,
#   'Pacific Rim',
#   180000000,
#   56,
#   '2013-07-11',
#   407602906,
#   'Pacific Rim',
#   6.7,
#   4794,
#   "When legions of monstrous creatures, known as Kaiju, started rising from the sea, a war began that would take millions of lives and consume humanity's resources for years on end. To combat the giant Kaiju, a special type of weapon was devised: massive robots, called Jaegers, which are controlled simultaneously by two pilots whose minds are locked in a neural bridge. But even the Jaegers are proving nearly defenseless in the face of the relentless Kaiju. On the verge of defeat, the forces defending mankind have no choice but to turn to two unlikely heroes—a washed-up former pilot (Charlie Hunnam) and an untested trainee (Rinko Kikuchi)—who are teamed to drive a legendary but seemingly obsolete Jaeger from the past. Together, they stand as mankind's last hope against the mounting apocalypse.",
#   'To Fight Monsters, We Created Monsters',
#   68726,
#   4798),
#  (43649,
#   'Transformers: Dark of the Moon',
#   195000000,
#   28,
#   '2011-06-28',
#   1123746996,
#   'Transformers: Dark of the Moon',
#   6.1,
#   3299,
#   "Sam Witwicky takes his first tenuous steps into adulthood while remaining a reluctant human ally of Autobot-leader Optimus Prime. The film centers around the space race between the USSR and the USA, suggesting there was a hidden Transformers role in it all that remains one of the planet's most dangerous secrets.",
#   'The invasion we always feared. An enemy we never expected.',
#   38356,
#   4788),
#  (43650,
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   185000000,
#   75,
#   '2008-05-21',
#   786636033,
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   5.7,
#   2495,
#   "Set during the Cold War, the Soviets – led by sword-wielding Irina Spalko – are in search of a crystal skull which has supernatural powers related to a mystical Lost City of Gold. After being captured and then escaping from them, Indy is coerced to head to Peru at the behest of a young man whose friend – and Indy's colleague – Professor Oxley has been captured for his knowledge of the skull's whereabouts.",
#   'The adventure continues . . .',
#   217,
#   4799),
#  (43651,
#   'The Good Dinosaur',
#   175000000,
#   51,
#   '2015-11-14',
#   331926147,
#   'The Good Dinosaur',
#   6.6,
#   1736,
#   'An epic journey into the world of dinosaurs where an Apatosaurus named Arlo makes an unlikely human friend.',
#   'Little Arms With Big Attitude',
#   105864,
#   4800),
#  (43652,
#   'Brave',
#   185000000,
#   125,
#   '2012-06-21',
#   538983207,
#   'Brave',
#   6.7,
#   4641,
#   'Brave is set in the mystical Scottish Highlands, where Mérida is the princess of a kingdom ruled by King Fergus and Queen Elinor. An unruly daughter and an accomplished archer, Mérida one day defies a sacred custom of the land and inadvertently brings turmoil to the kingdom. In an attempt to set things right, Mérida seeks out an eccentric old Wise Woman and is granted an ill-fated wish. Also figuring into Mérida’s quest — and serving as comic relief — are the kingdom’s three lords: the enormous Lord MacGuffin, the surly Lord Macintosh, and the disagreeable Lord Dingwall.',
#   'Change your fate.',
#   62177,
#   4801),
#  (43653,
#   'Star Trek Beyond',
#   185000000,
#   65,
#   '2016-07-07',
#   343471816,
#   'Star Trek Beyond',
#   6.6,
#   2568,
#   'The USS Enterprise crew explores the furthest reaches of uncharted space, where they encounter a mysterious new enemy who puts them and everything the Federation stands for to the test.',
#   None,
#   188927,
#   4802),
#  (43654,
#   'WALL·E',
#   180000000,
#   66,
#   '2008-06-22',
#   521311860,
#   'WALL·E',
#   7.8,
#   6296,
#   "WALL·E is the last robot left on an Earth that has been overrun with garbage and all humans have fled to outer space. For 700 years he has continued to try and clean up the mess, but has developed some rather interesting human-like qualities. When a ship arrives with a sleek new type of robot, WALL·E thinks he's finally found a friend and stows away on the ship when it leaves.",
#   'An adventure beyond the ordinar-E.',
#   10681,
#   4766),
#  (43655,
#   'Rush Hour 3',
#   140000000,
#   22,
#   '2007-08-08',
#   258022233,
#   'Rush Hour 3',
#   6.1,
#   783,
#   "After an attempted assassination on Ambassador Han, Inspector Lee and Detective Carter are back in action as they head to Paris to protect a French woman with knowledge of the Triads' secret leaders. Lee also holds secret meetings with a United Nations authority, but his personal struggles with a Chinese criminal mastermind named Kenji, which reveals that it's Lee's long-lost...brother.",
#   'The Rush Is On!',
#   5174,
#   4786),
#  (43656,
#   '2012',
#   200000000,
#   45,
#   '2009-10-10',
#   769653595,
#   '2012',
#   5.6,
#   4903,
#   'Dr. Adrian Helmsley, part of a worldwide geophysical team investigating the effect on the earth of radiation from unprecedented solar storms, learns that the earth\'s core is heating up. He warns U.S. President Thomas Wilson that the crust of the earth is becoming unstable and that without proper preparations for saving a fraction of the world\'s population, the entire race is doomed. Meanwhile, writer Jackson Curtis stumbles on the same information. While the world\'s leaders race to build "arks" to escape the impending cataclysm, Curtis struggles to find a way to save his family. Meanwhile, volcanic eruptions and earthquakes of unprecedented strength wreak havoc around the world.',
#   'We Were Warned.',
#   14161,
#   4803),
#  (43657,
#   'A Christmas Carol',
#   200000000,
#   39,
#   '2009-11-04',
#   325233863,
#   'A Christmas Carol',
#   6.6,
#   1095,
#   'Miser Ebenezer Scrooge is awakened on Christmas Eve by spirits who reveal to him his own miserable existence, what opportunities he wasted in his youth, his current cruelties, and the dire fate that awaits him if he does not change his ways. Scrooge is faced with his own story of growing bitterness and meanness, and must decide what his own future will hold: death or redemption.',
#   "Season's Greedings",
#   17979,
#   4804),
#  (43658,
#   'Jupiter Ascending',
#   176000003,
#   85,
#   '2015-02-04',
#   183987723,
#   'Jupiter Ascending',
#   5.2,
#   2768,
#   'In a universe where human genetic material is the most precious commodity, an impoverished young Earth woman becomes the key to strategic maneuvers and internal strife within a powerful dynasty…',
#   'Expand your universe.',
#   76757,
#   4805),
#  (43659,
#   'The Legend of Tarzan',
#   180000000,
#   42,
#   '2016-06-29',
#   356743061,
#   'The Legend of Tarzan',
#   5.5,
#   2430,
#   'Tarzan, having acclimated to life in London, is called back to his former home in the jungle to investigate the activities at a mining encampment.',
#   'Human. Nature.',
#   258489,
#   4770),
#  (43660,
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   180000000,
#   67,
#   '2005-12-07',
#   748806957,
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   6.7,
#   2629,
#   "Siblings Lucy, Edmund, Susan and Peter step through a magical wardrobe and find the land of Narnia. There, the they discover a charming, once peaceful kingdom that has been plunged into eternal winter by the evil White Witch, Jadis. Aided by the wise and magnificent lion, Aslan, the children lead Narnia into a spectacular, climactic battle to be free of the Witch's glacial powers forever.",
#   'Evil Has Reigned For 100 Years...',
#   411,
#   4774),
#  (43661,
#   'X-Men: Apocalypse',
#   178000000,
#   139,
#   '2016-05-18',
#   543934787,
#   'X-Men: Apocalypse',
#   6.4,
#   4721,
#   "After the re-emergence of the world's first mutant, world-destroyer Apocalypse, the X-Men must unite to defeat his extinction level plan.",
#   'Only the strong will survive',
#   246655,
#   4772),
#  (43662,
#   'The Dark Knight',
#   185000000,
#   187,
#   '2008-07-16',
#   1004558444,
#   'The Dark Knight',
#   8.2,
#   12002,
#   'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#   'Why So Serious?',
#   155,
#   4765),
#  (43663,
#   'Up',
#   175000000,
#   92,
#   '2009-05-13',
#   735099082,
#   'Up',
#   7.7,
#   6870,
#   'Carl Fredricksen spent his entire life dreaming of exploring the globe and experiencing life to its fullest. But at age 78, life seems to have passed him by, until a twist of fate (and a persistent 8-year old Wilderness Explorer named Russell) gives him a new lease on life.',
#   None,
#   14160,
#   4806),
#  (43664,
#   'Monsters vs Aliens',
#   175000000,
#   36,
#   '2009-03-19',
#   381509870,
#   'Monsters vs Aliens',
#   6.0,
#   1423,
#   'When Susan Murphy is unwittingly clobbered by a meteor full of outer space gunk on her wedding day, she mysteriously grows to 49-feet-11-inches. The military jumps into action and captures Susan, secreting her away to a covert government compound. She is renamed Ginormica and placed in confinement with a ragtag group of Monsters...',
#   'When aliens attack, monsters fight back.',
#   15512,
#   4807),
#  (43665,
#   'Iron Man',
#   140000000,
#   120,
#   '2008-04-30',
#   585174222,
#   'Iron Man',
#   7.4,
#   8776,
#   'After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.',
#   "Heroes aren't born. They're built.",
#   1726,
#   4808),
#  (43666,
#   'Hugo',
#   170000000,
#   32,
#   '2011-11-22',
#   185770160,
#   'Hugo',
#   7.0,
#   2141,
#   "Hugo is an orphan boy living in the walls of a train station in 1930s Paris. He learned to fix clocks and other gadgets from his father and uncle which he puts to use keeping the train station clocks running. The only thing that he has left that connects him to his dead father is an automaton (mechanical man) that doesn't work without a special key which Hugo needs to find to unlock the secret he believes it contains. On his adventures, he meets with a shopkeeper, George Melies, who works in the train station and his adventure-seeking god-daughter. Hugo finds that they have a surprising connection to his father and the automaton, and he discovers it unlocks some memories the old man has buried inside regarding his past.",
#   'One of the most legendary directors of our time takes you on an extraordinary adventure.',
#   44826,
#   4809),
#  (43667,
#   'Wild Wild West',
#   170000000,
#   40,
#   '1999-06-29',
#   222104681,
#   'Wild Wild West',
#   5.1,
#   1020,
#   "Legless Southern inventor Dr. Arliss Loveless plans to rekindle the Civil War by assassinating President U.S. Grant. Only two men can stop him: gunfighter James West and master-of-disguise and inventor Artemus Gordon. The two must team up to thwart Loveless' plans.",
#   "It's a whole new west.",
#   8487,
#   4776),
#  (43668,
#   'The Mummy: Tomb of the Dragon Emperor',
#   145000000,
#   60,
#   '2008-07-01',
#   401128639,
#   'The Mummy: Tomb of the Dragon Emperor',
#   5.2,
#   1387,
#   "Archaeologist Rick O'Connell travels to China, pitting him against an emperor from the 2,000-year-old Han dynasty who's returned from the dead to pursue a quest for world domination. This time, O'Connell enlists the help of his wife and son to quash the so-called 'Dragon Emperor' and his abuse of supernatural power.",
#   'A New Evil Awakens.',
#   1735,
#   4810),
#  (43669,
#   'Suicide Squad',
#   175000000,
#   90,
#   '2016-08-02',
#   745000000,
#   'Suicide Squad',
#   5.9,
#   7458,
#   'From DC Comics comes the Suicide Squad, an antihero team of incarcerated supervillains who act as deniable assets for the United States government, undertaking high-risk black ops missions in exchange for commuted prison sentences.',
#   'Worst Heroes Ever',
#   297761,
#   4811),
#  (43670,
#   'Evan Almighty',
#   175000000,
#   27,
#   '2007-06-09',
#   173000000,
#   'Evan Almighty',
#   5.3,
#   1151,
#   'God contacts Congressman Evan Baxter and tells him to build an ark in preparation for a great flood.',
#   'A comedy of biblical proportions',
#   2698,
#   4812),
#  (43671,
#   'Edge of Tomorrow',
#   178000000,
#   79,
#   '2014-05-27',
#   370541256,
#   'Edge of Tomorrow',
#   7.6,
#   4858,
#   'Major Bill Cage is an officer who has never seen a day of combat when he is unceremoniously demoted and dropped into combat. Cage is killed within minutes, managing to take an alpha alien down with him. He awakens back at the beginning of the same day and is forced to fight and die again... and again - as physical contact with the alien has thrown him into a time loop.',
#   'Live, Die, Repeat',
#   137113,
#   4813),
#  (43672,
#   'Waterworld',
#   175000000,
#   44,
#   '1995-07-28',
#   264218220,
#   'Waterworld',
#   5.9,
#   992,
#   "In a futuristic world where the polar ice caps have melted and made Earth a liquid planet, a beautiful barmaid rescues a mutant seafarer from a floating island prison. They escape, along with her young charge, Enola, and sail off aboard his ship. But the trio soon becomes the target of a menacing pirate who covets the map to 'Dryland' – which is tattooed on Enola's back.",
#   'Beyond the horizon lies the secret to a new beginning.',
#   9804,
#   4814),
#  (43673,
#   'G.I. Joe: The Rise of Cobra',
#   175000000,
#   32,
#   '2009-08-04',
#   302469017,
#   'G.I. Joe: The Rise of Cobra',
#   5.6,
#   1962,
#   'From the Egyptian desert to deep below the polar ice caps, the elite G.I. JOE team uses the latest in next-generation spy and military equipment to fight the corrupt arms dealer Destro and the growing threat of the mysterious Cobra organization to prevent them from plunging the world into chaos.',
#   "When all else fails, they don't.",
#   14869,
#   4815),
#  (43674,
#   'Inside Out',
#   175000000,
#   128,
#   '2015-06-09',
#   857611174,
#   'Inside Out',
#   8.0,
#   6560,
#   "Growing up can be a bumpy road, and it's no exception for Riley, who is uprooted from her Midwest life when her father starts a new job in San Francisco. Like all of us, Riley is guided by her emotions - Joy, Fear, Anger, Disgust and Sadness. The emotions live in Headquarters, the control center inside Riley's mind, where they help advise her through everyday life. As Riley and her emotions struggle to adjust to a new life in San Francisco, turmoil ensues in Headquarters. Although Joy, Riley's main and most important emotion, tries to keep things positive, the emotions conflict on how best to navigate a new city, house and school.",
#   'Meet the little voices inside your head.',
#   150540,
#   4806),
#  (43675,
#   'The Jungle Book',
#   175000000,
#   94,
#   '2016-04-07',
#   966550600,
#   'The Jungle Book',
#   6.7,
#   2892,
#   'After a threat from the tiger Shere Khan forces him to flee the jungle, a man-cub named Mowgli embarks on a journey of self discovery with the help of panther, Bagheera, and free spirited bear, Baloo.',
#   None,
#   278927,
#   4808),
#  (43676,
#   'Iron Man 2',
#   200000000,
#   77,
#   '2010-04-28',
#   623933331,
#   'Iron Man 2',
#   6.6,
#   6849,
#   "With the world now aware of his dual life as the armored superhero Iron Man, billionaire inventor Tony Stark faces pressure from the government, the press and the public to share his technology with the military. Unwilling to let go of his invention, Stark, with Pepper Potts and James 'Rhodey' Rhodes at his side, must forge new alliances – and confront powerful enemies.",
#   "It's not the armor that makes the hero, but the man inside.",
#   10138,
#   4808),
#  (43677,
#   'Snow White and the Huntsman',
#   170000000,
#   77,
#   '2012-05-30',
#   396600000,
#   'Snow White and the Huntsman',
#   5.8,
#   3118,
#   'After the Evil Queen marries the King, she performs a violent coup in which the King is murdered and his daughter, Snow White, is taken captive. Almost a decade later, a grown Snow White is still in the clutches of the Queen. In order to obtain immortality, The Evil Queen needs the heart of Snow White. After Snow escapes the castle, the Queen sends the Huntsman to find her in the Dark Forest.',
#   'The Fairytale is Over',
#   58595,
#   4816),
#  (43678,
#   'Maleficent',
#   180000000,
#   110,
#   '2014-05-28',
#   758539785,
#   'Maleficent',
#   7.0,
#   4496,
#   "The untold story of Disney's most iconic villain from the 1959 classic 'Sleeping Beauty'. A beautiful, pure-hearted young woman, Maleficent has an idyllic life growing up in a peaceable forest kingdom, until one day when an invading army threatens the harmony of the land.  Maleficent rises to be the land's fiercest protector, but she ultimately suffers a ruthless betrayal – an act that begins to turn her heart into stone. Bent on revenge, Maleficent faces an epic battle with the invading King's successor and, as a result, places a curse upon his newborn infant Aurora. As the child grows, Maleficent realizes that Aurora holds the key to peace in the kingdom - and to Maleficent's true happiness as well.",
#   "Don't believe the fairy tale.",
#   102651,
#   4817),
#  (43679,
#   'Dawn of the Planet of the Apes',
#   170000000,
#   243,
#   '2014-06-26',
#   710644566,
#   'Dawn of the Planet of the Apes',
#   7.3,
#   4410,
#   'A group of scientists in San Francisco struggle to stay alive in the aftermath of a plague that is wiping out humanity, while Caesar tries to maintain dominance over his community of intelligent apes.',
#   'One last chance for peace.',
#   119450,
#   4818),
#  (43680,
#   'The Lovers',
#   27000000,
#   2,
#   '2015-02-13',
#   0,
#   'The Lovers',
#   4.8,
#   34,
#   'The Lovers is an epic romance time travel adventure film. Helmed by Roland Joffé from a story by Ajey Jhankar, the film is a sweeping tale of an impossible love set against the backdrop of the first Anglo-Maratha war across two time periods and continents and centred around four characters — a British officer in 18th century colonial India, the Indian woman he falls deeply in love with, an American present-day marine biologist and his wife.',
#   'Love is longer than life.',
#   79698,
#   4819),
#  (43681,
#   '47 Ronin',
#   175000000,
#   41,
#   '2013-12-06',
#   150962475,
#   '47 Ronin',
#   5.9,
#   1326,
#   'Based on the original 1941 movie from Japan, and from ancient Japan’s most enduring tale, the epic 3D fantasy-adventure 47 Ronin is born.  Keanu Reeves leads the cast as Kai, an outcast who joins Oishi (Hiroyuki Sanada), the leader of the 47 outcast samurai.  Together they seek vengeance upon the treacherous overlord who killed their master and banished their kind.  To restore honor to their homeland, the warriors embark upon a quest that challenges them with a series of trials that would destroy ordinary warriors.',
#   'For courage. For loyalty. For honor.',
#   64686,
#   4820),
#  (43682,
#   'Captain America: The Winter Soldier',
#   170000000,
#   72,
#   '2014-03-20',
#   714766572,
#   'Captain America: The Winter Soldier',
#   7.6,
#   5764,
#   'After the cataclysmic events in New York with The Avengers, Steve Rogers, aka Captain America is living quietly in Washington, D.C. and trying to adjust to the modern world. But when a S.H.I.E.L.D. colleague comes under attack, Steve becomes embroiled in a web of intrigue that threatens to put the world at risk. Joining forces with the Black Widow, Captain America struggles to expose the ever-widening conspiracy while fighting off professional assassins sent to silence him at every turn. When the full scope of the villainous plot is revealed, Captain America and the Black Widow enlist the help of a new ally, the Falcon. However, they soon find themselves up against an unexpected and formidable enemy—the Winter Soldier.',
#   'In heroes we trust.',
#   100402,
#   4781),
#  (43683,
#   'Shrek Forever After',
#   165000000,
#   44,
#   '2010-05-16',
#   752600867,
#   'Shrek Forever After',
#   6.0,
#   1959,
#   "A bored and domesticated Shrek pacts with deal-maker Rumpelstiltskin to get back to feeling like a real ogre again, but when he's duped and sent to a twisted version of Far Far Away—where Rumpelstiltskin is king, ogres are hunted, and he and Fiona have never met—he sets out to restore his world and reclaim his true love.",
#   "It ain't Ogre... Til it's Ogre",
#   10192,
#   4821),
#  (43684,
#   'Tomorrowland',
#   190000000,
#   130,
#   '2015-05-19',
#   209154322,
#   'Tomorrowland',
#   6.2,
#   2846,
#   'Bound by a shared destiny, a bright, optimistic teen bursting with scientific curiosity and a former boy-genius inventor jaded by disillusionment embark on a danger-filled mission to unearth the secrets of an enigmatic place somewhere in time and space that exists in their collective memory as "Tomorrowland."',
#   'Imagine a world where nothing is impossible.',
#   158852,
#   4822),
#  (43685,
#   'Big Hero 6',
#   165000000,
#   203,
#   '2014-10-24',
#   652105443,
#   'Big Hero 6',
#   7.8,
#   6135,
#   'The special bond that develops between plus-sized inflatable robot Baymax, and prodigy Hiro Hamada, who team up with a group of friends to form a band of high-tech heroes.',
#   'From the creators of Wreck-it Ralph and Frozen',
#   177572,
#   4823),
#  (43686,
#   'Wreck-It Ralph',
#   165000000,
#   62,
#   '2012-11-01',
#   471222889,
#   'Wreck-It Ralph',
#   7.1,
#   4570,
#   "Wreck-It Ralph is the 9-foot-tall, 643-pound villain of an arcade video game named Fix-It Felix Jr., in which the game's titular hero fixes buildings that Ralph destroys. Wanting to prove he can be a good guy and not just a villain, Ralph escapes his game and lands in Hero's Duty, a first-person shooter where he helps the game's hero battle against alien invaders. He later enters Sugar Rush, a kart racing game set on tracks made of candies, cookies and other sweets. There, Ralph meets Vanellope von Schweetz who has learned that her game is faced with a dire threat that could affect the entire arcade, and one that Ralph may have inadvertently started.",
#   'The story of a regular guy just looking for a little wreck-ognition.',
#   82690,
#   4824),
#  (43687,
#   'The Polar Express',
#   165000000,
#   47,
#   '2004-11-10',
#   305875730,
#   'The Polar Express',
#   6.4,
# ...
#   'Some People Get Into Trouble No Matter What They WEAR.',
#   9879,
#   5223),
#  (44563,
#   'Marmaduke',
#   50000000,
#   12,
#   '2010-06-04',
#   83761844,
#   'Marmaduke',
#   5.0,
#   149,
#   "When Phil and Debbie Winslow relocate from their native Kansas to the sunny climes of Orange County, their big-hearted, havoc-wreaking Great Dane gets a taste of the dog's life, California-style.",
#   'Live Large',
#   38579,
#   5164),
#  (44564,
#   'Hereafter',
#   50000000,
#   13,
#   '2010-10-15',
#   105197635,
#   'Hereafter',
#   5.8,
#   510,
#   'A supernatural thriller centered on three people -- a blue-collar American, a French journalist and a London school boy -- who are touched by death in different ways.',
#   'Touched by death. Changed by life.',
#   44603,
#   5087),
#  (44565,
#   'Murder by Numbers',
#   50000000,
#   16,
#   '2002-04-19',
#   56714147,
#   'Murder by Numbers',
#   6.0,
#   268,
#   'Tenacious homicide detective Cassie Mayweather and her still-green partner are working a murder case, attempting to profile two malevolently brilliant young men: cold, calculating killers whose dark secrets might explain their crimes.',
#   'The only flaw in their plan was her.',
#   11892,
#   5224),
#  (44566,
#   'Assassins',
#   50000000,
#   23,
#   '1995-10-06',
#   30303072,
#   'Assassins',
#   6.0,
#   387,
#   'Assassin Robert Rath arrives at a funeral to kill a prominent mobster, only to witness a rival hired gun complete the job for him -- with grisly results. Horrified by the murder of innocent bystanders, Rath decides to take one last job and then return to civilian life. But finding his way out of the world of contract killing grows ever more dangerous as Rath falls for his female target and becomes a marked man himself.',
#   'In the shadows of life, In the business of death, One man found a reason to live...',
#   9691,
#   4866),
#  (44567,
#   'Hannibal Rising',
#   50000000,
#   6,
#   '2007-02-06',
#   82169884,
#   'Hannibal Rising',
#   6.0,
#   654,
#   'The story of the early, murderous roots of the cannibalistic killer, Hannibal Lecter – from his hard-scrabble Lithuanian childhood, where he witnesses the repulsive lengths to which hungry soldiers will go to satiate themselves, through his sojourn in France, where as a med student he hones his appetite for the kill.',
#   'It started with revenge.',
#   1248,
#   5225),
#  (44568,
#   'The Story of Us',
#   50000000,
#   6,
#   '1999-10-13',
#   58900031,
#   'The Story of Us',
#   5.9,
#   75,
#   'Ben and Katie Jordan are a married couple who go through hard times in fifteen years of marriage.',
#   None,
#   12220,
#   5101),
#  (44569,
#   'The Host',
#   44000000,
#   42,
#   '2013-03-22',
#   63327201,
#   'The Host',
#   6.0,
#   1817,
#   'A parasitic alien soul is injected into the body of Melanie Stryder. Instead of carrying out her race\'s mission of taking over the Earth, "Wanda" (as she comes to be called) forms a bond with her host and sets out to aid other free humans.',
#   'You will be one of us',
#   72710,
#   5226),
#  (44570,
#   'Basic',
#   50000000,
#   19,
#   '2003-04-18',
#   42792561,
#   'Basic',
#   6.2,
#   286,
#   'A DEA agent investigates the disappearance of a legendary Army ranger drill sergeant and several of his cadets during a training exercise gone severely awry.',
#   'Deception is their most deadly weapon.',
#   10782,
#   4890),
#  (44571,
#   'Blood Work',
#   50000000,
#   10,
#   '2002-08-04',
#   26199517,
#   'Blood Work',
#   6.1,
#   206,
#   'Still recovering from a heart transplant, a retired FBI profiler returns to service when his own blood analysis offers clues to the identity of a serial killer.',
#   "He's a heartbeat away from catching the killer",
#   9573,
#   5087),
#  (44572,
#   'The International',
#   50000000,
#   13,
#   '2009-02-03',
#   60161391,
#   'The International',
#   6.0,
#   368,
#   "An interpol agent and an attorney are determined to bring one of the world's most powerful banks to justice. Uncovering money laundering, arms trading, and conspiracy to destabilize world governments, their investigation takes them from Berlin, Milan, New York and Istanbul. Finding themselves in a chase across the globe, their relentless tenacity puts their own lives at risk.",
#   'Is your money making a killing?',
#   4959,
#   4936),
#  (44573,
#   'Escape from L.A.',
#   50000000,
#   21,
#   '1996-08-09',
#   42277365,
#   'Escape from L.A.',
#   5.6,
#   373,
#   'This time, a cataclysmic temblor hits Los Angeles, turning it into an island. The president views the quake as a sign from above, expels Los Angeles from the country and makes it a penal colony for those found guilty of moral crimes. When his daughter, part of a resistance movement, steals the control unit for a doomsday weapon, Snake again gets tapped to save the day.',
#   'Snake Is Back.',
#   10061,
#   5227),
#  (44574,
#   'The Iron Giant',
#   70000000,
#   61,
#   '1999-08-06',
#   23159305,
#   'The Iron Giant',
#   7.6,
#   1436,
#   'In the small town of Rockwell, Maine in October 1957, a giant metal machine befriends a nine-year-old boy and ultimately finds its humanity by unselfishly saving people from their own fears and prejudices.',
#   'It came from outer space!',
#   10386,
#   4822),
#  (44575,
#   'The Life Aquatic with Steve Zissou',
#   50000000,
#   25,
#   '2004-12-10',
#   34808403,
#   'The Life Aquatic with Steve Zissou',
#   7.1,
#   775,
#   'Wes Anderson’s incisive quirky comedy build up stars complex characters like in ‘The Royal Tenenbaums’ with Bill Murray on in the leading role. An ocean adventure documentary film maker Zissou is put in all imaginable life situations and a tough life crisis as he attempts to make a new film about capturing the creature that caused him pain.',
#   'The deeper you go, the weirder life gets.',
#   421,
#   5228),
#  (44576,
#   'Free State of Jones',
#   50000000,
#   21,
#   '2016-06-24',
#   25035950,
#   'Free State of Jones',
#   6.6,
#   428,
#   'In 1863, Mississippi farmer Newt Knight serves as a medic for the Confederate Army. Opposed to slavery, Knight would rather help the wounded than fight the Union. After his nephew dies in battle, Newt returns home to Jones County to safeguard his family but is soon branded an outlaw deserter. Forced to flee, he finds refuge with a group of runaway slaves hiding out in the swamps. Forging an alliance with the slaves and other farmers, Knight leads a rebellion that would forever change history.',
#   'Based on the incredible true story.',
#   316152,
#   4973),
#  (44577,
#   'The Life of David Gale',
#   50000000,
#   22,
#   '2003-02-21',
#   38955598,
#   'The Life of David Gale',
#   7.3,
#   480,
#   'A man against capital punishment is accused of murdering a fellow activist and is sent to death row.',
#   'The crime is clear. The truth is not.',
#   11615,
#   5166),
#  (44578,
#   'Man of the House',
#   40000000,
#   6,
#   '2005-02-25',
#   0,
#   'Man of the House',
#   5.4,
#   120,
#   'Texas Ranger Roland Sharp is assigned to protect the only witnesses to the murder of a key figure in the prosecution of a drug kingpin -- a group of University of Texas cheerleaders. Sharp must now go undercover as an assistant cheerleading coach and move in with the young women.',
#   'Protecting witnesses is a challenge. Living with them is impossible.',
#   13498,
#   5152),
#  (44579,
#   'Run All Night',
#   50000000,
#   74,
#   '2015-03-11',
#   71561644,
#   'Run All Night',
#   6.3,
#   1148,
#   'Brooklyn mobster and prolific hit man Jimmy Conlon has seen better days. Longtime best friend of a mob boss, Jimmy is haunted by the sins of his past—as well as a dogged police detective who’s been one step behind Jimmy for 30 years. But when Jimmy’s estranged son becomes a target, Jimmy must make a choice between the crime family he chose and the real family he abandoned long ago. Now, with nowhere safe to turn, Jimmy has just one night to figure out exactly where his loyalties lie and to see if he can finally make things right.',
#   'No sin goes unpunished',
#   241554,
#   5202),
#  (44580,
#   'Eastern Promises',
#   51500000,
#   35,
#   '2007-09-14',
#   55112356,
#   'Eastern Promises',
#   7.2,
#   848,
#   'A Russian teenager living in London who dies during childbirth leaves clues to a midwife in her journal that could tie her child to a rape involving a violent Russian mob family.',
#   'Every sin leaves a mark.',
#   2252,
#   5229),
#  (44581,
#   'Into the Blue',
#   50000000,
#   14,
#   '2005-09-30',
#   44434439,
#   'Into the Blue',
#   5.8,
#   458,
#   'When they take some friends on an extreme sport adventure, the last thing Jared and Sam expect to see below the shark-infested waters is a legendary pirate ship rumored to contain millions of dollars in gold. But their good fortune is short-lived, as a ruthless gang of criminals gets word of what they have uncovered.',
#   'Treasure has its price.',
#   11968,
#   5230),
#  (44582,
#   'Joan of Arc',
#   60000000,
#   21,
#   '1999-10-18',
#   66976317,
#   'The Messenger: The Story of Joan of Arc',
#   6.2,
#   367,
#   "In 1429 a teenage girl from a remote French village stood before her King with a message she claimed came from God; that she would defeat the world's greatest army and liberate her country from its political and religious turmoil. Following her mission to reclaim god's dimished kingdom - through her amazing victories until her violent and untimely death.",
#   None,
#   10047,
#   4949),
#  (44583,
#   'Your Highness',
#   49900000,
#   21,
#   '2011-04-08',
#   26121638,
#   'Your Highness',
#   5.2,
#   501,
#   "A fantasy movie about an arrogant, lazy prince and his more heroic brother who must complete a quest in order to save their father's kingdom.",
#   'Get your quest on.',
#   38319,
#   5231),
#  (44584,
#   'Dream House',
#   50000000,
#   19,
#   '2011-09-30',
#   38502340,
#   'Dream House',
#   5.8,
#   391,
#   "Publisher, Will Atenton quits a lucrative job in New York to relocate his wife, Libby and their daughters to a quaint town in New England. However, as they settle into their home the Atentons discover that a woman and her children were murdered there, and the surviving husband is the town's prime suspect. With help from a neighbor who was close to the murdered family, Will pieces together a horrifying chain of events.",
#   'Once upon a time, there were two little girls who lived in a house.',
#   69668,
#   5232),
#  (44585,
#   'Mad City',
#   50000000,
#   3,
#   '1997-11-07',
#   10541523,
#   'Mad City',
#   5.9,
#   81,
#   'A misguided museum guard who loses his job and then tries to get it back at gunpoint is thrown into the fierce world of ratings-driven TV gone mad.',
#   'One man will make a mistake. The other will make it a spectacle.',
#   9770,
#   5233),
#  (44586,
#   "Baby's Day Out",
#   50000000,
#   21,
#   '1994-07-01',
#   16671505,
#   "Baby's Day Out",
#   5.8,
#   274,
#   "Baby Bink couldn't ask for more; he has adoring (if somewhat sickly-sweet) parents, he lives in a huge mansion, and he's just about to appear in the social pages of the paper. Unfortunately, not everyone in the world is as nice as Baby Bink's parents; especially the three enterprising kidnapers who pretend to be photographers from the newspaper. Successfully kidnaping Baby Bink, they have a harder time keeping hold of the rascal, who not only keeps one step ahead of them, but seems to be more than a little bit smarter than the three bumbling criminals.",
#   'No bib. No crib. No problem.',
#   11212,
#   5234),
#  (44587,
#   'The Scarlet Letter',
#   50000000,
#   7,
#   '1995-10-13',
#   10382407,
#   'The Scarlet Letter',
#   5.5,
#   108,
#   'Set in puritanical Boston in the mid 1600s, the story of seamstress Hester Prynne, who is outcast after she becomes pregnant by a respected reverend. She refuses to divulge the name of the father, is "convicted" of adultery and forced to wear a scarlet "A" until an Indian attack unites the Puritans and leads to a reevaluation of their laws and morals.',
#   'When intimacy is forbidden and passion is a sin, love is the most defiant crime of all.',
#   10533,
#   4819),
#  (44588,
#   'Fair Game',
#   22000000,
#   12,
#   '2010-05-20',
#   24188922,
#   'Fair Game',
#   6.5,
#   235,
#   "Wife and mother Valerie Plame (Naomi Watts) has a double life as a CIA operative, hiding her vocation from family and friends. Her husband, Joseph Wilson (Sean Penn), writes a controversial article in The New York Times, refuting stories about the sale of enriched uranium to Iraq, Then Valerie's secret work and identity is leaked to the press. With her cover blown and other people endangered, Valerie's career and personal life begin to unravel.",
#   'Wife. Mother. Spy.',
#   38363,
#   4813),
#  (44589,
#   'Domino',
#   50000000,
#   18,
#   '2005-09-22',
#   22944502,
#   'Domino',
#   6.0,
#   444,
#   'The daughter of actor, Laurence Harvey turns away from her career as a Ford model to become a bounty hunter.',
#   'Heads You Live... Tails You Die.',
#   9923,
#   4923),
#  (44590,
#   'Jade',
#   50000000,
#   8,
#   '1995-10-13',
#   9851610,
#   'Jade',
#   5.2,
#   44,
#   'Someone does a nasty hatchet job on a San Fransisco big noise and the Assistant D.A. takes charge of the investigation. Through a web of blackmail and prostitution involving the Governor, an old lover of the law man emerges as a prime suspect and he has to deal with his personal feelings as well as the case.',
#   'Some fantasies go too far.',
#   11863,
#   5170),
#  (44591,
#   'Gamer',
#   50000000,
#   27,
#   '2009-09-03',
#   40828540,
#   'Gamer',
#   5.6,
#   760,
#   'Mind-control technology has taken society by a storm, a multiplayer on-line game called "Slayers" allows players to control human prisoners in mass-scale. Simon (Lerman) controls Kable (Butler), the online champion of the game. Kable\'s ultimate challenge becomes regaining his identity and independence by defeating the game\'s mastermind (Hall).',
#   "In the near future, you don't live to play... you'll play to live.",
#   18501,
#   5156),
#  (44592,
#   'Beautiful Creatures',
#   60000000,
#   40,
#   '2013-02-13',
#   60052138,
#   'Beautiful Creatures',
#   5.6,
#   984,
#   "Ethan Wate just wants to get to know Lena Duchannes better, but unbeknownst to him, Lena has strange powers.  As Lena's 16th birthday approaches she might decide her fate, to be good or evil.  A choice which will impact her relationship forever.",
#   'Dark secrets will come to light.',
#   109491,
#   5235),
#  (44593,
#   'Death to Smoochy',
#   55000000,
#   11,
#   '2002-03-28',
#   0,
#   'Death to Smoochy',
#   5.9,
#   132,
#   "Tells the story of Rainbow Randolph, the corrupt, costumed star of a popular children's TV show, who is fired over a bribery scandal and replaced by squeaky-clean Smoochy, a puffy fuscia rhinoceros. As Smoochy catapults to fame - scoring hit ratings and the affections of a network executive - Randolph makes the unsuspecting rhino the target of his numerous outrageous attempts to exact revenge and reclaim his status as America's sweetheart.",
#   'Get ready for an unexpected hit.',
#   9275,
#   5236),
#  (44594,
#   'Zoolander 2',
#   50000000,
#   37,
#   '2016-02-06',
#   55969000,
#   'Zoolander 2',
#   4.7,
#   797,
#   'Derek and Hansel are modelling again when an opposing company attempts to take them out from the business.',
#   'Long time no Z',
#   329833,
#   4960),
#  (44595,
#   'The Big Bounce',
#   50000000,
#   6,
#   '2004-01-30',
#   6808550,
#   'The Big Bounce',
#   5.0,
#   76,
#   "A small-time con artist and a Hawaiian real estate developer's mischievous, enterprising mistress team up for a potential $200,000 score.",
#   "It's all in who you trust",
#   12634,
#   5237),
#  (44596,
#   'What Planet Are You From?',
#   60000000,
#   2,
#   '2000-03-03',
#   0,
#   'What Planet Are You From?',
#   5.4,
#   37,
#   "A highly-evolved planet, whose denizens feel no emotion and reproduce by cloning, plans to take over Earth from the inside by sending an operative, fashioned with a humming, mechanical penis, to impregnate an earthling and stay until the birth. The alien, Harold Anderson, goes to Phoenix as a banker and sets to work finding a mate. His approaches to women are inept, and the humming phallus doesn't help, but on the advice of a banking colleague, he cruises an AA meeting, meets Susan, and somehow convinces her to marry. The clock starts to tick: will she conceive, have a baby, and lose Harold (and the child) to his planet before he discovers emotion and starts to care?",
#   "To save his planet, an alien must find a woman on Earth to have his baby. There's just one problem.",
#   10416,
#   5031),
#  ...]

# %% [markdown]
# # We will have to convert all data in table form then only we would be able to perform data analysis

# %%
# Creating a DataFrame to get data in tables
movies = pd.DataFrame(movies,columns=['id', 'original_title', 'budget', 'popularity',
                                  'release_date', 'revenue', 'title', 'vote_average',
                                  'vote_count', 'overview', 'tagline','uid',
                                  'director_id'] )

# %%
# Displaying the DataFrame
movies
# Out:
#          id                            original_title     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# 4     43601                               John Carter  260000000          43
# ...     ...                                       ...        ...         ...
# 4768  48395                               El Mariachi     220000          14
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# 4772  48399                         My Date with Drew          0           1
#
#      release_date     revenue                                     title  \
# 0      2009-12-10  2787965087                                    Avatar
# 1      2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2      2015-10-26   880674609                                   Spectre
# 3      2012-07-16  1084939099                     The Dark Knight Rises
# 4      2012-03-07   284139100                               John Carter
# ...           ...         ...                                       ...
# 4768   1992-09-04     2040920                               El Mariachi
# 4769   2011-12-26           0                                 Newlyweds
# 4770   2013-10-13           0                 Signed, Sealed, Delivered
# 4771   2012-05-03           0                          Shanghai Calling
# 4772   2005-08-05           0                         My Date with Drew
#
#       vote_average  vote_count  \
# 0              7.2       11800
# 1              6.9        4500
# 2              6.3        4466
# 3              7.6        9106
# 4              6.1        2124
# ...            ...         ...
# 4768           6.6         238
# 4769           5.9           5
# 4770           7.0           6
# 4771           5.7           7
# 4772           6.3          16
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4768  El Mariachi just wants to play his guitar and ...
# 4769  A newlywed couple's honeymoon is upended by th...
# 4770  "Signed, Sealed, Delivered" introduces a dedic...
# 4771  When ambitious New York attorney Sam is sent t...
# 4772  Ever since the second grade when he first saw ...
#
#                                                 tagline     uid  director_id
# 0                           Enter the World of Pandora.   19995         4762
# 1        At the end of the world, the adventure begins.     285         4763
# 2                                 A Plan No One Escapes  206647         4764
# 3                                       The Legend Ends   49026         4765
# 4                  Lost in our world, found in another.   49529         4766
# ...                                                 ...     ...          ...
# 4768  He didn't come looking for trouble, but troubl...    9367         5097
# 4769  A newlywed couple's honeymoon is upended by th...   72766         6485
# 4770                                               None  231617         7108
# 4771                           A New Yorker in Shanghai  126186         7109
# 4772                                               None   25975         7110
#
# [4773 rows x 13 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4773 entries, 0 to 4772
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4773 non-null   int64
#  1   original_title  4773 non-null   object
#  2   budget          4773 non-null   int64
#  3   popularity      4773 non-null   int64
#  4   release_date    4773 non-null   object
#  5   revenue         4773 non-null   int64
#  6   title           4773 non-null   object
#  7   vote_average    4773 non-null   float64
#  8   vote_count      4773 non-null   int64
#  9   overview        4770 non-null   object
#  10  tagline         3951 non-null   object
#  11  uid             4773 non-null   int64
#  12  director_id     4773 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 484.9+ KB

# %% [markdown]
# 3. Get all the data about directors?

# %%
# Fetching the data of the Director table from the Database
cur.execute("SELECT * FROM directors") # Here cur means cursor
# Creating the cursor object
directors = cur.fetchall()

# %%
directors
# Out:
# [('James Cameron', 4762, 2, 2710, 'Directing'),
#  ('Gore Verbinski', 4763, 2, 1704, 'Directing'),
#  ('Sam Mendes', 4764, 2, 39, 'Directing'),
#  ('Christopher Nolan', 4765, 2, 525, 'Directing'),
#  ('Andrew Stanton', 4766, 2, 7, 'Directing'),
#  ('Sam Raimi', 4767, 2, 7623, 'Directing'),
#  ('Byron Howard', 4768, 2, 76595, 'Directing'),
#  ('Joss Whedon', 4769, 2, 12891, 'Directing'),
#  ('David Yates', 4770, 2, 11343, 'Directing'),
#  ('Zack Snyder', 4771, 2, 15217, 'Directing'),
#  ('Bryan Singer', 4772, 2, 9032, 'Directing'),
#  ('Marc Forster', 4773, 2, 12995, 'Directing'),
#  ('Andrew Adamson', 4774, 2, 5524, 'Directing'),
#  ('Rob Marshall', 4775, 2, 17633, 'Directing'),
#  ('Barry Sonnenfeld', 4776, 2, 5174, 'Directing'),
#  ('Peter Jackson', 4777, 2, 108, 'Directing'),
#  ('Marc Webb', 4778, 2, 87742, 'Directing'),
#  ('Ridley Scott', 4779, 2, 578, 'Directing'),
#  ('Chris Weitz', 4780, 0, 3288, 'Directing'),
#  ('Anthony Russo', 4781, 2, 19271, 'Directing'),
#  ('Peter Berg', 4782, 2, 36602, 'Directing'),
#  ('Colin Trevorrow', 4783, 2, 930707, 'Directing'),
#  ('Shane Black', 4784, 2, 1108, 'Directing'),
#  ('Tim Burton', 4785, 2, 510, 'Directing'),
#  ('Brett Ratner', 4786, 2, 11091, 'Directing'),
#  ('Dan Scanlon', 4787, 2, 225976, 'Directing'),
#  ('Michael Bay', 4788, 2, 865, 'Directing'),
#  ('Joseph Kosinski', 4789, 2, 86270, 'Directing'),
#  ('John Lasseter', 4790, 2, 7879, 'Directing'),
#  ('Martin Campbell', 4791, 2, 10702, 'Directing'),
#  ('Lee Unkrich', 4792, 2, 8, 'Directing'),
#  ('McG', 4793, 2, 36425, 'Directing'),
#  ('James Wan', 4794, 2, 2127, 'Directing'),
#  ('J.J. Abrams', 4795, 2, 15344, 'Directing'),
#  ('Baz Luhrmann', 4796, 2, 6201, 'Directing'),
#  ('Mike Newell', 4797, 2, 10723, 'Directing'),
#  ('Guillermo del Toro', 4798, 2, 10828, 'Directing'),
#  ('Steven Spielberg', 4799, 2, 488, 'Directing'),
#  ('Peter Sohn', 4800, 2, 21198, 'Directing'),
#  ('Brenda Chapman', 4801, 1, 59803, 'Directing'),
#  ('Justin Lin', 4802, 0, 58189, 'Directing'),
#  ('Roland Emmerich', 4803, 2, 6046, 'Directing'),
#  ('Robert Zemeckis', 4804, 2, 24, 'Directing'),
#  ('Lilly Wachowski', 4805, 1, 9339, 'Directing'),
#  ('Pete Docter', 4806, 2, 12890, 'Directing'),
#  ('Conrad Vernon', 4807, 2, 12080, 'Directing'),
#  ('Jon Favreau', 4808, 2, 15277, 'Directing'),
#  ('Martin Scorsese', 4809, 2, 1032, 'Directing'),
#  ('Rob Cohen', 4810, 2, 18878, 'Directing'),
#  ('David Ayer', 4811, 0, 19769, 'Directing'),
#  ('Tom Shadyac', 4812, 2, 4499, 'Directing'),
#  ('Doug Liman', 4813, 2, 11694, 'Directing'),
#  ('Kevin Reynolds', 4814, 0, 8300, 'Directing'),
#  ('Stephen Sommers', 4815, 2, 7775, 'Directing'),
#  ('Rupert Sanders', 4816, 2, 228134, 'Directing'),
#  ('Robert Stromberg', 4817, 0, 1032536, 'Directing'),
#  ('Matt Reeves', 4818, 2, 32278, 'Directing'),
#  ('Roland Joffé', 4819, 0, 8965, 'Directing'),
#  ('Carl Rinsch', 4820, 0, 239571, 'Directing'),
#  ('Mike Mitchell', 4821, 2, 64151, 'Directing'),
#  ('Brad Bird', 4822, 2, 7087, 'Directing'),
#  ('Chris Williams', 4823, 2, 70238, 'Directing'),
#  ('Rich Moore', 4824, 2, 165787, 'Directing'),
#  ('Chris Sanders', 4825, 2, 66193, 'Directing'),
#  ('Jonathan Mostow', 4826, 2, 7213, 'Directing'),
#  ('James Gunn', 4827, 2, 15218, 'Directing'),
#  ('Hideaki Anno', 4828, 2, 77921, 'Directing'),
#  ('David Fincher', 4829, 2, 7467, 'Directing'),
#  ('Matthew Vaughn', 4830, 2, 957, 'Directing'),
#  ('Francis Lawrence', 4831, 2, 10943, 'Directing'),
#  ('Jon Turteltaub', 4832, 2, 12962, 'Directing'),
#  ('Wolfgang Petersen', 4833, 2, 5231, 'Directing'),
#  ('James Bobin', 4834, 0, 26205, 'Directing'),
#  ('Chris Miller', 4835, 2, 12098, 'Directing'),
#  ('Duncan Jones', 4836, 2, 81850, 'Directing'),
#  ('Alan Taylor', 4837, 2, 47005, 'Directing'),
#  ('Michael Apted', 4838, 2, 10781, 'Directing'),
#  ('Oliver Stone', 4839, 2, 1152, 'Directing'),
#  ('Jan Pinkava', 4840, 2, 7930, 'Directing'),
#  ('Eric Darnell', 4841, 2, 18863, 'Directing'),
#  ('Shawn Levy', 4842, 2, 17825, 'Directing'),
#  ('Gavin Hood', 4843, 2, 13079, 'Directing'),
#  ('Chris Buck', 4844, 0, 15774, 'Directing'),
#  ('George Miller', 4845, 2, 20629, 'Directing'),
#  ('Ron Howard', 4846, 2, 6159, 'Directing'),
#  ('Kenneth Branagh', 4847, 2, 11181, 'Directing'),
#  ('Hoyt Yeatman', 4848, 0, 84851, 'Directing'),
#  ('Jonathan Liebesman', 4849, 0, 66739, 'Directing'),
#  ('Christopher McQuarrie', 4850, 0, 9033, 'Directing'),
#  ('Joe Johnston', 4851, 2, 4945, 'Directing'),
#  ('Steve Hickner', 4852, 2, 44113, 'Directing'),
#  ('Jennifer Yuh Nelson', 4853, 1, 142312, 'Directing'),
#  ('M. Night Shyamalan', 4854, 2, 11614, 'Directing'),
#  ('Simon Wells', 4855, 2, 21879, 'Directing'),
#  ('David Bowers', 4856, 2, 33183, 'Directing'),
#  ('Joe Wright', 4857, 2, 36588, 'Directing'),
#  ('Rob Minkoff', 4858, 2, 18898, 'Directing'),
#  ('Lee Tamahori', 4859, 2, 7256, 'Directing'),
#  ('Paul Feig', 4860, 2, 116805, 'Directing'),
#  ('Peter Ramsey', 4861, 2, 151007, 'Directing'),
#  ('Dean Parisot', 4862, 2, 15002, 'Directing'),
#  ('Edward Zwick', 4863, 2, 9181, 'Directing'),
#  ('Dean DeBlois', 4864, 2, 69797, 'Directing'),
#  ('Alex Proyas', 4865, 2, 21085, 'Directing'),
#  ('Richard Donner', 4866, 2, 7187, 'Directing'),
#  ('Ang Lee', 4867, 2, 1614, 'Directing'),
#  ('Jon M. Chu', 4868, 2, 54507, 'Directing'),
#  ('Breck Eisner', 4869, 2, 52609, 'Directing'),
#  ('Hironobu Sakaguchi', 4870, 0, 21692, 'Directing'),
#  ('Peter Weir', 4871, 2, 2690, 'Directing'),
#  ('Bill Condon', 4872, 2, 15557, 'Directing'),
#  ('Louis Leterrier', 4873, 2, 18865, 'Directing'),
#  ('Alejandro González Iñárritu', 4874, 2, 223, 'Directing'),
#  ('David Soren', 4875, 0, 94075, 'Directing'),
#  ('Paul Greengrass', 4876, 2, 25598, 'Directing'),
#  ('Mark Osborne', 4877, 2, 57741, 'Directing'),
#  ('Peyton Reed', 4878, 2, 59026, 'Directing'),
#  ('Tim Johnson', 4879, 2, 52870, 'Directing'),
#  ('Phillip Noyce', 4880, 2, 13015, 'Directing'),
#  ('Darren Aronofsky', 4881, 2, 6431, 'Directing'),
#  ('Alfonso Cuarón', 4882, 2, 11218, 'Directing'),
#  ('Ralph Zondag', 4883, 2, 65855, 'Directing'),
#  ('Tom McGrath', 4884, 2, 18864, 'Directing'),
#  ('Chris Columbus', 4885, 2, 10965, 'Directing'),
#  ('Robert Schwentke', 4886, 2, 57270, 'Directing'),
#  ('Carlos Saldanha', 4887, 2, 5714, 'Directing'),
#  ('Guy Ritchie', 4888, 2, 956, 'Directing'),
#  ('Paul Verhoeven', 4889, 2, 10491, 'Directing'),
#  ('John McTiernan', 4890, 0, 1090, 'Directing'),
#  ('Tony Gilroy', 4891, 2, 19242, 'Directing'),
#  ('Joel Schumacher', 4892, 2, 5572, 'Directing'),
#  ('John Woo', 4893, 2, 11401, 'Directing'),
#  ('Tim Story', 4894, 2, 20400, 'Directing'),
#  ('Mark Steven Johnson', 4895, 2, 16837, 'Directing'),
#  ('Neill Blomkamp', 4896, 2, 82194, 'Directing'),
#  ('David Twohy', 4897, 0, 28239, 'Directing'),
#  ('José Padilha', 4898, 2, 52576, 'Directing'),
#  ('James L. Brooks', 4899, 2, 3388, 'Directing'),
#  ('James Mangold', 4900, 2, 366, 'Directing'),
#  ('George Lucas', 4901, 2, 1, 'Directing'),
#  ('Thomas Langmann', 4902, 2, 20674, 'Directing'),
#  ('Cedric Nicolas-Troyan', 4903, 0, 1454884, 'Directing'),
#  ('Roger Donaldson', 4904, 2, 21370, 'Directing'),
#  ('Dave Green', 4905, 0, 1101410, 'Directing'),
#  ('Josh Trank', 4906, 2, 934803, 'Directing'),
#  ('Brad Peyton', 4907, 2, 132876, 'Directing'),
#  ('Roger Spottiswoode', 4908, 2, 1724, 'Directing'),
#  ('Steven Soderbergh', 4909, 2, 1884, 'Directing'),
#  ('Rob Letterman', 4910, 0, 65630, 'Directing'),
#  ('Michel Gondry', 4911, 2, 201, 'Directing'),
#  ('Noam Murro', 4912, 0, 78914, 'Directing'),
#  ('Raja Gosnell', 4913, 2, 1215, 'Directing'),
#  ('Will Finn', 4914, 2, 70287, 'Directing'),
#  ('Jan de Bont', 4915, 2, 2209, 'Directing'),
#  ('Len Wiseman', 4916, 2, 3950, 'Directing'),
#  ('Frank Coraci', 4917, 2, 57370, 'Directing'),
#  ('Michael Mann', 4918, 2, 638, 'Directing'),
#  ('Bo Welch', 4919, 2, 5133, 'Directing'),
#  ('Ron Clements', 4920, 2, 15810, 'Directing'),
#  ('Peter Chelsom', 4921, 2, 36804, 'Directing'),
#  ('Dominic Sena', 4922, 2, 58498, 'Directing'),
#  ('Tony Scott', 4923, 2, 893, 'Directing'),
#  ('Paul Weitz', 4924, 2, 3289, 'Directing'),
#  ('Adam McKay', 4925, 2, 55710, 'Directing'),
#  ('Chuck Russell', 4926, 2, 26713, 'Directing'),
#  ('Quentin Tarantino', 4927, 2, 138, 'Directing'),
#  ('Gary Trousdale', 4928, 2, 62047, 'Directing'),
#  ('Mark Dindal', 4929, 2, 61411, 'Directing'),
#  ('Simon West', 4930, 2, 12786, 'Directing'),
#  ('Stefen Fangmeier', 4931, 0, 25453, 'Directing'),
#  ('Spike Jonze', 4932, 2, 5953, 'Directing'),
#  ('Chris Wedge', 4933, 2, 5713, 'Directing'),
#  ('Florian Henckel von Donnersmarck', 4934, 2, 8193, 'Directing'),
#  ('Peter Hyams', 4935, 2, 37710, 'Directing'),
#  ('Tom Tykwer', 4936, 2, 1071, 'Directing'),
#  ('Pitof', 4937, 2, 4586, 'Directing'),
#  ('Brad Silberling', 4938, 0, 11887, 'Directing'),
#  ('Patrick Hughes', 4939, 2, 143059, 'Directing'),
#  ('Ericson Core', 4940, 2, 21673, 'Directing'),
#  ('Lawrence Guterman', 4941, 0, 64191, 'Directing'),
#  ('Ron Underwood', 4942, 2, 33485, 'Directing'),
#  ('Steve Martino', 4943, 2, 71729, 'Directing'),
#  ('David Mamet', 4944, 2, 1255, 'Directing'),
#  ('Zhang Yimou', 4945, 2, 607, 'Directing'),
#  ('Ash Brannon', 4946, 2, 12905, 'Directing'),
#  ('Frank Oz', 4947, 2, 7908, 'Directing'),
#  ('Jay Roach', 4948, 2, 6737, 'Directing'),
#  ('Luc Besson', 4949, 2, 59, 'Directing'),
#  ('Michael Patrick King', 4950, 2, 38023, 'Directing'),
#  ('Don Michael Paul', 4951, 2, 27005, 'Directing'),
#  ('Sergei Bodrov', 4952, 0, 130938, 'Directing'),
#  ('Wally Pfister', 4953, 2, 559, 'Directing'),
#  ('Rupert Wyatt', 4954, 0, 77357, 'Directing'),
#  ('Mark Waters', 4955, 2, 54050, 'Directing'),
#  ('John Moore', 4956, 2, 12028, 'Directing'),
#  ('John Lee Hancock', 4957, 2, 54040, 'Directing'),
#  ('Renny Harlin', 4958, 2, 16938, 'Directing'),
#  ('Phil Lord', 4959, 0, 107446, 'Directing'),
#  ('Ben Stiller', 4960, 2, 7399, 'Directing'),
#  ('Tony Bancroft', 4961, 2, 66190, 'Directing'),
#  ('Timur Bekmambetov', 4962, 2, 23430, 'Directing'),
#  ('Walt Becker', 4963, 2, 68573, 'Directing'),
#  ('Dennis Dugan', 4964, 2, 17494, 'Directing'),
#  ('Sydney Pollack', 4965, 2, 2226, 'Directing'),
#  ('Thor Freudenthal', 4966, 2, 109857, 'Directing'),
#  ('Brian De Palma', 4967, 2, 1150, 'Directing'),
#  ('Mick Jackson', 4968, 2, 8843, 'Directing'),
#  ('Alan J. Pakula', 4969, 2, 6349, 'Directing'),
#  ('Kathryn Bigelow', 4970, 1, 14392, 'Directing'),
#  ('John Milius', 4971, 2, 8328, 'Directing'),
#  ('Andrei Konchalovsky', 4972, 2, 58728, 'Directing'),
#  ('Gary Ross', 4973, 2, 23964, 'Directing'),
#  ('Paul W.S. Anderson', 4974, 2, 4014, 'Directing'),
#  ('Genndy Tartakovsky', 4975, 0, 185438, 'Directing'),
#  ('Kevin Lima', 4976, 2, 15775, 'Directing'),
#  ('Daniel Espinosa', 4977, 2, 125738, 'Directing'),
#  ('Nancy Meyers', 4978, 1, 17698, 'Directing'),
#  ('Jill Culton', 4979, 1, 7881, 'Directing'),
#  ('Neil Burger', 4980, 2, 17329, 'Directing'),
#  ('Jean-Jacques Annaud', 4981, 2, 2352, 'Directing'),
#  ('Barry Cook', 4982, 2, 66191, 'Directing'),
#  ('Martin Brest', 4983, 2, 769, 'Directing'),
#  ('Andrew Davis', 4984, 2, 12989, 'Directing'),
#  ('Bob Fosse', 4985, 0, 66777, 'Directing'),
#  ('Tarsem Singh', 4986, 2, 56512, 'Directing'),
#  ('Edgar Wright', 4987, 2, 11090, 'Directing'),
#  ('Jon Amiel', 4988, 2, 15148, 'Directing'),
#  ('Peter Segal', 4989, 2, 13426, 'Directing'),
#  ('Pete Travis', 4990, 0, 43141, 'Directing'),
#  ('George A. Romero', 4991, 2, 14999, 'Directing'),
#  ('Sylvester Stallone', 4992, 2, 16483, 'Directing'),
#  ('Todd Phillips', 4993, 2, 57130, 'Directing'),
#  ('Karey Kirkpatrick', 4994, 2, 52845, 'Directing'),
#  ('Gary Winick', 4995, 2, 17046, 'Directing'),
#  ('Mimi Leder', 4996, 1, 51984, 'Directing'),
#  ('Seth Gordon', 4997, 2, 71600, 'Directing'),
#  ('Adam Shankman', 4998, 2, 20739, 'Directing'),
#  ('D.J. Caruso', 4999, 2, 40256, 'Directing'),
#  ('Anthony Minghella', 5000, 2, 2239, 'Directing'),
#  ('Albert Hughes', 5001, 2, 11447, 'Directing'),
#  ('Les Mayfield', 5002, 0, 56911, 'Directing'),
#  ('Joe Pytka', 5003, 2, 23677, 'Directing'),
#  ('Scott Derrickson', 5004, 2, 55499, 'Directing'),
#  ('Ivan Reitman', 5005, 2, 8858, 'Directing'),
#  ('Eric Brevig', 5006, 2, 9622, 'Directing'),
#  ('Kelly Asbury', 5007, 2, 12079, 'Directing'),
#  ('Stephen Hopkins', 5008, 2, 2042, 'Directing'),
#  ('Jonathan Demme', 5009, 2, 16294, 'Directing'),
#  ('Henry Jaglom', 5010, 2, 117075, 'Directing'),
#  ('James Algar', 5011, 2, 5690, 'Directing'),
#  ('Vincent Ward', 5012, 0, 9198, 'Directing'),
#  ('Steven Brill', 5013, 2, 32593, 'Directing'),
#  ('Terry Gilliam', 5014, 2, 280, 'Directing'),
#  ('Lucile Hadzihalilovic', 5015, 0, 17627, 'Directing'),
#  ('Roger Christian', 5016, 2, 5058, 'Directing'),
#  ('Joe Dante', 5017, 2, 4600, 'Directing'),
#  ('Kevin Costner', 5018, 2, 1269, 'Directing'),
#  ('Antony Hoffman', 5019, 2, 56154, 'Directing'),
#  ('Jacques Perrin', 5020, 2, 20030, 'Directing'),
#  ('Andrés Couturier', 5021, 0, 1172908, 'Directing'),
#  ('Roger Allers', 5022, 2, 15812, 'Directing'),
#  ('Cody Cameron', 5023, 2, 12095, 'Directing'),
#  ('John Singleton', 5024, 2, 6482, 'Directing'),
#  ('Oliver Hirschbiegel', 5025, 2, 7832, 'Directing'),
#  ('Des McAnuff', 5026, 2, 588701, 'Directing'),
#  ('Chris Renaud', 5027, 0, 124748, 'Directing'),
#  ('Stephen Norrington', 5028, 2, 10808, 'Directing'),
#  ('Pierre Coffin', 5029, 2, 124747, 'Directing'),
#  ('David Kellogg', 5030, 2, 4759, 'Directing'),
#  ('Mike Nichols', 5031, 2, 5342, 'Directing'),
#  ('Vicky Jenson', 5032, 1, 12058, 'Directing'),
#  ('F. Gary Gray', 5033, 2, 37932, 'Directing'),
#  ('Antoine Fuqua', 5034, 2, 20907, 'Directing'),
#  ('Robert Luketic', 5035, 2, 36797, 'Directing'),
#  ('Gil Kenan', 5036, 2, 57193, 'Directing'),
#  ('Barry Levinson', 5037, 2, 8246, 'Directing'),
#  ('Jerry Zucker', 5038, 2, 3415, 'Directing'),
#  ('Andy Tennant', 5039, 2, 17167, 'Directing'),
#  ('Florent-Emilio Siri', 5040, 0, 1011158, 'Directing'),
#  ('Gary Goldman', 5041, 2, 12881, 'Directing'),
#  ('Ron Shelton', 5042, 2, 4037, 'Directing'),
#  ('Àlex Pastor', 5043, 2, 94220, 'Directing'),
#  ('Henry Selick', 5044, 2, 57646, 'Directing'),
#  ('Kyle Balda', 5045, 0, 8023, 'Directing'),
#  ('Fergal Reilly', 5046, 0, 52701, 'Directing'),
#  ('Judd Apatow', 5047, 2, 41039, 'Directing'),
#  ('Steve Carr', 5048, 2, 52112, 'Directing'),
#  ('Mel Gibson', 5049, 2, 2461, 'Directing'),
#  ('David Silverman', 5050, 2, 197, 'Directing'),
#  ('Frank Darabont', 5051, 2, 4027, 'Directing'),
#  ('Betty Thomas', 5052, 1, 31024, 'Directing'),
#  ('Garry Marshall', 5053, 2, 1201, 'Directing'),
#  ('Paul Tibbitt', 5054, 0, 217174, 'Directing'),
#  ('Clark Johnson', 5055, 2, 47640, 'Directing'),
#  ('Cameron Crowe', 5056, 2, 11649, 'Directing'),
#  ('Randall Wallace', 5057, 2, 2460, 'Directing'),
#  ('Jonathan Frakes', 5058, 2, 2388, 'Directing'),
#  ('George Clooney', 5059, 2, 1461, 'Directing'),
#  ('Gary Shore', 5060, 0, 1167470, 'Directing'),
#  ('Andrzej Bartkowiak', 5061, 2, 10765, 'Directing'),
#  ('Måns Mårlind', 5062, 2, 80923, 'Directing'),
#  ('Gregory Hoblit', 5063, 2, 17812, 'Directing'),
#  ('Gary McKendry', 5064, 0, 141688, 'Directing'),
#  ('Wych Kaosayananda', 5065, 0, 65615, 'Directing'),
#  ('Mikael Salomon', 5066, 2, 30149, 'Directing'),
#  ('Bobby Farrelly', 5067, 2, 7395, 'Directing'),
#  ('Dan St. Pierre', 5068, 0, 15780, 'Directing'),
#  ('Kerry Conran', 5069, 2, 41378, 'Directing'),
#  ('Michael Caton-Jones', 5070, 2, 30365, 'Directing'),
#  ('Mikael Håfström', 5071, 0, 29605, 'Directing'),
#  ('Phil Alden Robinson', 5072, 2, 23968, 'Directing'),
#  ('David Slade', 5073, 2, 27571, 'Directing'),
#  ('Joseph Ruben', 5074, 2, 52629, 'Directing'),
#  ('Seth MacFarlane', 5075, 2, 52139, 'Directing'),
#  ('Alejandro Amenábar', 5076, 2, 19840, 'Directing'),
#  ('Kinka Usher', 5077, 0, 59646, 'Directing'),
#  ('Craig Gillespie', 5078, 0, 50767, 'Directing'),
#  ('Rob Bowman', 5079, 2, 12523, 'Directing'),
#  ('Doug Lefler', 5080, 0, 58656, 'Directing'),
#  ('Scott Waugh', 5081, 2, 293911, 'Directing'),
#  ('Lawrence Kasdan', 5082, 2, 8844, 'Directing'),
#  ('Michael Lembeck', 5083, 2, 15045, 'Directing'),
#  ('Tom Hooper', 5084, 2, 70500, 'Directing'),
#  ('Nora Ephron', 5085, 0, 9248, 'Directing'),
#  ('Angelina Jolie', 5086, 1, 11701, 'Directing'),
#  ('Clint Eastwood', 5087, 2, 190, 'Directing'),
#  ('Larry Charles', 5088, 2, 6767, 'Directing'),
#  ('Stanley Kubrick', 5089, 2, 240, 'Directing'),
#  ('Will Gluck', 5090, 2, 82511, 'Directing'),
#  ('Glenn Ficarra', 5091, 2, 56411, 'Directing'),
#  ('David S. Goyer', 5092, 2, 3893, 'Directing'),
#  ('Taylor Hackford', 5093, 0, 18596, 'Directing'),
#  ('Michael Lehmann', 5094, 2, 7145, 'Directing'),
#  ('Stuart Beattie', 5095, 0, 1707, 'Directing'),
#  ('Roman Polanski', 5096, 2, 3556, 'Directing'),
#  ('Robert Rodriguez', 5097, 0, 2294, 'Directing'),
#  ('Baltasar Kormákur', 5098, 2, 67813, 'Directing'),
#  ('Daniel Lee', 5099, 2, 57832, 'Directing'),
#  ('Keenen Ivory Wayans', 5100, 2, 35689, 'Directing'),
#  ('Rob Reiner', 5101, 2, 3026, 'Directing'),
#  ('Marco Schnabel', 5102, 2, 71527, 'Directing'),
#  ('Demian Lichtenstein', 5103, 2, 71418, 'Directing'),
#  ('Josh Gordon', 5104, 2, 60922, 'Directing'),
#  ('Tim Hill', 5105, 2, 49903, 'Directing'),
#  ('David Frankel', 5106, 2, 5065, 'Directing'),
#  ('Marc Lawrence', 5107, 2, 18323, 'Directing'),
#  ('Peter Billingsley', 5108, 2, 12708, 'Directing'),
#  ('Wes Ball', 5109, 0, 1179066, 'Directing'),
#  ('Ryan Murphy', 5110, 2, 52779, 'Directing'),
#  ('Robert Redford', 5111, 2, 4135, 'Directing'),
#  ('Jay Russell', 5112, 2, 46297, 'Directing'),
#  ('Kenny Ortega', 5113, 2, 65310, 'Directing'),
#  ('David McNally', 5114, 2, 48980, 'Directing'),
#  ('Brian Robbins', 5115, 2, 53177, 'Directing'),
#  ('Brian Levant', 5116, 2, 13581, 'Directing'),
#  ('Steven Zaillian', 5117, 2, 2260, 'Directing'),
#  ('Sam Fell', 5118, 2, 58897, 'Directing'),
#  ('Jon Avnet', 5119, 2, 18250, 'Directing'),
#  ('Robert Stevenhagen', 5120, 0, 64152, 'Directing'),
#  ('Kevin Donovan', 5121, 2, 66654, 'Directing'),
#  ('Geoff Murphy', 5122, 2, 32277, 'Directing'),
#  ('David O. Russell', 5123, 2, 17883, 'Directing'),
#  ('Babak Najafi', 5124, 2, 132239, 'Directing'),
#  ('Jean-Pierre Jeunet', 5125, 2, 2419, 'Directing'),
#  ('Anthony Stacchi', 5126, 2, 52691, 'Directing'),
#  ('Griffin Dunne', 5127, 0, 2171, 'Directing'),
#  ('John Pasquin', 5128, 2, 58072, 'Directing'),
#  ('Ruben Fleischer', 5129, 2, 91268, 'Directing'),
#  ('Harold Ramis', 5130, 2, 1524, 'Directing'),
#  ('Kevin Macdonald', 5131, 2, 17350, 'Directing'),
#  ('Donald Petrie', 5132, 2, 18281, 'Directing'),
#  ('Jorge Blanco', 5133, 2, 117052, 'Directing'),
#  ('Stuart Baird', 5134, 2, 2523, 'Directing'),
#  ('Joel Coen', 5135, 0, 1223, 'Directing'),
#  ('Robert Lorenz', 5136, 2, 4746, 'Directing'),
#  ('Harold Becker', 5137, 2, 23213, 'Directing'),
#  ('Scott Stewart', 5138, 0, 116357, 'Directing'),
#  ('Tony Bill', 5139, 2, 57138, 'Directing'),
#  ('Rod Lurie', 5140, 2, 21526, 'Directing'),
#  ('Walter Hill', 5141, 2, 1723, 'Directing'),
#  ('Akiva Goldsman', 5142, 2, 5575, 'Directing'),
#  ('Harald Zwart', 5143, 2, 21981, 'Directing'),
#  ('Walter Salles', 5144, 2, 8574, 'Directing'),
#  ('Iain Softley', 5145, 2, 1978, 'Directing'),
#  ('Frank Miller', 5146, 2, 2293, 'Directing'),
#  ('David Koepp', 5147, 2, 508, 'Directing'),
#  ('Uwe Boll', 5148, 2, 23799, 'Directing'),
#  ('Soi Cheang', 5149, 2, 93991, 'Directing'),
#  ('John Dahl', 5150, 2, 21053, 'Directing'),
#  ('Tim Miller', 5151, 2, 55252, 'Directing'),
#  ('Stephen Herek', 5152, 2, 18356, 'Directing'),
#  ('Peter MacDonald', 5153, 2, 16589, 'Directing'),
#  ('Anthony Hemingway', 5154, 0, 1216147, 'Directing'),
#  ('Sean Anders', 5155, 2, 74619, 'Directing'),
#  ('Brian Taylor', 5156, 2, 20192, 'Directing'),
#  ('John Madden', 5157, 0, 18844, 'Directing'),
#  ('Kevin Bray', 5158, 2, 34453, 'Directing'),
#  ('Mike Gabriel', 5159, 2, 65530, 'Directing'),
#  ('Sam Weisman', 5160, 2, 54967, 'Directing'),
#  ('Jesse Dylan', 5161, 2, 54584, 'Directing'),
#  ('Wayne Wang', 5162, 0, 39819, 'Directing'),
#  ('Gabriele Muccino', 5163, 2, 20646, 'Directing'),
#  ('Tom Dey', 5164, 2, 46076, 'Directing'),
#  ('Jimmy Hayward', 5165, 2, 8029, 'Directing'),
#  ('Alan Parker', 5166, 2, 9168, 'Directing'),
#  ('John Frankenheimer', 5167, 2, 13776, 'Directing'),
#  ('Paul King', 5168, 2, 101666, 'Directing'),
#  ('Akiva Schaffer', 5169, 2, 62854, 'Directing'),
#  ('William Friedkin', 5170, 0, 15175, 'Directing'),
#  ('Kent Alterman', 5171, 2, 65702, 'Directing'),
#  ('Peter Lord', 5172, 2, 53304, 'Directing'),
#  ('Shekhar Kapur', 5173, 2, 37630, 'Directing'),
#  ('Karyn Kusama', 5174, 1, 54025, 'Directing'),
#  ('Ronald F. Maxwell', 5175, 2, 66088, 'Directing'),
#  ('Robert Butler', 5176, 2, 101767, 'Directing'),
#  ('Steve Antin', 5177, 2, 42745, 'Directing'),
#  ('Jim Gillespie', 5178, 2, 33254, 'Directing'),
#  ('Francis Ford Coppola', 5179, 2, 1776, 'Directing'),
#  ('Richard Lester', 5180, 0, 10586, 'Directing'),
#  ('Scott Cooper', 5181, 2, 65167, 'Directing'),
#  ('Curtis Hanson', 5182, 2, 323, 'Directing'),
#  ('Phyllida Lloyd', 5183, 1, 71068, 'Directing'),
#  ('Jay Chandrasekhar', 5184, 2, 52049, 'Directing'),
#  ('Terrence Malick', 5185, 2, 30715, 'Directing'),
#  ('David Dobkin', 5186, 2, 42994, 'Directing'),
#  ('Miloš Forman', 5187, 2, 3974, 'Directing'),
#  ('Pierre Morel', 5188, 2, 35453, 'Directing'),
#  ('Paul Hunter', 5189, 2, 70573, 'Directing'),
#  ('Steve Oedekerk', 5190, 2, 4489, 'Directing'),
#  ('John Whitesell', 5191, 2, 61175, 'Directing'),
#  ('George Nolfi', 5192, 2, 1921, 'Directing'),
#  ('Neil Jordan', 5193, 0, 17016, 'Directing'),
#  ('Rawson Marshall Thurber', 5194, 0, 57633, 'Directing'),
#  ('Spike Lee', 5195, 2, 5281, 'Directing'),
#  ('Brian Helgeland', 5196, 2, 4723, 'Directing'),
#  ('Frank Marshall', 5197, 2, 664, 'Directing'),
#  ('Hideo Nakata', 5198, 2, 26875, 'Directing'),
#  ('Peter Hewitt', 5199, 2, 18357, 'Directing'),
#  ('Joe Roth', 5200, 0, 18311, 'Directing'),
#  ('Bennett Miller', 5201, 2, 5345, 'Directing'),
#  ('Jaume Collet-Serra', 5202, 2, 59521, 'Directing'),
#  ('Andy Fickman', 5203, 2, 58375, 'Directing'),
#  ('James McTeigue', 5204, 2, 11266, 'Directing'),
#  ("Matthew O'Callaghan", 5205, 2, 61290, 'Directing'),
#  ('Angela Robinson', 5206, 1, 7312, 'Directing'),
#  ('Gary Fleder', 5207, 2, 5501, 'Directing'),
#  ('Tommy Wirkola', 5208, 2, 76927, 'Directing'),
#  ('Adrian Lyne', 5209, 2, 7270, 'Directing'),
#  ('Stephen Gaghan', 5210, 2, 2945, 'Directing'),
#  ('Jorge R. Gutierrez', 5211, 0, 1265056, 'Directing'),
#  ('Richard Loncraine', 5212, 2, 33315, 'Directing'),
#  ('Christophe Gans', 5213, 2, 8296, 'Directing'),
#  ('Howard Deutch', 5214, 2, 26502, 'Directing'),
#  ('Jon Hurwitz', 5215, 2, 68843, 'Directing'),
#  ('Steven Quale', 5216, 2, 93214, 'Directing'),
#  ('John Landis', 5217, 2, 4610, 'Directing'),
#  ('Alexander Witt', 5218, 2, 17649, 'Directing'),
#  ('Beeban Kidron', 5219, 1, 20237, 'Directing'),
#  ('Carl Franklin', 5220, 0, 21712, 'Directing'),
#  ('Steven Seagal', 5221, 2, 23880, 'Directing'),
#  ('Danny Boyle', 5222, 2, 2034, 'Directing'),
#  ('Andrew Bergman', 5223, 0, 41550, 'Directing'),
#  ('Barbet Schroeder', 5224, 2, 23393, 'Directing'),
#  ('Peter Webber', 5225, 2, 16785, 'Directing'),
#  ('Andrew Niccol', 5226, 2, 8685, 'Directing'),
#  ('John Carpenter', 5227, 2, 11770, 'Directing'),
#  ('Wes Anderson', 5228, 2, 5655, 'Directing'),
#  ('David Cronenberg', 5229, 2, 224, 'Directing'),
#  ('John Stockwell', 5230, 2, 57082, 'Directing'),
#  ('David Gordon Green', 5231, 2, 64141, 'Directing'),
#  ('Jim Sheridan', 5232, 2, 53334, 'Directing'),
#  ('Costa-Gavras', 5233, 0, 27436, 'Directing'),
#  ('Patrick Read Johnson', 5234, 2, 56059, 'Directing'),
#  ('Richard LaGravenese', 5235, 2, 2163, 'Directing'),
#  ('Danny DeVito', 5236, 2, 518, 'Directing'),
#  ('George Armitage', 5237, 0, 58294, 'Directing'),
#  ('Patrick Lussier', 5238, 0, 27226, 'Directing'),
#  ('James Wong', 5239, 2, 57134, 'Directing'),
#  ('Richard Curtis', 5240, 2, 7018, 'Directing'),
#  ('Chuck Bowman', 5241, 2, 41270, 'Directing'),
#  ('Olivier Megaton', 5242, 2, 75035, 'Directing'),
#  ('Deepa Mehta', 5243, 1, 4760, 'Directing'),
#  ('Warren Beatty', 5244, 2, 6449, 'Directing'),
#  ('Penny Marshall', 5245, 1, 14911, 'Directing'),
#  ('Ted Kotcheff', 5246, 2, 16544, 'Directing'),
#  ('Andrei Tarkovsky', 5247, 2, 8452, 'Directing'),
#  ('Yvette Kaplan', 5248, 0, 31093, 'Directing'),
#  ('Stephen Frears', 5249, 0, 3224, 'Directing'),
#  ('P.J. Hogan', 5250, 2, 3045, 'Directing'),
#  ('Brad Furman', 5251, 2, 144221, 'Directing'),
#  ('Terence Young', 5252, 2, 9855, 'Directing'),
#  ('David Zucker', 5253, 2, 12987, 'Directing'),
#  ('Denis Villeneuve', 5254, 2, 137427, 'Directing'),
#  ('Thomas Carter', 5255, 2, 52038, 'Directing'),
#  ('Roger Michell', 5256, 2, 7017, 'Directing'),
#  ('Luis Llosa', 5257, 2, 26648, 'Directing'),
#  ('Melville Shavelson', 5258, 2, 16745, 'Directing'),
#  ('Garth Jennings', 5259, 2, 52842, 'Directing'),
#  ('Joel Zwick', 5260, 2, 54644, 'Directing'),
#  ('Russell Mulcahy', 5261, 2, 52968, 'Directing'),
#  ('David R. Ellis', 5262, 2, 4755, 'Directing'),
#  ('Peter Howitt', 5263, 2, 7791, 'Directing'),
#  ('John A. Davis', 5264, 2, 60237, 'Directing'),
#  ('David Lynch', 5265, 2, 5602, 'Directing'),
#  ('Julie Taymor', 5266, 1, 16391, 'Directing'),
#  ('Mathieu Kassovitz', 5267, 2, 2406, 'Directing'),
#  ('John Gray', 5268, 2, 35155, 'Directing'),
#  ('John Schultz', 5269, 2, 79656, 'Directing'),
#  ('Sean Penn', 5270, 2, 2228, 'Directing'),
#  ('Susan Stroman', 5271, 1, 60129, 'Directing'),
#  ('Simon Wincer', 5272, 0, 18254, 'Directing'),
#  ('Billy Bob Thornton', 5273, 2, 879, 'Directing'),
#  ('Danny Pang', 5274, 2, 21905, 'Directing'),
#  ('George P. Cosmatos', 5275, 2, 16566, 'Directing'),
#  ('Oliver Parker', 5276, 2, 56710, 'Directing'),
#  ('Lawrence Kasanoff', 5277, 2, 43518, 'Directing'),
#  ('Ben Affleck', 5278, 2, 880, 'Directing'),
#  ('Brian Gibson', 5279, 2, 18069, 'Directing'),
#  ('Ben Sharpsteen', 5280, 2, 11426, 'Directing'),
#  ('Michael Cimino', 5281, 2, 12114, 'Directing'),
#  ('Paul McGuigan', 5282, 0, 2291, 'Directing'),
#  ('Gus Van Sant', 5283, 2, 5216, 'Directing'),
#  ('Roger Kumble', 5284, 2, 11873, 'Directing'),
#  ('Burr Steers', 5285, 0, 58552, 'Directing'),
#  ('Nick Park', 5286, 2, 7314, 'Directing'),
#  ('John Hamburg', 5287, 2, 17871, 'Directing'),
#  ('Reginald Hudlin', 5288, 2, 68215, 'Directing'),
#  ('Joseph L. Mankiewicz', 5289, 2, 10601, 'Directing'),
#  ('Barbra Streisand', 5290, 0, 10400, 'Directing'),
#  ('Mark Pellington', 5291, 2, 11676, 'Directing'),
#  ('John Glen', 5292, 2, 10179, 'Directing'),
#  ('Catherine Hardwicke', 5293, 1, 19850, 'Directing'),
#  ('John Herzfeld', 5294, 2, 27846, 'Directing'),
#  ('Annabel Jankel', 5295, 0, 58164, 'Directing'),
#  ('Julie Anne Robinson', 5296, 1, 114597, 'Directing'),
#  ('Seth Rogen', 5297, 2, 19274, 'Directing'),
#  ('Sngmoo Lee', 5298, 2, 141169, 'Directing'),
#  ('Jamel Debbouze', 5299, 2, 2408, 'Directing'),
#  ('Gordon Chan', 5300, 0, 64901, 'Directing'),
#  ('Asger Leth', 5301, 0, 72344, 'Directing'),
#  ('John G. Avildsen', 5302, 2, 16513, 'Directing'),
#  ('Anne Fletcher', 5303, 1, 29214, 'Directing'),
#  ('Bruce Beresford', 5304, 2, 5696, 'Directing'),
#  ('Sam Taylor-Johnson', 5305, 1, 1137903, 'Directing'),
#  ('Ken Kwapis', 5306, 0, 29009, 'Directing'),
#  ('Wes Craven', 5307, 2, 5140, 'Directing'),
#  ('Etan Cohen', 5308, 0, 52803, 'Directing'),
#  ('Nick Cassavetes', 5309, 2, 11151, 'Directing'),
#  ('Nicholas Stoller', 5310, 2, 52934, 'Directing'),
#  ('Mark A.Z. Dippé', 5311, 0, 87130, 'Directing'),
#  ('Callan Brunker', 5312, 0, 1098477, 'Directing'),
#  ('Nimród Antal', 5313, 2, 41671, 'Directing'),
#  ('Alejandro Agresti', 5314, 2, 21031, 'Directing'),
#  ('Peter Hedges', 5315, 2, 3290, 'Directing'),
#  ('Paul Weiland', 5316, 2, 66548, 'Directing'),
#  ('Colin Strause', 5317, 2, 6037, 'Directing'),
#  ('Joan Chen', 5318, 1, 6720, 'Directing'),
#  ('Greg Mottola', 5319, 2, 54733, 'Directing'),
#  ('Jake Kasdan', 5320, 2, 51851, 'Directing'),
#  ('Diane Keaton', 5321, 1, 3092, 'Directing'),
#  ('Kelly Makin', 5322, 2, 64030, 'Directing'),
#  ('Stephen Daldry', 5323, 2, 468, 'Directing'),
#  ('Christian Duguay', 5324, 2, 25735, 'Directing'),
#  ('Justin Chadwick', 5325, 2, 71570, 'Directing'),
#  ("Pat O'Connor", 5326, 2, 19969, 'Directing'),
#  ('Frederik Du Chau', 5327, 2, 50582, 'Directing'),
#  ('Irwin Winkler', 5328, 2, 11472, 'Directing'),
#  ('Joseph Kahn', 5329, 2, 66823, 'Directing'),
#  ('Sofia Coppola', 5330, 1, 1769, 'Directing'),
#  ('Stephen T. Kay', 5331, 2, 56435, 'Directing'),
#  ('Juan Antonio Bayona', 5332, 2, 51894, 'Directing'),
#  ('Elaine May', 5333, 1, 58251, 'Directing'),
#  ('Dennie Gordon', 5334, 1, 66960, 'Directing'),
#  ('Charles Shyer', 5335, 2, 56106, 'Directing'),
#  ('Ulu Grosbard', 5336, 2, 140354, 'Directing'),
#  ('William Malone', 5337, 2, 57898, 'Directing'),
#  ('Malcolm D. Lee', 5338, 2, 72024, 'Directing'),
#  ('Jerry Jameson', 5339, 2, 52094, 'Directing'),
#  ('Mic Rodgers', 5340, 2, 18889, 'Directing'),
#  ('Christian Alvart', 5341, 2, 54559, 'Directing'),
#  ('Jean-Marie Poiré', 5342, 2, 64909, 'Directing'),
#  ('Marc F. Adler', 5343, 2, 86295, 'Directing'),
#  ('Geoffrey Sax', 5344, 2, 61357, 'Directing'),
#  ('Richard Shepard', 5345, 2, 44740, 'Directing'),
#  ('Peter Chan', 5346, 2, 56739, 'Directing'),
#  ('Sergei Bodrov Jr.', 5347, 2, 71871, 'Directing'),
#  ('Bong Joon-ho', 5348, 2, 21684, 'Directing'),
#  ('Bibo Bergeron', 5349, 2, 65629, 'Directing'),
#  ('Jeff Nathanson', 5350, 2, 2689, 'Directing'),
#  ('S.S. Rajamouli', 5351, 2, 147021, 'Directing'),
#  ('Charles S. Dutton', 5352, 2, 17764, 'Directing'),
#  ('Jonathan Lynn', 5353, 2, 21217, 'Directing'),
#  ('David Carson', 5354, 2, 2380, 'Directing'),
#  ('Wong Kar-wai', 5355, 2, 12453, 'Directing'),
#  ('Yuefeng Song', 5356, 0, 1496406, 'Directing'),
#  ('Norman Jewison', 5357, 2, 13563, 'Directing'),
#  ('David Mirkin', 5358, 2, 58178, 'Directing'),
#  ('Luis Mandoki', 5359, 0, 46085, 'Directing'),
#  ('Lee Daniels', 5360, 2, 20019, 'Directing'),
#  ('Jeb Stuart', 5361, 2, 7671, 'Directing'),
#  ('Steve Miner', 5362, 2, 58712, 'Directing'),
#  ('Paul Thomas Anderson', 5363, 2, 4762, 'Directing'),
#  ('David Leland', 5364, 2, 33317, 'Directing'),
#  ('J Blakeson', 5365, 2, 111588, 'Directing'),
#  ('Ryan Coogler', 5366, 2, 1056121, 'Directing'),
#  ('Kirk Jones', 5367, 0, 64045, 'Directing'),
#  ('Jennifer Flackett', 5368, 1, 66218, 'Directing'),
#  ('Kevin Smith', 5369, 2, 19303, 'Directing'),
#  ('Christian Ditter', 5370, 2, 63820, 'Directing'),
#  ('Charles Martin Smith', 5371, 2, 1270, 'Directing'),
#  ('Fyodor Bondarchuk', 5372, 2, 80999, 'Directing'),
#  ('Irvin Kershner', 5373, 2, 10930, 'Directing'),
#  ('Steve Pink', 5374, 2, 3227, 'Directing'),
#  ('Scott Hicks', 5375, 2, 33433, 'Directing'),
#  ('Kirk De Micco', 5376, 2, 71267, 'Directing'),
#  ('Chris Rock', 5377, 2, 2632, 'Directing'),
#  ('Wilson Yip', 5378, 2, 63571, 'Directing'),
#  ('Robert Wise', 5379, 2, 1744, 'Directing'),
#  ('Kevin Rodney Sullivan', 5380, 2, 70777, 'Directing'),
#  ('Kevin Munroe', 5381, 2, 19499, 'Directing'),
#  ('Mike Tollin', 5382, 2, 53178, 'Directing'),
#  ('Patrick Tatopoulos', 5383, 2, 3964, 'Directing'),
#  ('Gary David Goldberg', 5384, 2, 70738, 'Directing'),
#  ('Tobe Hooper', 5385, 2, 10051, 'Directing'),
#  ('Alan Poul', 5386, 2, 113225, 'Directing'),
#  ('Luke Greenfield', 5387, 2, 65734, 'Directing'),
#  ('Gil Junger', 5388, 2, 40243, 'Directing'),
#  ('Michael Ritchie', 5389, 2, 12964, 'Directing'),
#  ('Steven E. de Souza', 5390, 2, 1726, 'Directing'),
#  ('Alexandre Aja', 5391, 2, 59291, 'Directing'),
#  ('Michael Rymer', 5392, 2, 28741, 'Directing'),
#  ('Hugh Wilson', 5393, 2, 28904, 'Directing'),
#  ('Mike Hodges', 5394, 0, 17281, 'Directing'),
#  ('Scott Mann', 5395, 0, 90812, 'Directing'),
#  ('Susanna White', 5396, 0, 113600, 'Directing'),
#  ('Chris Carter', 5397, 2, 12524, 'Directing'),
#  ("Tommy O'Haver", 5398, 2, 62514, 'Directing'),
#  ('Peter Landesman', 5399, 0, 1192754, 'Directing'),
#  ('Gary Chapman', 5400, 2, 80691, 'Directing'),
#  ('Craig Mazin', 5401, 2, 35796, 'Directing'),
#  ('Allen Hughes', 5402, 2, 11448, 'Directing'),
#  ('Kimble Rendall', 5403, 0, 64163, 'Directing'),
#  ('Peter Yates', 5404, 2, 12804, 'Directing'),
#  ('Lasse Hallström', 5405, 2, 5306, 'Directing'),
#  ('Jean-Marc Vallée', 5406, 2, 69371, 'Directing'),
#  ('Tsui Hark', 5407, 2, 26760, 'Directing'),
#  ('Lexi Alexander', 5408, 0, 56359, 'Directing'),
#  ('Ronny Yu', 5409, 0, 17268, 'Directing'),
#  ('Bille August', 5410, 2, 19684, 'Directing'),
#  ('Moustapha Akkad', 5411, 2, 66203, 'Directing'),
#  ('Jean-Paul Rappeneau', 5412, 2, 25950, 'Directing'),
#  ('Joachim Rønning', 5413, 0, 20307, 'Directing'),
#  ('Tony Kaye', 5414, 2, 814, 'Directing'),
#  ('Ken Scott', 5415, 0, 1375201, 'Directing'),
#  ('Hugh Johnson', 5416, 2, 22100, 'Directing'),
#  ('Hayao Miyazaki', 5417, 2, 608, 'Directing'),
#  ('George Tillman, Jr.', 5418, 2, 66121, 'Directing'),
#  ('Rand Ravich', 5419, 2, 29524, 'Directing'),
#  ('Hugh Hudson', 5420, 2, 58220, 'Directing'),
#  ('Ben Stassen', 5421, 2, 76100, 'Directing'),
#  ('Chris Gorak', 5422, 2, 10855, 'Directing'),
#  ('Scott Speer', 5423, 2, 932088, 'Directing'),
#  ('Joe Charbanic', 5424, 2, 66604, 'Directing'),
#  ('Jonathan Hensleigh', 5425, 2, 876, 'Directing'),
#  ('Danny Cannon', 5426, 2, 33279, 'Directing'),
#  ('Boaz Yakin', 5427, 2, 52358, 'Directing'),
#  ('Richard Marquand', 5428, 2, 19800, 'Directing'),
#  ('Neil Marshall', 5429, 2, 57581, 'Directing'),
#  ('David Wain', 5430, 2, 22214, 'Directing'),
#  ('Jared Hess', 5431, 2, 53925, 'Directing'),
#  ('Rupert Wainwright', 5432, 2, 11809, 'Directing'),
#  ('John Luessenhop', 5433, 2, 97026, 'Directing'),
#  ('Justin Zackham', 5434, 2, 52599, 'Directing'),
#  ('John Gatins', 5435, 2, 53176, 'Directing'),
#  ('Miguel Sapochnik', 5436, 2, 114404, 'Directing'),
#  ('Shim Hyung-Rae', 5437, 2, 64331, 'Directing'),
#  ('Don Scardino', 5438, 2, 93419, 'Directing'),
#  ('Tim Robbins', 5439, 2, 504, 'Directing'),
#  ('Tom Reeve', 5440, 2, 43673, 'Directing'),
#  ('Nanette Burstein', 5441, 1, 96439, 'Directing'),
#  ('Ariel Vromen', 5442, 2, 81476, 'Directing'),
#  ('Lewis Gilbert', 5443, 2, 10076, 'Directing'),
#  ('John Francis Daley', 5444, 2, 52935, 'Directing'),
#  ('J.B. Rogers', 5445, 0, 7409, 'Directing'),
#  ('Michael Sucsy', 5446, 2, 566328, 'Directing'),
#  ('Tom Vaughan', 5447, 2, 56717, 'Directing'),
#  ('Stephen Hillenburg', 5448, 2, 70651, 'Directing'),
#  ('Stig Bergqvist', 5449, 0, 80540, 'Directing'),
#  ('Jason Reitman', 5450, 2, 52443, 'Directing'),
#  ('Alexander Payne', 5451, 0, 13235, 'Directing'),
#  ('Jonathan Levine', 5452, 2, 56661, 'Directing'),
#  ('Rian Johnson', 5453, 2, 67367, 'Directing'),
#  ('Chris Noonan', 5454, 2, 58137, 'Directing'),
#  ('Michael McCullers', 5455, 2, 14172, 'Directing'),
#  ('Forest Whitaker', 5456, 2, 2178, 'Directing'),
#  ('Woody Allen', 5457, 2, 1243, 'Directing'),
#  ('Peter Lepeniotis', 5458, 0, 1262197, 'Directing'),
#  ('Ted Demme', 5459, 2, 34849, 'Directing'),
#  ('William Shatner', 5460, 2, 1748, 'Directing'),
#  ('James Gartner', 5461, 2, 60496, 'Directing'),
#  ('Lee Toland Krieger', 5462, 2, 109745, 'Directing'),
#  ('Tim McCanlies', 5463, 2, 77919, 'Directing'),
#  ('Drew Goddard', 5464, 2, 47506, 'Directing'),
#  ('Jason Friedberg', 5465, 2, 35694, 'Directing'),
#  ('Paul Michael Glaser', 5466, 2, 12988, 'Directing'),
#  ('John R. Leonetti', 5467, 2, 26714, 'Directing'),
#  ('Tom Hanks', 5468, 2, 31, 'Directing'),
#  ('Kimberly Peirce', 5469, 0, 2836, 'Directing'),
#  ('Liz Friedlander', 5470, 1, 60024, 'Directing'),
#  ('Phil Joanou', 5471, 2, 18500, 'Directing'),
#  ('Shane Acker', 5472, 2, 71923, 'Directing'),
#  ('Martha Coolidge', 5473, 1, 63713, 'Directing'),
#  ('Stephen Anderson', 5474, 0, 227438, 'Directing'),
#  ('Troy Miller', 5475, 2, 58868, 'Directing'),
#  ('Tate Taylor', 5476, 2, 55789, 'Directing'),
#  ('Brett Leonard', 5477, 0, 57090, 'Directing'),
#  ('Alister Grierson', 5478, 0, 59126, 'Directing'),
#  ('Nick Hurran', 5479, 2, 42274, 'Directing'),
#  ('Charles Stone III', 5480, 2, 80215, 'Directing'),
#  ('Paul Haggis', 5481, 2, 455, 'Directing'),
#  ('Kurt Wimmer', 5482, 2, 13927, 'Directing'),
#  ('Jean-François Richet', 5483, 0, 58324, 'Directing'),
#  ('Kevin Hooks', 5484, 2, 40230, 'Directing'),
#  ('Ellory Elkayem', 5485, 2, 56150, 'Directing'),
#  ('Niki Caro', 5486, 1, 15287, 'Directing'),
#  ('Vincenzo Natali', 5487, 2, 5877, 'Directing'),
#  ('Willard Huyck', 5488, 2, 686, 'Directing'),
#  ("Gavin O'Connor", 5489, 2, 77003, 'Directing'),
#  ('Bruce Hunt', 5490, 2, 44179, 'Directing'),
#  ('Christopher Roberts', 5491, 2, 20305, 'Directing'),
#  ('Kim Jee-woon', 5492, 0, 543568, 'Directing'),
#  ('Nick Hamm', 5493, 2, 6361, 'Directing'),
#  ('Andy Cadiff', 5494, 2, 80307, 'Directing'),
#  ('Mike Disa', 5495, 0, 108952, 'Directing'),
#  ('Richard J. Lewis', 5496, 2, 137475, 'Directing'),
#  ('Sergio Leone', 5497, 2, 4385, 'Directing'),
#  ('Niels Arden Oplev', 5498, 2, 19346, 'Directing'),
#  ('Michael Radford', 5499, 2, 28898, 'Directing'),
#  ('Steve Boyum', 5500, 2, 72258, 'Directing'),
#  ('Chen Kaige', 5501, 2, 20640, 'Directing'),
#  ('Corey Yuen Kwai', 5502, 0, 35452, 'Directing'),
#  ('Andrew Dominik', 5503, 2, 37618, 'Directing'),
#  ('Jackie Chan', 5504, 2, 18897, 'Directing'),
#  ('Laurent Tirard', 5505, 0, 64575, 'Directing'),
#  ('Reinhard Klooss', 5506, 2, 57035, 'Directing'),
#  ('Frédéric Auburtin', 5507, 2, 21126, 'Directing'),
#  ('Olivier Dahan', 5508, 2, 16919, 'Directing'),
#  ('Maksim Fadeev', 5509, 0, 1565981, 'Directing'),
#  ('Liliana Cavani', 5510, 1, 67750, 'Directing'),
#  ('Elizabeth Banks', 5511, 1, 9281, 'Directing'),
#  ('Edward Norton', 5512, 2, 819, 'Directing'),
#  ('Ben Falcone', 5513, 2, 170820, 'Directing'),
#  ('Richard Attenborough', 5514, 2, 4786, 'Directing'),
#  ('Don Mancini', 5515, 2, 65677, 'Directing'),
#  ('John Maybury', 5516, 2, 40307, 'Directing'),
#  ('Norton Virgien', 5517, 2, 86439, 'Directing'),
#  ('Shinji Aramaki', 5518, 0, 70100, 'Directing'),
#  ('Miguel Arteta', 5519, 2, 61069, 'Directing'),
#  ('James Gray', 5520, 2, 20561, 'Directing'),
#  ('Janusz Kamiński', 5521, 2, 492, 'Directing'),
#  ('Robert B. Weide', 5522, 0, 74159, 'Directing'),
#  ('Jeff Wadlow', 5523, 2, 55075, 'Directing'),
#  ('Agustín Díaz Yanes', 5524, 0, 127823, 'Directing'),
#  ('Camille Delamarre', 5525, 0, 928490, 'Directing'),
#  ('David Lean', 5526, 2, 12238, 'Directing'),
#  ('Richard Eyre', 5527, 2, 36693, 'Directing'),
#  ('Nicholas Meyer', 5528, 2, 1788, 'Directing'),
#  ('Callie Khouri', 5529, 1, 17397, 'Directing'),
#  ('Sanaa Hamri', 5530, 1, 64140, 'Directing'),
#  ('Todd Graff', 5531, 2, 18342, 'Directing'),
#  ('Philip Kaufman', 5532, 2, 648, 'Directing'),
#  ('Saul Dibb', 5533, 2, 73460, 'Directing'),
#  ('Walter Murch', 5534, 2, 154, 'Directing'),
#  ('Richard Linklater', 5535, 2, 564, 'Directing'),
#  ('E. Elias Merhige', 5536, 0, 17279, 'Directing'),
#  ('Menno Meyjes', 5537, 2, 736, 'Directing'),
#  ('Jodie Foster', 5538, 1, 1038, 'Directing'),
#  ('Scott Frank', 5539, 2, 2199, 'Directing'),
#  ('Kevin Allen', 5540, 2, 36083, 'Directing'),
#  ('Michael Cristofer', 5541, 2, 21136, 'Directing'),
#  ('Andrew Morahan', 5542, 2, 53599, 'Directing'),
#  ('Bob Rafelson', 5543, 2, 19450, 'Directing'),
#  ('Michael Cohn', 5544, 2, 56956, 'Directing'),
#  ('Alan Shapiro', 5545, 2, 129941, 'Directing'),
#  ('Fernando Meirelles', 5546, 2, 8557, 'Directing'),
#  ('Michael Hoffman', 5547, 2, 52405, 'Directing'),
#  ('Oleg Stepchenko', 5548, 0, 238220, 'Directing'),
#  ('Michael Winterbottom', 5549, 2, 172, 'Directing'),
#  ('Michael Pressman', 5550, 2, 59649, 'Directing'),
#  ('Sharon Maguire', 5551, 1, 9158, 'Directing'),
#  ('Charles Herman-Wurmfeld', 5552, 2, 76247, 'Directing'),
#  ('Gábor Csupó', 5553, 2, 36697, 'Directing'),
#  ('Tyler Perry', 5554, 2, 80602, 'Directing'),
#  ('Joe Carnahan', 5555, 2, 40223, 'Directing'),
#  ('John Polson', 5556, 2, 15337, 'Directing'),
#  ('Bernardo Bertolucci', 5557, 2, 4956, 'Directing'),
#  ('Cathy Malkasian', 5558, 1, 78488, 'Directing'),
#  ('Chris Nahon', 5559, 2, 21931, 'Directing'),
#  ('Fred Wolf', 5560, 2, 66563, 'Directing'),
#  ('Bille Woodruff', 5561, 0, 62116, 'Directing'),
#  ('Victor Salva', 5562, 2, 56349, 'Directing'),
#  ('Mark Helfrich', 5563, 2, 1098, 'Directing'),
#  ('Steve Bendelack', 5564, 2, 16356, 'Directing'),
#  ('Dwight H. Little', 5565, 0, 56998, 'Directing'),
#  ('Guillaume Canet', 5566, 2, 19866, 'Directing'),
#  ('Kirsten Sheridan', 5567, 1, 41285, 'Directing'),
#  ('Richard Fleischer', 5568, 0, 2087, 'Directing'),
#  ('Bob Spiers', 5569, 2, 47974, 'Directing'),
#  ('Damien Dante Wayans', 5570, 2, 59229, 'Directing'),
#  ('John Wells', 5571, 2, 47333, 'Directing'),
#  ('Tim Fywell', 5572, 0, 125544, 'Directing'),
#  ('Nigel Cole', 5573, 2, 24248, 'Directing'),
#  ('Dexter Fletcher', 5574, 2, 974, 'Directing'),
#  ('Jeremy Leven', 5575, 2, 25210, 'Directing'),
#  ('Sylvain White', 5576, 2, 31119, 'Directing'),
#  ('Troy Nixey', 5577, 2, 135601, 'Directing'),
#  ('Philip G. Atwell', 5578, 2, 65190, 'Directing'),
#  ('Jeff Schaffer', 5579, 2, 57405, 'Directing'),
#  ('James Bridges', 5580, 2, 14838, 'Directing'),
#  ('Steve Barron', 5581, 2, 18308, 'Directing'),
#  ('Bill Paxton', 5582, 2, 2053, 'Directing'),
#  ('Richard Kelly', 5583, 2, 1577, 'Directing'),
#  ('Carter Smith', 5584, 0, 68352, 'Directing'),
#  ('John Schlesinger', 5585, 2, 19304, 'Directing'),
#  ('Ringo Lam', 5586, 2, 26767, 'Directing'),
#  ('Bruce McCulloch', 5587, 2, 73499, 'Directing'),
#  ('Patricia Riggen', 5588, 0, 437833, 'Directing'),
#  ('Pascal Chaumeil', 5589, 2, 8392, 'Directing'),
#  ('Jonathan Kaplan', 5590, 2, 42171, 'Directing'),
#  ('Ole Bornedal', 5591, 2, 22676, 'Directing'),
#  ('Richard Benjamin', 5592, 2, 24318, 'Directing'),
#  ('Craig R. Baxley', 5593, 2, 63709, 'Directing'),
#  ('John Hillcoat', 5594, 2, 53333, 'Directing'),
#  ('John Guillermin', 5595, 2, 6778, 'Directing'),
#  ('Marcos Siega', 5596, 2, 74062, 'Directing'),
#  ('Rachel Talalay', 5597, 1, 56891, 'Directing'),
#  ('Jeffrey W. Byrd', 5598, 0, 109695, 'Directing'),
#  ('Atom Egoyan', 5599, 2, 56205, 'Directing'),
#  ('Robert Towne', 5600, 2, 11057, 'Directing'),
#  ('Giuseppe Tornatore', 5601, 0, 65314, 'Directing'),
#  ('Werner Herzog', 5602, 2, 6818, 'Directing'),
#  ('Jérôme Deschamps', 5603, 0, 93592, 'Directing'),
#  ('Inna Evlannikova', 5604, 1, 115999, 'Directing'),
#  ('Jonathan English', 5605, 2, 83730, 'Directing'),
#  ('Sergey Bondarchuk', 5606, 2, 38131, 'Directing'),
#  ('Teddy Chan', 5607, 0, 70703, 'Directing'),
#  ('Mario Van Peebles', 5608, 2, 16214, 'Directing'),
#  ('Leonard Nimoy', 5609, 2, 1749, 'Directing'),
#  ('Herbert Ross', 5610, 0, 18378, 'Directing'),
#  ('Bonnie Hunt', 5611, 1, 5149, 'Directing'),
#  ('Neil LaBute', 5612, 2, 58689, 'Directing'),
#  ('Grant Heslov', 5613, 2, 31511, 'Directing'),
#  ('George Gallo', 5614, 2, 21792, 'Directing'),
#  ('Sidney Lumet', 5615, 0, 39996, 'Directing'),
#  ('Douglas McGrath', 5616, 2, 32983, 'Directing'),
#  ('Kevin Spacey', 5617, 2, 1979, 'Directing'),
#  ('Richard Williams', 5618, 0, 116100, 'Directing'),
#  ('Mary McGuckian', 5619, 1, 130482, 'Directing'),
#  ('Tony Goldwyn', 5620, 2, 3417, 'Directing'),
#  ('Jonathan Newman', 5621, 2, 558177, 'Directing'),
#  ('Michael Dinner', 5622, 2, 84165, 'Directing'),
#  ('Joseph Sargent', 5623, 2, 15663, 'Directing'),
#  ('Jerry Zaks', 5624, 2, 59635, 'Directing'),
#  ('Fred Durst', 5625, 2, 29783, 'Directing'),
#  ('Anne Fontaine', 5626, 1, 48583, 'Directing'),
#  ('Jon Cassar', 5627, 0, 25873, 'Directing'),
#  ('Mira Nair', 5628, 1, 6495, 'Directing'),
#  ('Mel Brooks', 5629, 2, 14639, 'Directing'),
#  ('Russell Crowe', 5630, 2, 934, 'Directing'),
#  ('Jessie Nelson', 5631, 1, 16853, 'Directing'),
#  ('Christopher Spencer', 5632, 0, 235820, 'Directing'),
#  ('Mike Bigelow', 5633, 2, 69498, 'Directing'),
#  ('Daniel Sackheim', 5634, 2, 12632, 'Directing'),
#  ('Deborah Kaplan', 5635, 1, 13614, 'Directing'),
#  ('Uli Edel', 5636, 0, 15868, 'Directing'),
#  ('Fred Dekker', 5637, 2, 44056, 'Directing'),
#  ('Brian Trenchard-Smith', 5638, 0, 84981, 'Directing'),
#  ('Blake Edwards', 5639, 2, 1927, 'Directing'),
#  ('Laurence Dunmore', 5640, 0, 52894, 'Directing'),
#  ('Christian Carion', 5641, 2, 70221, 'Directing'),
#  ('Dax Shepard', 5642, 2, 51298, 'Directing'),
#  ('Rowan Joffe', 5643, 2, 17608, 'Directing'),
#  ('John Curran', 5644, 2, 96166, 'Directing'),
#  ('Juan José Campanella', 5645, 2, 84714, 'Directing'),
#  ('Trey Parker', 5646, 2, 34517, 'Directing'),
#  ('Stuart Gillard', 5647, 2, 76418, 'Directing'),
#  ('Katt Shea', 5648, 1, 102634, 'Directing'),
#  ('Joshua Michael Stern', 5649, 2, 64139, 'Directing'),
#  ('Tomas Alfredson', 5650, 2, 74396, 'Directing'),
#  ('John Duigan', 5651, 2, 72624, 'Directing'),
#  ('Colin Higgins', 5652, 2, 4967, 'Directing'),
#  ('Jim Sonzero', 5653, 2, 58514, 'Directing'),
#  ('Penelope Spheeris', 5654, 0, 58448, 'Directing'),
#  ('Jeff Tremaine', 5655, 2, 56578, 'Directing'),
#  ('Jeannot Szwarc', 5656, 2, 16187, 'Directing'),
#  ('Steve McQueen', 5657, 2, 72757, 'Directing'),
#  ('Thea Sharrock', 5658, 1, 1096867, 'Directing'),
#  ('Jon Lucas', 5659, 2, 52114, 'Directing'),
#  ('Robin Budd', 5660, 0, 1027737, 'Directing'),
#  ('Ava DuVernay', 5661, 1, 929825, 'Directing'),
#  ('Steve Trenbirth', 5662, 0, 142007, 'Directing'),
#  ('Mennan Yapo', 5663, 0, 61087, 'Directing'),
#  ('Jun Falkenstein', 5664, 1, 93301, 'Directing'),
#  ('Tom McCarthy', 5665, 0, 17867, 'Directing'),
#  ('Takashi Shimizu', 5666, 2, 20310, 'Directing'),
#  ('Gary Nelson', 5667, 2, 47893, 'Directing'),
#  ('Anton Corbijn', 5668, 2, 45052, 'Directing'),
#  ('Gregory Nava', 5669, 2, 16395, 'Directing'),
#  ('John Patrick Shanley', 5670, 2, 26095, 'Directing'),
#  ('Joshua Logan', 5671, 2, 86051, 'Directing'),
#  ('Steve Beck', 5672, 2, 57521, 'Directing'),
#  ('Todd Strauss-Schulson', 5673, 2, 222470, 'Directing'),
#  ('John McNaughton', 5674, 2, 9200, 'Directing'),
#  ('Nelson McCormick', 5675, 2, 45627, 'Directing'),
#  ('Eric Valette', 5676, 0, 51445, 'Directing'),
#  ('Andrew Fleming', 5677, 2, 41549, 'Directing'),
#  ('Michael Spierig', 5678, 2, 56501, 'Directing'),
#  ('Jim Field Smith', 5679, 2, 111686, 'Directing'),
#  ('Thomas Bezucha', 5680, 2, 56789, 'Directing'),
#  ('William Brent Bell', 5681, 2, 62768, 'Directing'),
#  ('Ben Gluck', 5682, 2, 61970, 'Directing'),
#  ('Jessica Bendinger', 5683, 1, 53014, 'Directing'),
#  ('Henry Joost', 5684, 2, 142272, 'Directing'),
#  ('Ed Harris', 5685, 2, 228, 'Directing'),
#  ('Alfred Hitchcock', 5686, 2, 2636, 'Directing'),
#  ('Shana Feste', 5687, 0, 129718, 'Directing'),
#  ('Steve Rash', 5688, 2, 54590, 'Directing'),
#  ('Mike Binder', 5689, 2, 24173, 'Directing'),
#  ('Michael J. Bassett', 5690, 2, 69593, 'Directing'),
#  ('Frank Nissen', 5691, 2, 73161, 'Directing'),
#  ('Stephen Chow', 5692, 2, 57607, 'Directing'),
#  ('Peter Hastings', 5693, 2, 64149, 'Directing'),
#  ('Paul Abascal', 5694, 2, 1216735, 'Directing'),
#  ('Chris Koch', 5695, 2, 58059, 'Directing'),
#  ('Amy Heckerling', 5696, 1, 57434, 'Directing'),
#  ('Michael Moore', 5697, 2, 17087, 'Directing'),
#  ('George Stevens', 5698, 2, 18738, 'Directing'),
#  ('Billy Ray', 5699, 2, 21807, 'Directing'),
#  ('Mark Mylod', 5700, 2, 57199, 'Directing'),
#  ('Stephen St. Leger', 5701, 0, 936154, 'Directing'),
#  ('Michael O. Sajbel', 5702, 2, 87178, 'Directing'),
#  ('Charles T. Kanganis', 5703, 2, 36147, 'Directing'),
#  ('Damon Santostefano', 5704, 2, 66039, 'Directing'),
#  ('Bob Clark', 5705, 2, 12698, 'Directing'),
#  ('Frank Passingham', 5706, 2, 53332, 'Directing'),
#  ('Benson Lee', 5707, 0, 1046142, 'Directing'),
#  ('Glen Morgan', 5708, 2, 58403, 'Directing'),
#  ('Mike Leigh', 5709, 2, 65452, 'Directing'),
#  ('Alejandro Monteverde', 5710, 0, 72960, 'Directing'),
#  ('Jonathan Glazer', 5711, 2, 66728, 'Directing'),
#  ('J.C. Chandor', 5712, 0, 556172, 'Directing'),
#  ('Paul Gross', 5713, 2, 84021, 'Directing'),
#  ('Marc Abraham', 5714, 2, 15219, 'Directing'),
#  ('Todd Haynes', 5715, 2, 16863, 'Directing'),
#  ('Mabrouk El Mechri', 5716, 2, 74924, 'Directing'),
#  ('Charlie Kaufman', 5717, 2, 202, 'Directing'),
#  ('Nancy Walker', 5718, 1, 47503, 'Directing'),
#  ('Angelo Pizzo', 5719, 0, 44848, 'Directing'),
#  ('Matthew Diamond', 5720, 2, 116370, 'Directing'),
#  ('Katsuhiro Ōtomo', 5721, 2, 185, 'Directing'),
#  ('David Anspaugh', 5722, 2, 44847, 'Directing'),
#  ('Andrew Jarecki', 5723, 2, 23287, 'Directing'),
#  ('Daniel Algrant', 5724, 2, 69696, 'Directing'),
#  ('Mike Barker', 5725, 2, 77964, 'Directing'),
#  ('Wayne Thornley', 5726, 0, 1098107, 'Directing'),
#  ('Gnana Rajasekaran', 5727, 0, 1339129, 'Directing'),
#  ('Tom Walsh', 5728, 0, 1275019, 'Directing'),
#  ('Jonathan Jakubowicz', 5729, 0, 57454, 'Directing'),
#  ('Scott Walker', 5730, 0, 1179590, 'Directing'),
#  ('Mark Rosman', 5731, 2, 68770, 'Directing'),
#  ('Rob Hawk', 5732, 0, 1585252, 'Directing'),
#  ('Britt Allcroft', 5733, 0, 113733, 'Directing'),
#  ('Alan Yuen', 5734, 0, 70110, 'Directing'),
#  ('Brian Percival', 5735, 2, 126945, 'Directing'),
#  ('Anand Tucker', 5736, 2, 26481, 'Directing'),
#  ('Anthony Mann', 5737, 2, 40199, 'Directing'),
#  ('Michael Dowse', 5738, 2, 71280, 'Directing'),
#  ('Daniel Barnz', 5739, 2, 84061, 'Directing'),
#  ('Emile Ardolino', 5740, 2, 716, 'Directing'),
#  ('Robert Altman', 5741, 2, 9789, 'Directing'),
#  ('James Schamus', 5742, 0, 1617, 'Directing'),
#  ('Andrew Douglas', 5743, 2, 62721, 'Directing'),
#  ('Ricky Gervais', 5744, 2, 17835, 'Directing'),
#  ('Vic Armstrong', 5745, 2, 15358, 'Directing'),
#  ('Terry Zwigoff', 5746, 0, 17447, 'Directing'),
#  ('Audrey Wells', 5747, 1, 36805, 'Directing'),
#  ('Rick Friedberg', 5748, 2, 65548, 'Directing'),
#  ('Sean McNamara', 5749, 2, 129952, 'Directing'),
#  ('Jody Hill', 5750, 2, 54710, 'Directing'),
#  ('Brandon Camp', 5751, 2, 62541, 'Directing'),
#  ('Kevin Tancharoen', 5752, 2, 101518, 'Directing'),
#  ('Nicholas Hytner', 5753, 2, 55476, 'Directing'),
#  ('Bart Freundlich', 5754, 2, 86203, 'Directing'),
#  ('William A. Fraker', 5755, 2, 12846, 'Directing'),
#  ('John Boorman', 5756, 2, 19665, 'Directing'),
#  ('Courtney Solomon', 5757, 2, 61921, 'Directing'),
#  ('Jeff Kanew', 5758, 2, 67897, 'Directing'),
#  ('István Szabó', 5759, 0, 225898, 'Directing'),
#  ('Matthew Robbins', 5760, 2, 12677, 'Directing'),
#  ('Hal Needham', 5761, 2, 67767, 'Directing'),
#  ...]

# %%
directors = pd.DataFrame(directors,columns=['name', 'id', 'gender', 'uid',
                                  'department'] )

# %%
directors
# Out:
#                    name    id  gender      uid department
# 0         James Cameron  4762       2     2710  Directing
# 1        Gore Verbinski  4763       2     1704  Directing
# 2            Sam Mendes  4764       2       39  Directing
# 3     Christopher Nolan  4765       2      525  Directing
# 4        Andrew Stanton  4766       2        7  Directing
# ...                 ...   ...     ...      ...        ...
# 2344      Shane Carruth  7106       2    76624  Directing
# 2345   Neill Dela Llana  7107       0  1174437  Directing
# 2346        Scott Smith  7108       0  1219158  Directing
# 2347        Daniel Hsia  7109       2   208138  Directing
# 2348   Brian Herzlinger  7110       2    85563  Directing
#
# [2349 rows x 5 columns]

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2349 non-null   object
#  1   id          2349 non-null   int64
#  2   gender      2349 non-null   int64
#  3   uid         2349 non-null   int64
#  4   department  2349 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 91.9+ KB

# %% [markdown]
# 4. Check how many movies are present in the IMDB table

# %%
# We will use count function to count total movies in table
cur.execute('SELECT COUNT(Title) FROM movies')
count = cur.fetchall()
print(f"The number of movies present in the IMDB databse is {count[0]}")
# Out:
# The number of movies present in the IMDB databse is (4773,)

# %% [markdown]
# 5. Find these 3 directors: James Cameron, Luc Besson, John Woo

# %%
# cur.execute("SELECT * FROM directors WHERE name IN ('Shane Carruth','Luc Besson', 'John Woo')") We can use this and also the query below
cur.execute("SELECT * FROM directors WHERE name =='Shane Carruth' or name =='Luc Besson' or name == 'John Woo'")
three_directors = cur.fetchall()
print(f"Theses 3 Directors data are: {three_directors}")
# Out:
# Theses 3 Directors data are: [('John Woo', 4893, 2, 11401, 'Directing'), ('Luc Besson', 4949, 2, 59, 'Directing'), ('Shane Carruth', 7106, 2, 76624, 'Directing')]

# %% [markdown]
# 6. Find all the directors with name starting with 'Steven'

# %%
cur.execute('SELECT * FROM directors WHERE name LIKE "Steven%"')
name_like = cur.fetchall()
print(f"The directors whose names are starting with the word 'Steven' are: {name_like}")
# Out:
# The directors whose names are starting with the word 'Steven' are: [('Steven Spielberg', 4799, 2, 488, 'Directing'), ('Steven Soderbergh', 4909, 2, 1884, 'Directing'), ('Steven Brill', 5013, 2, 32593, 'Directing'), ('Steven Zaillian', 5117, 2, 2260, 'Directing'), ('Steven Quale', 5216, 2, 93214, 'Directing'), ('Steven Seagal', 5221, 2, 23880, 'Directing'), ('Steven E. de Souza', 5390, 2, 1726, 'Directing'), ('Steven Shainberg', 5803, 2, 67795, 'Directing'), ('Steven R. Monroe', 6713, 2, 88039, 'Directing')]

# %% [markdown]
# 7. Count the Female directors

# %%
cur.execute("SELECT COUNT(*) FROM directors WHERE gender == '1'")
females = cur.fetchall()
print(f"The number of female directors are {females[0][0]}")
# Out:
# The number of female directors are 150

# %% [markdown]
# 8. Find the name of the 10th first women directors

# %%
cur.execute('SELECT name FROM directors WHERE gender==1')
tenth = cur.fetchall()
print(f"The tenth first women is {tenth[9][0]}")
# Out:
# The tenth first women is Angelina Jolie

# %% [markdown]
# 9. What are the 3 most popular movies?

# %%
cur.execute('SELECT title FROM movies ORDER BY popularity DESC LIMIT 3 ')
most_popular = cur.fetchall()
print(f"The 3 mostpopular movies are: {most_popular[0][0]}, {most_popular[1][0]} and {most_popular[2][0]}")
# Out:
# The 3 mostpopular movies are: Minions, Interstellar and Deadpool

# %% [markdown]
# 10. What are the 3 most bankable movies?

# %%
cur.execute('SELECT title FROM movies ORDER BY budget DESC LIMIT 3')
most_bankable = cur.fetchall()
most_bankable
print(f"The three most bankable movies are {most_bankable[0][0]}, {most_bankable[1][0]} and {most_bankable[2][0]}")
# Out:
# The three most bankable movies are Pirates of the Caribbean: On Stranger Tides, Pirates of the Caribbean: At World's End and Avengers: Age of Ultron

# %% [markdown]
# 11. What is the most awarded average rated movie since the Jan 1st, 2000?

# %%
cur.execute("SELECT Original_title FROM movies WHERE Release_date	 > '2000-01-01' ORDER BY vote_average DESC LIMIT 1")
most_awarded_avg = cur.fetchall()
print(f"The most awarded average rated movie is {most_awarded_avg[0][0]}")
# Out:
# The most awarded average rated movie is Sardaarji

# %% [markdown]
# 12. Which movie(s) were directed by Brenda Chapman?

# %%
cur.execute("SELECT original_title FROM movies JOIN directors ON directors.id = movies.director_id WHERE directors.name = 'Brenda Chapman'")
directed_by = cur.fetchall()
print(f"The movie(s) directed by Brenda Chapman is {directed_by[0][0]}")
# Out:
# The movie(s) directed by Brenda Chapman is Brave

# %% [markdown]
# 13. Name the director who has made the most movies?

# %%
cur.execute("SELECT name FROM directors JOIN movies ON directors.id = movies.director_id GROUP BY director_id ORDER BY COUNT(name) DESC limit 1") # group by -> it will allow to club rows
director_movie = cur.fetchall()                                                                                                                   # By default it is in ascending.
print(f"The director who made the most movies is {director_movie[0][0]}")
# Out:
# The director who made the most movies is Steven Spielberg

# %% [markdown]
# 14. Name of the director who is most bankable

# %%
cur.execute("SELECT name FROM directors JOIN movies ON directors.id = movies.director_id GROUP BY director_id ORDER BY SUM(budget) DESC limit 1")
most_bankable = cur.fetchall()
print(f'The most bankable director is {most_bankable[0][0]}')
# Out:
# The most bankable director is Steven Spielberg

# %% [markdown]
# # Budget Analysis

# %% [markdown]
# 1. Tell the Top 10 highest budget making movie

# %%
movies.columns
# Out:
# Index(['id', 'original_title', 'budget', 'popularity', 'release_date',
#        'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline',
#        'uid', 'director_id'],
#       dtype='object')

# %%
cur.execute('Select * FROM movies ORDER BY budget DESC LIMIT 10')
top_10 = cur.fetchall()
most_popular = pd.DataFrame(top_10, columns=['id', 'original_title', 'budget', 'popularity', 'release_date',
       'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline',
       'uid', 'director_id'])
most_popular
# Out:
#       id                               original_title     budget  popularity  \
# 0  43614  Pirates of the Caribbean: On Stranger Tides  380000000         135
# 1  43598     Pirates of the Caribbean: At World's End  300000000         139
# 2  43604                      Avengers: Age of Ultron  280000000         134
# 3  43607                             Superman Returns  270000000          57
# 4  43601                                  John Carter  260000000          43
# 5  43603                                      Tangled  260000000          48
# 6  43602                                 Spider-Man 3  258000000         115
# 7  43610                              The Lone Ranger  255000000          49
# 8  43600                        The Dark Knight Rises  250000000         112
# 9  43605       Harry Potter and the Half-Blood Prince  250000000          98
#
#   release_date     revenue                                        title  \
# 0   2011-05-14  1045713802  Pirates of the Caribbean: On Stranger Tides
# 1   2007-05-19   961000000     Pirates of the Caribbean: At World's End
# 2   2015-04-22  1405403694                      Avengers: Age of Ultron
# 3   2006-06-28   391081192                             Superman Returns
# 4   2012-03-07   284139100                                  John Carter
# 5   2010-11-24   591794936                                      Tangled
# 6   2007-05-01   890871626                                 Spider-Man 3
# 7   2013-07-03    89289910                              The Lone Ranger
# 8   2012-07-16  1084939099                        The Dark Knight Rises
# 9   2009-07-07   933959197       Harry Potter and the Half-Blood Prince
#
#    vote_average  vote_count  \
# 0           6.4        4948
# 1           6.9        4500
# 2           7.3        6767
# 3           5.4        1400
# 4           6.1        2124
# 5           7.4        3330
# 6           5.9        3576
# 7           5.9        2311
# 8           7.6        9106
# 9           7.4        5293
#
#                                             overview  \
# 0  Captain Jack Sparrow crosses paths with a woma...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  When Tony Stark tries to jumpstart a dormant p...
# 3  Superman returns to discover his 5-year absenc...
# 4  John Carter is a war-weary, former military ca...
# 5  When the kingdom's most wanted-and most charmi...
# 6  The seemingly invincible Spider-Man goes up ag...
# 7  The Texas Rangers chase down a gang of outlaws...
# 8  Following the death of District Attorney Harve...
# 9  As Harry begins his sixth year at Hogwarts, he...
#
#                                           tagline    uid  director_id
# 0                     Live Forever Or Die Trying.   1865         4775
# 1  At the end of the world, the adventure begins.    285         4763
# 2                             A New Age Has Come.  99861         4769
# 3                                            None   1452         4772
# 4            Lost in our world, found in another.  49529         4766
# 5        They're taking adventure to new lengths.  38757         4768
# 6                              The battle within.    559         4767
# 7                         Never Take Off the Mask  57201         4763
# 8                                 The Legend Ends  49026         4765
# 9                           Dark Secrets Revealed    767         4770

# %% [markdown]
# # Revenue Analysis

# %% [markdown]
# 1. Find Top 10 Revenue making movies

# %%
cur.execute("SELECT * FROM movies ORDER BY revenue DESC LIMIT 10")
top10_movies = cur.fetchall()
most_revenue = pd.DataFrame(top10_movies,  columns= ['id','original_title','budget','popularity','release_date',
                                    'revenue', 'title','vote_average','vote_count','overview',
                                    'tagline','uid','director_id'])
most_revenue
# Out:
#       id              original_title     budget  popularity release_date  \
# 0  43597                      Avatar  237000000         150   2009-12-10
# 1  43622                     Titanic  200000000         100   1997-11-18
# 2  43613                The Avengers  220000000         144   2012-04-25
# 3  43625              Jurassic World  150000000         418   2015-06-09
# 4  43641                   Furious 7  190000000         102   2015-04-01
# 5  43604     Avengers: Age of Ultron  280000000         134   2015-04-22
# 6  43721                      Frozen  150000000         165   2013-11-27
# 7  43628                  Iron Man 3  200000000          77   2013-04-18
# 8  44143                     Minions   74000000         875   2015-06-17
# 9  43623  Captain America: Civil War  250000000         198   2016-04-27
#
#       revenue                       title  vote_average  vote_count  \
# 0  2787965087                      Avatar           7.2       11800
# 1  1845034188                     Titanic           7.5        7562
# 2  1519557910                The Avengers           7.4       11776
# 3  1513528810              Jurassic World           6.5        8662
# 4  1506249360                   Furious 7           7.3        4176
# 5  1405403694     Avengers: Age of Ultron           7.3        6767
# 6  1274219009                      Frozen           7.3        5295
# 7  1215439994                  Iron Man 3           6.8        8806
# 8  1156730962                     Minions           6.4        4571
# 9  1153304495  Captain America: Civil War           7.1        7241
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  84 years later, a 101-year-old woman named Ros...
# 2  When an unexpected enemy emerges and threatens...
# 3  Twenty-two years after the events of Jurassic ...
# 4  Deckard Shaw seeks revenge against Dominic Tor...
# 5  When Tony Stark tries to jumpstart a dormant p...
# 6  Young princess Anna of Arendelle dreams about ...
# 7  When Tony Stark's world is torn apart by a for...
# 8  Minions Stuart, Kevin and Bob are recruited by...
# 9  Following the events of Age of Ultron, the col...
#
#                                              tagline     uid  director_id
# 0                        Enter the World of Pandora.   19995         4762
# 1          Nothing on Earth could come between them.     597         4762
# 2                            Some assembly required.   24428         4769
# 3                                  The park is open.  135397         4783
# 4                                Vengeance Hits Home  168259         4794
# 5                                A New Age Has Come.   99861         4769
# 6  Only the act of true love will thaw a frozen h...  109445         4844
# 7                Unleash the power behind the armor.   68721         4784
# 8       Before Gru, they had a history of bad bosses  211672         5045
# 9                                    Divided We Fall  271110         4781

# %% [markdown]
# # Voting Analysis

# %% [markdown]
# 1. Find the most popular movies with highest vote_average

# %%
cur.execute(("SELECT * FROM movies ORDER BY vote_average DESC LIMIT 10"))
most_pop = cur.fetchall()
most_popular_movie = pd.DataFrame(most_pop,columns =['id', 'original_title', 'budget', 'popularity', 'release_date',
       'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline',
       'uid', 'director_id'])
most_popular_movie
# Out:
#       id            original_title    budget  popularity release_date  \
# 0  47116          Stiff Upper Lips         0           0   1998-06-12
# 1  47642     Dancer, Texas Pop. 81         0           0   1998-05-01
# 2  47589                 Sardaarji         0           0   2015-06-26
# 3  45983            One Man's Hero         0           0   1999-08-02
# 4  45478  The Shawshank Redemption  25000000         136   1994-09-23
# 5  46567        There Goes My Baby  10500000           0   1994-09-02
# 6  46393     The Prisoner of Zenda         0           4   1937-09-03
# 7  46934             The Godfather   6000000         143   1972-03-14
# 8  44259                Fight Club  63000000         146   1999-10-15
# 9  45415          Schindler's List  22000000         104   1993-11-29
#
#      revenue                     title  vote_average  vote_count  \
# 0          0          Stiff Upper Lips          10.0           1
# 1     565592     Dancer, Texas Pop. 81          10.0           1
# 2          0                 Sardaarji           9.5           2
# 3          0            One Man's Hero           9.3           2
# 4   28341469  The Shawshank Redemption           8.5        8205
# 5     123509        There Goes My Baby           8.5           2
# 6          0     The Prisoner of Zenda           8.4          11
# 7  245066411             The Godfather           8.4        5893
# 8  100853753                Fight Club           8.3        9413
# 9  321365567          Schindler's List           8.3        4329
#
#                                             overview  \
# 0  Stiff Upper Lips is a broad parody of British ...
# 1  Four guys, best friends, have grown up togethe...
# 2  A ghost hunter uses bottles to capture trouble...
# 3  One Man's Hero tells the little-known story of...
# 4  Framed in the 1940s for the double murder of h...
# 5  A group of high school seniors meets in the su...
# 6  An Englishman on a Ruritarian holiday must imp...
# 7  Spanning the years 1945 to 1955, a chronicle o...
# 8  A ticking-time-bomb insomniac and a slippery s...
# 9  The true story of how businessman Oskar Schind...
#
#                                              tagline     uid  director_id
# 0                                               None   89861         6332
# 1       in the middle of nowhere they had everything   78373         5463
# 2                                               None  346081         6588
# 3           One man's hero is another man's traitor.   69848         5770
# 4  Fear can hold you prisoner. Hope can set you f...     278         5051
# 5                                               None   88641         6051
# 6       The most thrilling swordfight ever filmed...   43867         5972
# 7                         An offer you can't refuse.     238         5179
# 8                            Mischief. Mayhem. Soap.     550         4829
# 9    Whoever saves one life, saves the world entire.     424         4799

# %% [markdown]
# # Director Analysis

# %% [markdown]
# 1. Name all the directors with the number of movies and revenue where Revenue should be taken into account for doing the analysis. The director who has the highest revenue should comes at the top and so on and so forth.

# %%
cur.execute("SELECT name,COUNT(*) AS 'Total Movies',SUM(revenue) AS 'Total Revenue' FROM  directors JOIN movies WHERE directors.id==movies.director_id GROUP BY director_id ORDER BY SUM(revenue) DESC")
director_revenue=cur.fetchall()
director_most_revenue=pd.DataFrame(director_revenue,columns=['Director_Name','Total Movies','Total Revenue'])
director_most_revenue.head(10)
# Out:
#        Director_Name  Total Movies  Total Revenue
# 0   Steven Spielberg            27     9147393164
# 1      Peter Jackson             9     6498642820
# 2      James Cameron             7     5883569439
# 3        Michael Bay            12     5832524638
# 4  Christopher Nolan             8     4227483234
# 5     Chris Columbus            11     3725631503
# 6    Robert Zemeckis            13     3590622002
# 7       George Lucas             5     3339113893
# 8         Tim Burton            14     3337418241
# 9       Ridley Scott            16     3189557997

# %% [markdown]
# 2. Name all the directors with the number of movies and revenue where number of movies should be taken into account for doing the analysis. The director who has the highest number of movies should comes at the top and so on and so forth.

# %%
cur.execute("SELECT name, COUNT(title), SUM(revenue) FROM directors JOIN movies ON movies.director_id = directors.id GROUP by director_id ORDER BY  COUNT(title) DESC LIMIT 10")
director_movies = cur.fetchall()
director_most_movies = pd.DataFrame(director_movies,columns=['name','no_of_title','revenue'])
director_most_movies
# Out:
#                 name  no_of_title     revenue
# 0   Steven Spielberg           27  9147393164
# 1        Woody Allen           21   669101038
# 2     Clint Eastwood           20  2512058888
# 3    Martin Scorsese           20  1956635998
# 4          Spike Lee           16   340618771
# 5   Robert Rodriguez           16  1109899581
# 6       Ridley Scott           16  3189557997
# 7       Renny Harlin           15  1031500590
# 8  Steven Soderbergh           15  2114864443
# 9       Oliver Stone           14  1278048615

# %% [markdown]
# 3. Give the Title of the movie, realease_date, budget, revenue, popularity and vote_average made by Steven Spielberg

# %%
cur.execute("SELECT title, release_date,budget,revenue,popularity,vote_average FROM directors JOIN movies ON directors.id==movies.director_id WHERE directors.name=='Steven Spielberg'")
movies_list=cur.fetchall()
movies_list_Steven_Spielberg=pd.DataFrame(movies_list,columns=['Movie_Name','Release_Date','Total Budget','Total_Revenue','Popularity','Vote_Average'])
movies_list_Steven_Spielberg
# Out:
#                                            Movie_Name Release_Date  \
# 0   Indiana Jones and the Kingdom of the Crystal S...   2008-05-21
# 1                                             The BFG   2016-06-01
# 2                                   War of the Worlds   2005-06-28
# 3                            The Adventures of Tintin   2011-10-25
# 4                                     Minority Report   2002-06-20
# 5                        A.I. Artificial Intelligence   2001-06-29
# 6                       The Lost World: Jurassic Park   1997-05-23
# 7                                        The Terminal   2004-06-17
# 8                                              Munich   2005-12-22
# 9                                                Hook   1991-12-11
# 10                                          War Horse   2011-12-25
# 11                                Saving Private Ryan   1998-07-24
# 12                                            Lincoln   2012-11-09
# 13                                      Jurassic Park   1993-06-11
# 14                                Catch Me If You Can   2002-12-25
# 15                 Indiana Jones and the Last Crusade   1989-05-24
# 16                                    Bridge of Spies   2015-10-15
# 17                                            Amistad   1997-12-03
# 18                                               1941   1979-12-13
# 19               Indiana Jones and the Temple of Doom   1984-05-23
# 20                                   Schindler's List   1993-11-29
# 21                            Raiders of the Lost Ark   1981-06-12
# 22                 Close Encounters of the Third Kind   1977-11-16
# 23                                   The Color Purple   1985-12-18
# 24                                               Jaws   1975-06-18
# 25                         E.T. the Extra-Terrestrial   1982-04-03
# 26                           Twilight Zone: The Movie   1983-06-24
#
#     Total Budget  Total_Revenue  Popularity  Vote_Average
# 0      185000000      786636033          75           5.7
# 1      140000000      183345589          44           6.0
# 2      132000000      591739379          48           6.2
# 3      130000000      371940071          89           6.7
# 4      102000000      358372926          65           7.1
# 5      100000000      235926552          34           6.8
# 6       73000000      229074524           2           6.2
# 7       60000000      219417255          57           7.0
# 8       70000000      130358911          29           6.9
# 9       70000000      300854823          33           6.6
# 10      66000000      177584879          29           7.0
# 11      70000000      481840909          76           7.9
# 12      65000000      275293450          36           6.7
# 13      63000000      920100000          40           7.6
# 14      52000000      352114312          73           7.7
# 15      48000000      474171806          80           7.6
# 16      40000000      165478348          48           7.2
# 17      36000000       74000000           3           6.8
# 18      35000000       31755742          10           5.6
# 19      28000000      333000000          66           7.1
# 20      22000000      321365567         104           8.3
# 21      18000000      389925971          68           7.7
# 22      20000000      303788635          52           7.2
# 23      15000000      146292009          17           7.7
# 24       7000000      470654000          50           7.5
# 25      10500000      792910554          56           7.3
# 26      10000000       29450919          12           6.2
