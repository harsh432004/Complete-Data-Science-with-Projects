# %%
x= 46
y= 98
x,y = 46,98
print(x,y)
# Out:
# 46 98

# %%
x,y = y,x

# %%
x,y
# Out:
# (98, 46)

# %%
1987 >= 1907
# Out:
# True

# %%
a = 2 * 3
b = 3 * 3
c = 3
a = b
b = c
c = a
print(a, b, c)
# Out:
# 9 3 9

# %%
c is not a
# Out:
# False

# %% [markdown]
# # Revision

# %%
a = "12"

# %%
type(a)
# Out:
# str

# %%
print("12"*10)

# 1212
# Error
# Out:
# 12121212121212121212

# %%
var = 12
vari = 14
vary = 23

# %%
# print(var + vari - vary)

# var + vari = 12 + 14 = 26 - 23 =3
# vari - vary = 14 - 23 = -9 = 12 + (-9) = 12- 9 = 3
# 3

# + - = -
# + + = +
# - + = -
# - - = +

a = 12+4/4*8-2
print(a)
# Out:
# 18.0

# %%
is -> ==
not -> !

# %%
a,b = 12,15

# %%
a == b
# Out:
# False

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
a != b
# Out:
# True

# %%
@shape = 12

name = @shape + 2
name
# Out:
#   File "<ipython-input-81-29bb962057e0>", line 1
#     @shape = 12
#            ^
# SyntaxError: invalid syntax

# %%
print("python")

# dkfgjdfkgfkbnfgo
# dlgjfkblfgbkfgbfkbf

# %% [markdown]
# # String methods

# %%
string1 = "today is saturday"

# %%
# [] -> Square Brackets
# {} -> Curly Brackets
# () -> Round Brackets

# %% [markdown]
# *   captialize()

# %%
string1 = string1.capitalize() #capitalize first letter

# %%
string1
# Out:
# 'Today is saturday'

# %% [markdown]
# *   len()

# %%
len(string1)
# Out:
# 17

# %% [markdown]
# *   center()

# %%
######sahil######

# %%
# variable.center(len, char)

# %%
asd = string1.center(20)

# %%
asd
# Out:
# ' Today is saturday  '

# %%
asdi = "Apple"

# %%
asdi.center(20,"*")
# Out:
# '*******Apple********'

# %% [markdown]
# *   endswith()

# %%
# 1 - True
# 2 - False

# %%
# string1.endswith(value, start, end)
string2 = "Today is saturday"

# %%
string2.endswith("h")
# Out:
# True

# %%
string1.endswith("y",3,9)
# Out:
# False

# %%
string1
# Out:
# 'Today is saturday'

# %% [markdown]
# 1.   startswith()

# %%
# string1.startswith(value, start, end)

# %%
tar = "Welcome to the world"

# %%
tar.startswith("W")
# Out:
# True

# %% [markdown]
# 1.   count()

# %%
tar
# Out:
# 'Welcome to the world'

# %%
tar.count("w")
# Out:
# 1

# %% [markdown]
# 1. upper() & lower()

# %%
a -> lowercase
A -> Uppercase

# %%
tar.upper()
# Out:
# 'WELCOME TO THE WORLD'

# %%
tar = tar.lower()

# %%
tar
# Out:
# 'welcome to the world'

# %% [markdown]
# # Input

# %%
a = int(input("Enter the value of a "))
b = int(input("Enter the value of b "))

# %%
print(a)
print(b)
type(b)
# Out:
# 12
# 21
# int

# %%
a+b

# Error
# 1245
# 57
# Out:
# 33

# %%
input() -> String

# %% [markdown]
# # Typecasting

# %%
age = "22"

# %%
type(int(age))
# Out:
# int

# %% [markdown]
# # Python Data Structures

# %%
# Arrays, Stack, Queue, Linked Lits, Hashing, Graphs, Trees

1. List - [1,2,3,4,5,6,7,7,7,7,76,6,6,6,11,1,2,2,2]
2. Tuple - ()
3. Dict - {key:value}
Computer: A machine that understands humans
4. Set - {1,2,3,4,5,6,7}

if elif else -> Conditional Statement
For
while
try except

project =

# %%
{dgjgidjghfdighdig}

# %%
a = 4

# %%
a
# Out:
# 4

# %%
email = "dear professor,......."
# "Dear professor..."

# %%
email = email.capitalize()

# %%
email
# Out:
# 'Dear professor,.......'

# %%
email = email.upper()

# %%
email
# Out:
# 'DEAR PROFESSOR,.......'

# %%
email
# Out:
# 'DEAR PROFESSOR,.......'

# %%
email = email.upper()#[5:14]

# Error

# DEAR professor,.......

# %%
email[5:14]
#  Immutable -> They never ever supports the item assignment
# Out:
# 'SSOR'

# %%
email.lower()
# Out:
# 'professor'

# %%
# lower(email[5:14])
