# %% [markdown]
# # Revision
#
# 1. Tuple -> count(), index()  #it is immutable
# 2. Dictionary -> CRUD

# %% [markdown]
# # Sets
#
# 1. Python Data Structure
# 2. {}
# 3. Unordered
# 4. Unchangable -> inbuilt
# 5. It does not supports duplicacy

# %%
seti = {11,3,7,1,8} #not everytime it will be in ascending order

# %%
seti

# 11,3,7,1,8
# 1,3,7,8,11
# Out:
# {1, 3, 7, 8, 11}

# %%
setii = {1,2,3,4,5,4,1,2,3,2,1}

# %%
setii

# Error
# 1,2,3,4,5
# Out:
# {1, 2, 3, 4, 5}

# %%
seti
# Out:
# {'Cherries', 'apples', 'cherries', 'mangoes'}

# %%
listi = list(seti)

# %%
listi.sort
print(listi)
# Out:
# ['Cherries', 'cherries', 'mangoes', 'apples']

# %%
listi[0] = "Banana"

# %%
listi
# Out:
# ['Banana', 'cherries', 'mangoes', 'apples']

# %%
seti = set(listi)

# %%
seti
# Out:
# {'Banana', 'apples', 'cherries', 'mangoes'}

# %%
"Banana" in seti
# Out:
# True

# %%
# CRUD

#  C -> Create {}, set
# R -> print(). for 
# U -> adding any elements, update, {1,1} -> {2,2}
# D -> Delete, remove, pop

set_a = {"apples", "bananas", "mangoes"}
set_b = {"oranges"}


# Adding up the two sets

set_a.update(set_b)

# %%
set_a

# {"apples", "bananas", "mangoes", "oranges"}
# {"apples", "bananas", "mangoes",{"oranges"}}
# Out:
# {'apples', 'bananas', 'mangoes', 'oranges'}

# %%
set_a.add("grapes")
print(set_a)
# Out:
# {'grapes', 'mangoes', 'oranges', 'bananas', 'apples'}

# %%
set_a.add("kiwi")

# %%
set_a
# Out:
# {'apples', 'bananas', 'grapes', 'kiwi', 'mangoes', 'oranges'}

# %%
# List
remove(), pop(), del

# %%
# Sets

remove()  #removes by name

# %%
set_a.remove("kiwi")

# %%
set_a
# Out:
# {'apples', 'bananas', 'grapes', 'mangoes', 'oranges'}

# %%
set_a.discard("grapes")

# %%
set_a
# Out:
# {'apples', 'bananas', 'mangoes', 'oranges'}

# %%
# clear()

set_a.clear()

# %%
set_a
# Out:
# set()

# %%
set_a = {"apple", "bananas", "cherries"}
# example = {"apple"}
set_b = {"google", "microsoft", "apple"}

# %%
set_c = set_a.union(set_b)
print(set_c)
set_c = set_a.intersection(set_b)
print(set_c)
set_c = set_b.difference(set_a)
print(set_c)
# Out:
# {'apple', 'microsoft', 'bananas', 'cherries', 'google'}
# {'apple'}
# {'microsoft', 'google'}

# %%
set_c
# Out:
# {'google', 'microsoft'}

# %%
Python -> Multithre. multi proces, queue, stack


1. Web Develop 
2. Automa. Engi
3. Scrap
4. Data Analyis -> 


Data Types -> String, Integers, Float, Boolean
Data Structure -> List, Tuple, Dict, Set
Conditional Statement -> if,elif,else
Loop -> for & while
Day 7 -> Activity Day -(List Comprehension)

Functions -> def ___()
Oops -> Classes, objects, inheritence (single, multiple, multi level), abstraction, polymor. (overriding & overloading), Encap,

# %% [markdown]
# # Conditional Statements

# %%
a == b
a != b
a < b
a > b
a >= b
a <= b

# %%
# Italy Vs England -> Italy
# if England wins -> I'm getting 5000 extra
# otherwise -> Chores

# if uncle -> 100 < -> Snacks
# if uncle -> 100 -> Power Rangers Trump Cards
# if uncle -> >100 -> A remote control car
# otherwise -> Cry


winner = "Germany"

if winner == "England":
  print("5000 extra pocket money")
elif condition:
  statement
else:
  print("Chores")


if 
elif winner === ___
# Out:
# Chores

# %%
# if uncle -> 100 < -> Snacks
# if uncle -> 100 -> Power Rangers Trump Cards
# if uncle -> >100 -> A remote control car
# otherwise -> Cry

price = int(input("Enter the price: "))

if 100 > price > 50:
  print("Buy some snacks")
elif price == 100:
  print("Purchase the PR T. Cards")
elif 1500 > price > 100:
  print("Purchase the PS5")
elif price > 1499:
  print("Purchase the RC car")
else:
  print("Cry")
# Out:
# Purchase the RC car

# %%
stri = "Monday"

# %%
stri == False
# Out:
# False

# %%
try:
  if stripop:
    print("hello world")
except:
  print("bbye world")

# try except
# Out:
# bbye world

# %%
listi = ["Mr Bean", "Tom & Jerry", "Bob the Builder", "Richie Rich","Noddy"]

# %%
if "Noddy" in listi:
  print("Yes it is")
elif "Oswald" not in listi:
  listi.append("Garfield")
# else:
#   listi.clear()
# Out:
# Yes it is

# %%
listi
# Out:
# ['Mr Bean', 'Tom & Jerry', 'Bob the Builder', 'Richie Rich', 'Noddy']

# %%
inp = input("Enter name: ")

# num = 0-1
# alpha = a-zA-Z
# isnumeric()
# isalpha()
# isalnum() -> Alpha Numberic

if inp.isalnum():
  print("Sorry, try again")
else:
  print("Drop off from the college")
# Out:
# Drop off from the college

# %%
For & While

Python DS, input, methods, datatypes, conditional statement

# %%
dict1={"A":"a","B":"b","C":"c"}
dict1.items()
# Out:
# dict_items([('A', 'a'), ('B', 'b'), ('C', 'c')])

# %%
dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50, 6:60}

# %%
dic4 = dic1 + dic2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 dic4 = dic1 + dic2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
asd = tuple(tuppl)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-a27ba524ee95> in <module>()
# ----> 1 asd = tuple(tuple_to_list)
#
# TypeError: 'tuple' object is not callable

# %%
dic3={5:50,6:60} #value values

# %%
dic3.pop(6)
# Out:
# 60

# %%
dic3
# Out:
# {5: 50}
