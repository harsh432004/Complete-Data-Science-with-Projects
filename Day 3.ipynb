# %%
a = (input("Enter you name"))
b = ("Hello" + " " + a)
print(b)
# Error
# Work perfectly fine
# Out:
# Hello Vaisudi

# %%
a = int(input())
b = int(input())
print((a+b) + (-a))


# 2
# 4
# Out:
# 45

# %%
a = int(input("input a number: "))
b = int(input("input a number: "))

ans = (a+b)

# Error
# Concatenate +
#  42
#  6

# %%
ans
# Out:
# 45

# %%
stri = "Python"
print(stri[1:4] + " does not make any sense")
# Out:
# yth does not make any sense

# %%
stri = "Welcome "
print(stri*9)
# WelcomeWelcome
#  Welcome Welcome
# Welcome
# Welcome
# Out:
# Welcome Welcome Welcome Welcome Welcome Welcome Welcome Welcome Welcome

# %%
stri = "example"
print(stri.center(22,'*'))

# exampl
# *exampole**
# **example*
# **********example*********
# Out:
# *******example********

# %%
stri = "bat"

# %%
stri.replace("b", "c")
# Out:
# 'cat'

# %%
string = 'Hello, world.'
type(string)
# No
# Yes
# Out:
# str

# %%
"How to stop Thanos from snapping".endswith("g")
# Out:
# True

# %%
"How to stop Thanos from snapping".startswith("H")
# Out:
# True

# %%
a = "welcome"
print(a.upper().lower().capitalize())
print(a.upper().lower().capitalize())
# Out:
# Welcome
# Welcome

# %%
a = print(type(str(int(float(14.7)))))
# Out:
# <class 'str'>

# %%
print(a)
# Out:
# None

# %%
a = 14.9

# %%
b = int(a)

# 14.9 int
#  14 int
#  15 int

# %%
b
# Out:
# 14

# %% [markdown]
# # Python Data Structures
#
# Organising, Structuring, Collection, Storing, Managing
#
#
#
# 1. List
# 2. Tuple
# 3. Dict
# 4. Set

# %% [markdown]
# # List
#
# 1. Python Data Structure
# 2. Changeable -> CRUD (C-> Create, R->Read, U->Update, D->Delete)
# 3. Store hetregenous data -> Different datatype
# 4. It allows duplicate value

# %%
lis = ["Potatoes",
"Tomatoes",
"Peas",
"Onion", 
"Cauliflower",
"Ladyfinger"]

# %%
lis
# Out:
# ['Potatoes', 'Tomatoes', 'Peas', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
print(lis[4])
print(lis[-1])
# Out:
# Cauliflower
# Ladyfinger

# %%
lis
# Out:
# ['Potatoes', 'Tomatoes', 'Peas', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
stri = "Hewlo world"

# %%
stri[0:9:2]
# Out:
# 'Hwowr'

# %%
#CRUD

# C -> Create
# R -> Read
# U -> Updation
# D -> Delete

# %%
lis
# Out:
# ['Potatoes', 'Tomatoes', 'Peas', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
lis[2] = "Dhaniya"

# %%
lis
# Out:
# ['Potatoes', 'Tomatoes', 'Dhaniya', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
# Adding the list

# append() -> Adds the elements into the list in the end
# extend() -> Add the elements of two or more dictionary into one
# insert() -> Add the elements into the list w.r.t to the provided index

# %%
lis.append("Milk")
print(lis)
# Out:
# ['Potatoes', 'Tomatoes', 'Dhaniya', 'Onion', 'Cauliflower', 'Ladyfinger', 'Biscuits', 'Milk']

# %%
lis.append("Biscuits")
print(lis)
# Out:
# ['Potatoes', 'Tomatoes', 'Dhaniya', 'Onion', 'Cauliflower', 'Ladyfinger', 'Biscuits', 'Milk', 'Biscuits']

# %%
lis.insert(1,"Pencil")
print(lis)
# Out:
# ['Potatoes', 'Pencil', 'Tomatoes', 'Dhaniya', 'Onion', 'Cauliflower', 'Ladyfinger', 'Biscuits', 'Milk', 'Biscuits']

# %%
lis[1]
# Out:
# 'Pencil'

# %%
elec = ["Laptop", "Speaker", "Microphone"]
games = ["Temple Run", "COD","COC", "PubG"]

# %%
elec.extend(games)

# %%
elec
# Out:
# ['Laptop', 'Speaker', 'Microphone', 'Temple Run', 'COD', 'COC', 'PubG']

# %%
# To perform the deletion

remove(give me the name of the element)
pop(give me the index)
del -> delete it, just give me the index

# %%
elec.remove("Temple Run")
print(elec)
elec.pop(3)
print(elec)
del elec [2]
print(elec)
# Out:
# ['Laptop', 'Speaker', 'Microphone', 'COD', 'COC', 'PubG']
# ['Laptop', 'Speaker', 'Microphone', 'COC', 'PubG']
# ['Laptop', 'Speaker', 'COC', 'PubG']

# %%
elec
# Out:
# ['Laptop', 'Speaker', 'COC', 'PubG']

# %%
elec.pop(-1)
# Out:
# 'PubG'

# %%
elec.pop()
print(elec)
# Out:
# ['Laptop', 'Speaker']

# %%
elec
# Out:
# ['Laptop', 'Speaker']

# %%
num = [1,2,3,4,5,6,7]

# %%
num.remove(4)

# %%
num
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
num.remove(5)
print(num)
# Out:
# [1, 2, 3, 6, 7]

# %%
listi = [[1,2,3],[4,5,6]]

# %%
listi[1][2]
# Out:
# 6

# %%
gdfhgd = []

# %%
listi[1].remove(5)

# %%
listi
# Out:
# [[1, 2, 3], [4, 6]]

# %%
elec = ['laptop', 'mobile','computer', 'mosue']

# %%
# a.remove()
# len(a)
# del a[]

# %%
del elec[2]

# %%
elec
# Out:
# ['laptop', 'mobile', 'mosue']

# %%
grades = [38, 44, 78,37,12,9,34,76,23]
print(max(grades))
print(min(grades))
# Out:
# 78
# 9

# %%
grades.sort()
print(grades)
grades.reverse()
print(grades)
# Out:
# [9, 12, 23, 34, 37, 38, 44, 76, 78]
# [78, 76, 44, 38, 37, 34, 23, 12, 9]

# %%
grades.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 grades.len()
#
# AttributeError: 'list' object has no attribute 'len'

# %%
len(grades)
# Out:
# 9

# %%
alph = ["Hello", "World", "Cat"]

# %%
max(alph)
# Out:
# 'World'

# %%
min(alph)
# Out:
# 'Cat'

# %%
apl = ["z", "b", "f","d"]

# %%
apl.sort()

# %%
apl
# Out:
# ['b', 'd', 'f', 'z']

# %%
grades.sort(reverse=True)

# %%
grades
# Out:
# [78, 76, 44, 38, 37, 34, 23, 12, 9]

# %%
grades.reverse()

# %%
grades
# Out:
# [9, 12, 23, 34, 37, 38, 44, 76, 78]

# %%
basic list -> advanced list (list comprehension)

# %%
listi = []

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
f = int(input())

listi.append(a)
listi.append(b)
listi.append(a)
listi.append(d)
listi.append(e)

# %%
listi
# Out:
# [4, 8, 4, 84, 44]

# %%
print("Hello world")
# Out:
# 'Hello world'

# %%
# Summary

1. CRUD
2. Append, LIst methods, extends, insert, remove, pop ,del, max, min, sort, indexing & slicing(more about)

# %%
lis = [1,2]
lis1 = [4,5]

# %%
lis+lis1
# Out:
# [1, 2, 4, 5]

# %%
a = "Hello Hola Hey Hi"

# %%
a = [67,"Hey","98",98, 240,0.5,"0.6"]

# %%
a.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 a.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
