# %% [markdown]
# # Revision

# %%
# DataFrame - Intro
# Creation of the DataFrame -
1. List
2. Another DataFrame
3. Dict
4. Series
5. Ndarray
# Columns - CRUD
Column Selection
Column Addition
Column Deletion - del, pop, drop

# %%
import pandas as pd

# %%
data = {"Apples":[102, 500, 250, 75],"Grapes":[50, 150, 90, 45]}
df = pd.DataFrame(data,index=["A", "B", "C", "D"])

# %%
df
# Out:
#    Apples  Grapes
# A     102      50
# B     500     150
# C     250      90
# D      75      45

# %%
df[['Grapes']]
# Out:
#    Grapes
# A      50
# B     150
# C      90
# D      45

# %%
df['Bananas'] = df['Grapes'] + 50

# %%
df['Pear'] = df['Bananas'] + 100
df['Mangoes'] = df['Pear'] + 500
df['Jackfruit'] = df['Grapes'] + 150
df['Strawberry'] = df['Jackfruit'] + 200
df['Oranges'] = df['Strawberry'] + 70

# %%
df
# Out:
#    Apples  Grapes  Bananas  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50      100   200      700        200         400      470
# B     500     150      200   300      800        300         500      570
# C     250      90      140   240      740        240         440      510
# D      75      45       95   195      695        195         395      465

# %%
df.drop(['Bananas'], axis=1, inplace=True)

# %%
df
# Out:
#    Apples  Grapes  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50   200      700        200         400      470
# B     500     150   300      800        300         500      570
# C     250      90   240      740        240         440      510
# D      75      45   195      695        195         395      465

# %% [markdown]
# # Row - CRUD

# %%
df
# Out:
#    Apples  Grapes  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50   200      700        200         400      470
# B     500     150   300      800        300         500      570
# C     250      90   240      740        240         440      510
# D      75      45   195      695        195         395      465

# %% [markdown]
# * Row selection

# %%
loc & i(integer)loc

# %%
# loc -> Index_name but wont take an integer
df.loc[[3]] # here it will throw an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 # loc -> Index_name but wont take an integer
# ----> 2 df.loc[[3]]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# ...

# %%
df.iloc[[2]] # here it wont throw any error
# Out:
#    Apples  Grapes  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# C     250      90   240      740        240         440      510

# %%
# iloc -> index
df.iloc[2:3]
# Out:
#    Apples  Grapes  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# C     250      90   240      740        240         440      510

# %% [markdown]
# * Row Addition

# %%
student_marks = {"Name":["Rahul", "Rohit", "Venkat", "Sahil", "Ankita"],
                 "OS":[25, 75.5, 96, 0, 100],
                 "DBMS":[20, 80, 60, 50, 99]}

df1 = pd.DataFrame(student_marks)

# %%
df1
# Out:
#      Name     OS  DBMS
# 0   Rahul   25.0    20
# 1   Rohit   75.5    80
# 2  Venkat   96.0    60
# 3   Sahil    0.0    50
# 4  Ankita  100.0    99

# %%
data2 = {"Name":"Robby", "OS":60.5, "DBMS":55.5}

# %%
# 1st Method -> append()
df1 = df1.append(data2,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21960\3300580844.py in ?()
#       1 # 1st Method -> append()
# ----> 2 df1 = df1.append(data2,ignore_index=True)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df1
# Out:
#      Name     OS  DBMS
# 0   Rahul   25.0    20
# 1   Rohit   75.5    80
# 2  Venkat   96.0    60
# 3   Sahil    0.0    50
# 4  Ankita  100.0    99

# %%
# 2nd Method -> concat()
data3 = {"Name":"Spiderman", "OS":90, "DBMS":100}
df3 = pd.DataFrame(data3,index=[0])

# arr.append(1)

# %%
df3
# Out:
#         Name  OS  DBMS
# 0  Spiderman  90   100

# %%
df1 = pd.concat([df1, df3])

# %%
df1
# Out:
#         Name     OS  DBMS
# 0      Rahul   25.0    20
# 1      Rohit   75.5    80
# 2     Venkat   96.0    60
# 3      Sahil    0.0    50
# 4     Ankita  100.0    99
# 0  Spiderman   90.0   100

# %%
df1.loc[[0]]
# Out:
#         Name    OS  DBMS
# 0      Rahul  25.0    20
# 0  Spiderman  90.0   100

# %%
df1
# Out:
#         Name     OS  DBMS
# 0      Rahul   25.0    20
# 1      Rohit   75.5    80
# 2     Venkat   96.0    60
# 3      Sahil    0.0    50
# 4     Ankita  100.0    99
# 0  Spiderman   90.0   100

# %%
df1.loc[[4]]
# Out:
#      Name     OS  DBMS
# 4  Ankita  100.0    99

# %%
df1.iloc[4] = ["Steve", 67,23] # here to update rows we have to give exact same number of values else it will throw an error

# %%
df1
# Out:
#         Name    OS  DBMS
# 0      Rahul  25.0    20
# 1      Rohit  75.5    80
# 2     Venkat  96.0    60
# 3      Sahil   0.0    50
# 4      Steve  67.0    23
# 0  Spiderman  90.0   100

# %% [markdown]
# * Row Deletion

# %%
del, pop, drop

# %%
del df1.loc[[0]] # del with not work here with loc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 del df1.loc[[0]]
#
# AttributeError: __delitem__

# %%
df1.pop(df1.loc[[1]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21960\241364784.py in ?()
# ----> 1 df1.pop(df1.loc[[1]])
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, item)
#    5569         1  parrot       24.0
#    5570         2    lion       80.5
#    5571         3  monkey        NaN
#    5572         """
# -> 5573         return super().pop(item=item)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, item)
#     900     def pop(self, item: Hashable) -> Series | Any:
# --> 901         result = self[item]
#     902         del self[item]
#     903
#     904         return result
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, key)
#    3879             return self._getitem_slice(key)
#    3880
#    3881         # Do we have a (boolean) DataFrame?
# ...

# %%
df1.loc.pop([6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df1.loc.pop([6])
#
# AttributeError: '_LocIndexer' object has no attribute 'pop'

# %%
df1.pop(6) # here del and pop will only work for colummns and not for rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df1.pop(6)
#
# ...

# %%
df1.drop(0, inplace=True) # to make permanant change in data always use inplace = true else it will mark as temporary change

# %%
df1
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %%
lis = [1,2,3,4,5,6,7]

# %% [markdown]
# Pandas is used for
# * Data Exploration
# * Data Cleaning
# * Data Manipulation
# * Data Analysis

# %%
df1
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %% [markdown]
# # Data Exploration

# %%
df
# Out:
#    Apples  Grapes  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50   200      700        200         400      470
# B     500     150   300      800        300         500      570
# C     250      90   240      740        240         440      510
# D      75      45   195      695        195         395      465

# %%
df1 #10 millions # Population -> (Superset of all the Samples)
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %% [markdown]
# * head()

# %%
df1.head() # Sample (Subset of Population) means it will only show data of top 4-5 entities if we have large data of about 10 million
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %% [markdown]
# * tail()

# %%
df1.tail()
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %%
df1.head(2) # It will return first 2 rows
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60

# %%
df1.tail(1)  # It will return last 2 rows
# Out:
#     Name    OS  DBMS
# 4  Steve  67.0    23

# %% [markdown]
# * dtypes

# %%
df1.dtypes
# Out:
# Name     object
# OS      float64
# DBMS      int64
# dtype: object

# %% [markdown]
# * empty

# %%
df1.empty
# Out:
# False

# %% [markdown]
# * ndim

# %%
df1.ndim
# Out:
# 2

# %% [markdown]
# * shape

# %%
df1.shape
# Out:
# (4, 3)

# %% [markdown]
# * size

# %%
df1.size
# Out:
# 12

# %% [markdown]
# * values

# %%
df1.values # here it won't print column names
# Out:
# array([['Rohit', 75.5, 80],
#        ['Venkat', 96.0, 60],
#        ['Sahil', 0.0, 50],
#        ['Steve', 67.0, 23]], dtype=object)

# %%
df1.keys  # here it will print column names
# Out:
# <bound method NDFrame.keys of      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23>

# %% [markdown]
# * describe

# %%
df1.describe()
# Out:
#               OS       DBMS
# count   4.000000   4.000000
# mean   59.625000  53.250000
# std    41.571976  23.711811
# min     0.000000  23.000000
# 25%    50.250000  43.250000
# 50%    71.250000  55.000000
# 75%    80.625000  65.000000
# max    96.000000  80.000000

# %% [markdown]
# * T

# %%
df1.T # T here is transpose, here rows is changed to cols and cols to rows
# Out:
#           1       2      3      4
# Name  Rohit  Venkat  Sahil  Steve
# OS     75.5    96.0    0.0   67.0
# DBMS     80      60     50     23

# %%
df1.iloc[1]
# Out:
# Name    Venkat
# OS        96.0
# DBMS        60
# Name: 2, dtype: object

# %%
df1
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %%
asd = df1.T

# %%
asd.iloc[1]
# Out:
# 1    75.5
# 2    96.0
# 3     0.0
# 4    67.0
# Name: OS, dtype: object

# %% [markdown]
# * sum()

# %%
df1.sum()
# Out:
# Name    RohitVenkatSahilSteve
# OS                      238.5
# DBMS                      213
# dtype: object

# %%
df1["OS"].sum()
# Out:
# 238.5

# %%
df1.sum(1) # 1 -> axis

# %% [markdown]
# * mean()

# %%
df1
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %% [markdown]
# * mode()

# %%
df1
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %%
df1.mode()
# Out:
#      Name    OS  DBMS
# 0   Rohit   0.0    23
# 1   Sahil  67.0    50
# 2   Steve  75.5    60
# 3  Venkat  96.0    80

# %%
df1.mode(1) # arrange oderwise from accesding to descending
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_21960\3078165969.py:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   df1.mode(1)
#         0     1   2
# 1   Rohit  75.5  80
# 2  Venkat  96.0  60
# 3   Sahil   0.0  50
# 4   Steve  67.0  23

# %% [markdown]
# * std -> Standard Deviation

# %%
df1
# Out:
#      Name    OS  DBMS
# 1   Rohit  75.5    80
# 2  Venkat  96.0    60
# 3   Sahil   0.0    50
# 4   Steve  67.0    23

# %%
df1.std() # Standard Deviation

# %%
df1.std(1)
# Out:
# 1     3.535534
# 2     3.181981
# 3    25.455844
# 4    31.112698
# 5     0.707107
# 7     3.889087
# dtype: float64

# %% [markdown]
# * min() & max()

# %%
df1.min()
# Out:
# Name    Rohit
# OS        0.0
# DBMS       23
# dtype: object

# %%
df1.max()
# Out:
# Name    Venkat
# OS        96.0
# DBMS        80
# dtype: object

# %%
df1.min(1) # 1 -> axis

# %%
df1.max(1)

# %% [markdown]
# # You can also explore more on data exploration with following features:-
# * cumsum()
# * cumprod()
